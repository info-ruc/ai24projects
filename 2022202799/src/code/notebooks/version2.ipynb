# %% [markdown]
# # 人工智能引论大作业——遥感图像土地利用分类
# ## 2022202799
# ## Segment anything2 模型微调

# %%
import numpy as np
import torch
import cv2
import os
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor

# %%
# import data
os.chdir(r"D:\code\PycharmProjects\sam2-main")

data_dir=r"./EarthVQA/" # Path to dataset
data=[] # list of files in dataset
for ff, name in enumerate(os.listdir(data_dir+"Train/images_png/")):  # go over all folder annotation
    data.append({"image":data_dir+"Train/images_png/"+name,
                 "annotation":data_dir+"Train/masks_png/"+name})

# %%
def read_batch(data): # read random image and its annotaion from the dataset

   #  select image

        ent  = data[np.random.randint(len(data))] # choose random entry
        Img = cv2.imread(ent["image"])[...,::-1]  # read image
        ann_map = cv2.imread(ent["annotation"]) # read annotation

   # resize image

        r = np.min([1024 / Img.shape[1], 1024 / Img.shape[0]]) # scalling factor
        Img = cv2.resize(Img, (int(Img.shape[1] * r), int(Img.shape[0] * r)))
        ann_map = cv2.resize(ann_map, (int(ann_map.shape[1] * r), int(ann_map.shape[0] * r)),interpolation=cv2.INTER_NEAREST)

   # merge vessels and materials annotations

        mat_map = ann_map[:,:,0] # material annotation map
        ves_map = ann_map[:,:,2] # vessel  annotaion map
        mat_map[mat_map==0] = ves_map[mat_map==0]*(mat_map.max()+1) # merge maps

   # Get binary masks and points

        inds = np.unique(mat_map)[1:] # load all indices
        points= []
        masks = []
        for ind in inds:
            mask=(mat_map == ind).astype(np.uint8) # make binary mask corresponding to index ind
            masks.append(mask)
            coords = np.argwhere(mask > 0) # get all coordinates in mask
            yx = np.array(coords[np.random.randint(len(coords))]) # choose random point/coordinate
            points.append([[yx[1], yx[0]]])
        return Img,np.array(masks),np.array(points), np.ones([len(masks),1])

# %%
# Load model

sam2_checkpoint = "./checkpoints/sam2.1_hiera_tiny.pt" # path to model weight
model_cfg = "configs/sam2.1/sam2.1_hiera_t.yaml" #  model config
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda") # load model
predictor = SAM2ImagePredictor(sam2_model)

# %%
# Set training parameters

predictor.model.sam_mask_decoder.train(True) # enable training of mask decoder
predictor.model.sam_prompt_encoder.train(True) # enable training of prompt encoder

optimizer=torch.optim.AdamW(params=predictor.model.parameters(),lr=1e-5,weight_decay=4e-5)
scaler = torch.cuda.amp.GradScaler() # mixed precision

# %%
# Training loop

for itr in range(100000):
    with torch.cuda.amp.autocast(): # cast to mix precision
            image,mask,input_point, input_label = read_batch(data) # load data batch
            if mask.shape[0]==0: continue # ignore empty batches
            predictor.set_image(image) # apply SAM image encoder to the image

            # prompt encoding

            mask_input, unnorm_coords, labels, unnorm_box = predictor._prep_prompts(input_point, input_label, box=None, mask_logits=None, normalize_coords=True)
            sparse_embeddings, dense_embeddings = predictor.model.sam_prompt_encoder(points=(unnorm_coords, labels),boxes=None,masks=None,)

            # mask decoder

            batched_mode = unnorm_coords.shape[0] > 1 # multi object prediction
            high_res_features = [feat_level[-1].unsqueeze(0) for feat_level in predictor._features["high_res_feats"]]
            low_res_masks, prd_scores, _, _ = predictor.model.sam_mask_decoder(image_embeddings=predictor._features["image_embed"][-1].unsqueeze(0),image_pe=predictor.model.sam_prompt_encoder.get_dense_pe(),sparse_prompt_embeddings=sparse_embeddings,dense_prompt_embeddings=dense_embeddings,multimask_output=True,repeat_image=batched_mode,high_res_features=high_res_features,)
            prd_masks = predictor._transforms.postprocess_masks(low_res_masks, predictor._orig_hw[-1])# Upscale the masks to the original image resolution

            # Segmentaion Loss caclulation

            gt_mask = torch.tensor(mask.astype(np.float32)).cuda()
            prd_mask = torch.sigmoid(prd_masks[:, 0])# Turn logit map to probability map
            seg_loss = (-gt_mask * torch.log(prd_mask + 0.00001) - (1 - gt_mask) * torch.log((1 - prd_mask) + 0.00001)).mean() # cross entropy loss

            # Score loss calculation (intersection over union) IOU

            inter = (gt_mask * (prd_mask > 0.5)).sum(1).sum(1)
            iou = inter / (gt_mask.sum(1).sum(1) + (prd_mask > 0.5).sum(1).sum(1) - inter)
            score_loss = torch.abs(prd_scores[:, 0] - iou).mean()
            loss=seg_loss+score_loss*0.05  # mix losses

            # apply back propogation

            predictor.model.zero_grad() # empty gradient
            scaler.scale(loss).backward()  # Backpropogate
            scaler.step(optimizer)
            scaler.update() # Mix precision

            if itr%1000==0: torch.save(predictor.model.state_dict(), "model_t.torch");print("save model")

            # Display results

            if itr==0: mean_iou=0
            mean_iou = mean_iou * 0.99 + 0.01 * np.mean(iou.cpu().detach().numpy())
            print("step)",itr, "Accuracy(IOU)=",mean_iou)
# Out:
# save model
# step) 0 Accuracy(IOU)= 0.005588364
# step) 1 Accuracy(IOU)= 0.010495117
# step) 2 Accuracy(IOU)= 0.011233896
# step) 3 Accuracy(IOU)= 0.0139609575
# step) 4 Accuracy(IOU)= 0.01956644
# step) 5 Accuracy(IOU)= 0.0219254
# step) 6 Accuracy(IOU)= 0.028955787
# step) 7 Accuracy(IOU)= 0.031131096
# step) 8 Accuracy(IOU)= 0.033197332
# step) 9 Accuracy(IOU)= 0.03431467
# step) 10 Accuracy(IOU)= 0.03734589
# step) 11 Accuracy(IOU)= 0.038586706
# step) 12 Accuracy(IOU)= 0.039886158
# step) 13 Accuracy(IOU)= 0.04374494
# step) 14 Accuracy(IOU)= 0.04507479
# step) 15 Accuracy(IOU)= 0.048743837
# step) 16 Accuracy(IOU)= 0.051432814
# step) 17 Accuracy(IOU)= 0.052245002
# step) 18 Accuracy(IOU)= 0.05278453
# step) 19 Accuracy(IOU)= 0.05731366
# step) 20 Accuracy(IOU)= 0.05773709
# step) 21 Accuracy(IOU)= 0.0601292
# step) 22 Accuracy(IOU)= 0.06378638
# step) 23 Accuracy(IOU)= 0.06702466
# step) 24 Accuracy(IOU)= 0.06940178
# step) 25 Accuracy(IOU)= 0.069734454
# step) 26 Accuracy(IOU)= 0.07258125
# step) 27 Accuracy(IOU)= 0.07372106
# step) 28 Accuracy(IOU)= 0.0777
# step) 29 Accuracy(IOU)= 0.078647524
# step) 30 Accuracy(IOU)= 0.0813946
# step) 31 Accuracy(IOU)= 0.08188163
# step) 32 Accuracy(IOU)= 0.08475212
# step) 33 Accuracy(IOU)= 0.08682584
# step) 34 Accuracy(IOU)= 0.08912126
# step) 35 Accuracy(IOU)= 0.09316642
# step) 36 Accuracy(IOU)= 0.09407349
# step) 37 Accuracy(IOU)= 0.09843719
# step) 38 Accuracy(IOU)= 0.09868988
# step) 39 Accuracy(IOU)= 0.09826487
# step) 40 Accuracy(IOU)= 0.09902034
# step) 41 Accuracy(IOU)= 0.10022794
# step) 42 Accuracy(IOU)= 0.10027125
# step) 43 Accuracy(IOU)= 0.10050077
# step) 44 Accuracy(IOU)= 0.101305336
# step) 45 Accuracy(IOU)= 0.10412912
# step) 46 Accuracy(IOU)= 0.10648234
# step) 47 Accuracy(IOU)= 0.1081807
# step) 48 Accuracy(IOU)= 0.10971555
# step) 49 Accuracy(IOU)= 0.11412074
# step) 50 Accuracy(IOU)= 0.1151833
# step) 51 Accuracy(IOU)= 0.1164086
# step) 52 Accuracy(IOU)= 0.1186674
# step) 53 Accuracy(IOU)= 0.12035951
# step) 54 Accuracy(IOU)= 0.12185117
# step) 55 Accuracy(IOU)= 0.12337131
# step) 56 Accuracy(IOU)= 0.12416944
# step) 57 Accuracy(IOU)= 0.12394345
# step) 58 Accuracy(IOU)= 0.124777675
# step) 59 Accuracy(IOU)= 0.1256903
# step) 60 Accuracy(IOU)= 0.1273373
# step) 61 Accuracy(IOU)= 0.12774304
# step) 62 Accuracy(IOU)= 0.12948202
# step) 63 Accuracy(IOU)= 0.13214988
# step) 64 Accuracy(IOU)= 0.13387588
# step) 65 Accuracy(IOU)= 0.1352584
# step) 66 Accuracy(IOU)= 0.13595264
# step) 67 Accuracy(IOU)= 0.13770486
# step) 68 Accuracy(IOU)= 0.13894883
# step) 69 Accuracy(IOU)= 0.14222851
# step) 70 Accuracy(IOU)= 0.14515102
# step) 71 Accuracy(IOU)= 0.14506198
# step) 72 Accuracy(IOU)= 0.14489499
# step) 73 Accuracy(IOU)= 0.14401649
# step) 74 Accuracy(IOU)= 0.14563961
# step) 75 Accuracy(IOU)= 0.14556803
# step) 76 Accuracy(IOU)= 0.14563043
# step) 77 Accuracy(IOU)= 0.14746995
# step) 78 Accuracy(IOU)= 0.14762285
# step) 79 Accuracy(IOU)= 0.15060952
# step) 80 Accuracy(IOU)= 0.15387887
# step) 81 Accuracy(IOU)= 0.15527362
# step) 82 Accuracy(IOU)= 0.15899694
# step) 83 Accuracy(IOU)= 0.16623421
# step) 84 Accuracy(IOU)= 0.16593607
# step) 85 Accuracy(IOU)= 0.17244565
# step) 86 Accuracy(IOU)= 0.1741765
# step) 87 Accuracy(IOU)= 0.17366888
# step) 88 Accuracy(IOU)= 0.17378531
# step) 89 Accuracy(IOU)= 0.17294453
# step) 90 Accuracy(IOU)= 0.17149867
# step) 91 Accuracy(IOU)= 0.17140013
# step) 92 Accuracy(IOU)= 0.1717374
# step) 93 Accuracy(IOU)= 0.17231236
# step) 94 Accuracy(IOU)= 0.173477
# step) 95 Accuracy(IOU)= 0.17388333
# step) 96 Accuracy(IOU)= 0.1762765
# step) 97 Accuracy(IOU)= 0.17516468
# step) 98 Accuracy(IOU)= 0.17693965
# step) 99 Accuracy(IOU)= 0.1773693
# step) 100 Accuracy(IOU)= 0.18523698
# step) 101 Accuracy(IOU)= 0.18582994
# step) 102 Accuracy(IOU)= 0.19088629
# step) 103 Accuracy(IOU)= 0.19090305
# step) 104 Accuracy(IOU)= 0.19260985
# step) 105 Accuracy(IOU)= 0.19173467
# step) 106 Accuracy(IOU)= 0.19046152
# step) 107 Accuracy(IOU)= 0.19278866
# step) 108 Accuracy(IOU)= 0.19450149
# step) 109 Accuracy(IOU)= 0.19526623
# step) 110 Accuracy(IOU)= 0.19754589
# step) 111 Accuracy(IOU)= 0.1974133
# step) 112 Accuracy(IOU)= 0.1968984
# step) 113 Accuracy(IOU)= 0.19756547
# step) 114 Accuracy(IOU)= 0.19857025
# step) 115 Accuracy(IOU)= 0.19783883
# step) 116 Accuracy(IOU)= 0.19858937
# step) 117 Accuracy(IOU)= 0.20055765
# step) 118 Accuracy(IOU)= 0.20305173
# step) 119 Accuracy(IOU)= 0.20158496
# step) 120 Accuracy(IOU)= 0.20344391
# step) 121 Accuracy(IOU)= 0.20256762
# step) 122 Accuracy(IOU)= 0.2016956
# step) 123 Accuracy(IOU)= 0.2028276
# step) 124 Accuracy(IOU)= 0.20286164
# step) 125 Accuracy(IOU)= 0.20271209
# step) 126 Accuracy(IOU)= 0.20382324
# step) 127 Accuracy(IOU)= 0.20331179
# step) 128 Accuracy(IOU)= 0.20294617
# step) 129 Accuracy(IOU)= 0.20292245
# step) 130 Accuracy(IOU)= 0.20283958
# step) 131 Accuracy(IOU)= 0.20218946
# step) 132 Accuracy(IOU)= 0.20258157
# step) 133 Accuracy(IOU)= 0.20197985
# step) 134 Accuracy(IOU)= 0.20542732
# step) 135 Accuracy(IOU)= 0.20613976
# step) 136 Accuracy(IOU)= 0.2068559
# step) 137 Accuracy(IOU)= 0.2068748
# step) 138 Accuracy(IOU)= 0.20727691
# step) 139 Accuracy(IOU)= 0.20552878
# step) 140 Accuracy(IOU)= 0.20742509
# step) 141 Accuracy(IOU)= 0.20604089
# step) 142 Accuracy(IOU)= 0.20573387
# step) 143 Accuracy(IOU)= 0.20631967
# step) 144 Accuracy(IOU)= 0.2075357
# step) 145 Accuracy(IOU)= 0.20728567
# step) 146 Accuracy(IOU)= 0.20722546
# step) 147 Accuracy(IOU)= 0.20742522
# step) 148 Accuracy(IOU)= 0.20785184
# step) 149 Accuracy(IOU)= 0.21078077
# step) 150 Accuracy(IOU)= 0.21056546
# step) 151 Accuracy(IOU)= 0.2119687
# step) 152 Accuracy(IOU)= 0.21208866
# step) 153 Accuracy(IOU)= 0.21268766
# step) 154 Accuracy(IOU)= 0.21211013
# step) 155 Accuracy(IOU)= 0.21520081
# step) 156 Accuracy(IOU)= 0.21531267
# step) 157 Accuracy(IOU)= 0.21510288
# step) 158 Accuracy(IOU)= 0.21453787
# step) 159 Accuracy(IOU)= 0.21299513
# step) 160 Accuracy(IOU)= 0.21390624
# step) 161 Accuracy(IOU)= 0.21447003
# step) 162 Accuracy(IOU)= 0.21350883
# step) 163 Accuracy(IOU)= 0.21333638
# step) 164 Accuracy(IOU)= 0.21304545
# step) 165 Accuracy(IOU)= 0.21271218
# step) 166 Accuracy(IOU)= 0.21162234
# step) 167 Accuracy(IOU)= 0.21248338
# step) 168 Accuracy(IOU)= 0.21333505
# step) 169 Accuracy(IOU)= 0.21334197
# step) 170 Accuracy(IOU)= 0.21317945
# step) 171 Accuracy(IOU)= 0.21461067
# step) 172 Accuracy(IOU)= 0.21441154
# step) 173 Accuracy(IOU)= 0.21396996
# step) 174 Accuracy(IOU)= 0.21562578
# step) 175 Accuracy(IOU)= 0.21633084
# step) 176 Accuracy(IOU)= 0.21562761
# step) 177 Accuracy(IOU)= 0.21527965
# step) 178 Accuracy(IOU)= 0.21486016
# step) 179 Accuracy(IOU)= 0.21531671
# step) 180 Accuracy(IOU)= 0.21499175
# step) 181 Accuracy(IOU)= 0.21442755
# step) 182 Accuracy(IOU)= 0.21720302
# step) 183 Accuracy(IOU)= 0.21702726
# step) 184 Accuracy(IOU)= 0.21765192
# step) 185 Accuracy(IOU)= 0.21701972
# step) 186 Accuracy(IOU)= 0.21592548
# step) 187 Accuracy(IOU)= 0.21544026
# step) 188 Accuracy(IOU)= 0.21554549
# step) 189 Accuracy(IOU)= 0.21656346
# step) 190 Accuracy(IOU)= 0.21836771
# step) 191 Accuracy(IOU)= 0.2187992
# step) 192 Accuracy(IOU)= 0.21995102
# step) 193 Accuracy(IOU)= 0.21871191
# step) 194 Accuracy(IOU)= 0.21793866
# step) 195 Accuracy(IOU)= 0.21682796
# step) 196 Accuracy(IOU)= 0.21838106
# step) 197 Accuracy(IOU)= 0.22019394
# step) 198 Accuracy(IOU)= 0.21898325
# step) 199 Accuracy(IOU)= 0.22174047
# step) 200 Accuracy(IOU)= 0.22114685
# step) 201 Accuracy(IOU)= 0.22103387
# step) 202 Accuracy(IOU)= 0.22217052
# step) 203 Accuracy(IOU)= 0.22056955
# step) 204 Accuracy(IOU)= 0.22293809
# step) 205 Accuracy(IOU)= 0.22255449
# step) 206 Accuracy(IOU)= 0.22389317
# step) 207 Accuracy(IOU)= 0.22601968
# step) 208 Accuracy(IOU)= 0.22495243
# step) 209 Accuracy(IOU)= 0.22389948
# step) 210 Accuracy(IOU)= 0.22310372
# step) 211 Accuracy(IOU)= 0.22139816
# step) 212 Accuracy(IOU)= 0.2218785
# step) 213 Accuracy(IOU)= 0.22320275
# step) 214 Accuracy(IOU)= 0.22319758
# step) 215 Accuracy(IOU)= 0.22352226
# step) 216 Accuracy(IOU)= 0.22401331
# step) 217 Accuracy(IOU)= 0.2248702
# step) 218 Accuracy(IOU)= 0.22567381
# step) 219 Accuracy(IOU)= 0.22691514
# step) 220 Accuracy(IOU)= 0.22499752
# step) 221 Accuracy(IOU)= 0.22353765
# step) 222 Accuracy(IOU)= 0.22602496
# step) 223 Accuracy(IOU)= 0.22537115
# step) 224 Accuracy(IOU)= 0.22563052
# step) 225 Accuracy(IOU)= 0.22549874
# step) 226 Accuracy(IOU)= 0.22491266
# step) 227 Accuracy(IOU)= 0.22469674
# step) 228 Accuracy(IOU)= 0.2262205
# step) 229 Accuracy(IOU)= 0.22757734
# step) 230 Accuracy(IOU)= 0.22569773
# step) 231 Accuracy(IOU)= 0.22895096
# step) 232 Accuracy(IOU)= 0.23087786
# step) 233 Accuracy(IOU)= 0.23135619
# step) 234 Accuracy(IOU)= 0.23199493
# step) 235 Accuracy(IOU)= 0.23405245
# step) 236 Accuracy(IOU)= 0.23362757
# step) 237 Accuracy(IOU)= 0.23385055
# step) 238 Accuracy(IOU)= 0.23259307
# step) 239 Accuracy(IOU)= 0.2329663
# step) 240 Accuracy(IOU)= 0.23316692
# step) 241 Accuracy(IOU)= 0.2345076
# step) 242 Accuracy(IOU)= 0.2338514
# step) 243 Accuracy(IOU)= 0.23321809
# step) 244 Accuracy(IOU)= 0.23209438
# step) 245 Accuracy(IOU)= 0.23378672
# step) 246 Accuracy(IOU)= 0.23442493
# step) 247 Accuracy(IOU)= 0.23677759
# step) 248 Accuracy(IOU)= 0.23529458
# step) 249 Accuracy(IOU)= 0.23392832
# step) 250 Accuracy(IOU)= 0.23337549
# step) 251 Accuracy(IOU)= 0.23487906
# step) 252 Accuracy(IOU)= 0.23437797
# step) 253 Accuracy(IOU)= 0.23328546
# step) 254 Accuracy(IOU)= 0.23352662
# step) 255 Accuracy(IOU)= 0.23341815
# step) 256 Accuracy(IOU)= 0.23570234
# step) 257 Accuracy(IOU)= 0.2379851
# step) 258 Accuracy(IOU)= 0.24049297
# step) 259 Accuracy(IOU)= 0.24037977
# step) 260 Accuracy(IOU)= 0.24091356
# step) 261 Accuracy(IOU)= 0.24280615
# step) 262 Accuracy(IOU)= 0.2431148
# step) 264 Accuracy(IOU)= 0.241089
# step) 265 Accuracy(IOU)= 0.24120793
# step) 266 Accuracy(IOU)= 0.23951173
# step) 267 Accuracy(IOU)= 0.23743963
# step) 268 Accuracy(IOU)= 0.23854697
# step) 269 Accuracy(IOU)= 0.23897144
# step) 270 Accuracy(IOU)= 0.24121378
# step) 271 Accuracy(IOU)= 0.24258897
# step) 272 Accuracy(IOU)= 0.24293919
# step) 273 Accuracy(IOU)= 0.24285994
# step) 274 Accuracy(IOU)= 0.24318203
# step) 275 Accuracy(IOU)= 0.24253684
# step) 276 Accuracy(IOU)= 0.24116473
# step) 277 Accuracy(IOU)= 0.24165094
# step) 278 Accuracy(IOU)= 0.24038437
# step) 279 Accuracy(IOU)= 0.23908073
# step) 280 Accuracy(IOU)= 0.2393255
# step) 281 Accuracy(IOU)= 0.23779456
# step) 282 Accuracy(IOU)= 0.24066496
# step) 283 Accuracy(IOU)= 0.24115486
# step) 284 Accuracy(IOU)= 0.24083461
# step) 285 Accuracy(IOU)= 0.24301688
# step) 286 Accuracy(IOU)= 0.24267817
# step) 287 Accuracy(IOU)= 0.24366014
# step) 288 Accuracy(IOU)= 0.24568835
# step) 289 Accuracy(IOU)= 0.2494483
# step) 290 Accuracy(IOU)= 0.25031233
# step) 291 Accuracy(IOU)= 0.24975942
# step) 292 Accuracy(IOU)= 0.24935217
# step) 293 Accuracy(IOU)= 0.24809635
# step) 294 Accuracy(IOU)= 0.24937887
# step) 295 Accuracy(IOU)= 0.24774902
# step) 296 Accuracy(IOU)= 0.24875991
# step) 297 Accuracy(IOU)= 0.24928607
# step) 298 Accuracy(IOU)= 0.24806568
# step) 299 Accuracy(IOU)= 0.24580221
# step) 300 Accuracy(IOU)= 0.24576274
# step) 301 Accuracy(IOU)= 0.24483502
# step) 302 Accuracy(IOU)= 0.247036
# step) 303 Accuracy(IOU)= 0.24620739
# step) 304 Accuracy(IOU)= 0.24577974
# step) 305 Accuracy(IOU)= 0.2477648
# step) 306 Accuracy(IOU)= 0.24921876
# step) 307 Accuracy(IOU)= 0.24781819
# step) 308 Accuracy(IOU)= 0.24724613
# step) 309 Accuracy(IOU)= 0.24667913
# step) 310 Accuracy(IOU)= 0.2462564
# step) 311 Accuracy(IOU)= 0.24628337
# step) 312 Accuracy(IOU)= 0.24505883
# step) 313 Accuracy(IOU)= 0.24735834
# step) 314 Accuracy(IOU)= 0.24740328
# step) 315 Accuracy(IOU)= 0.24671225
# step) 316 Accuracy(IOU)= 0.24604635
# step) 317 Accuracy(IOU)= 0.24495879
# step) 318 Accuracy(IOU)= 0.24489234
# step) 319 Accuracy(IOU)= 0.24372046
# step) 320 Accuracy(IOU)= 0.24544503
# step) 321 Accuracy(IOU)= 0.2445663
# step) 322 Accuracy(IOU)= 0.24435015
# step) 323 Accuracy(IOU)= 0.24358916
# step) 324 Accuracy(IOU)= 0.250965
# step) 325 Accuracy(IOU)= 0.2506654
# step) 326 Accuracy(IOU)= 0.25196183
# step) 327 Accuracy(IOU)= 0.25377735
# step) 328 Accuracy(IOU)= 0.25246933
# step) 329 Accuracy(IOU)= 0.25080657
# step) 330 Accuracy(IOU)= 0.2501553
# step) 331 Accuracy(IOU)= 0.25397608
# step) 332 Accuracy(IOU)= 0.2550932
# step) 333 Accuracy(IOU)= 0.25491095
# step) 334 Accuracy(IOU)= 0.2537846
# step) 335 Accuracy(IOU)= 0.25562084
# step) 336 Accuracy(IOU)= 0.25588366
# step) 337 Accuracy(IOU)= 0.257161
# step) 338 Accuracy(IOU)= 0.2617926
# step) 339 Accuracy(IOU)= 0.26090077
# step) 340 Accuracy(IOU)= 0.2603025
# step) 341 Accuracy(IOU)= 0.2594796
# step) 342 Accuracy(IOU)= 0.26136285
# step) 343 Accuracy(IOU)= 0.26080903
# step) 344 Accuracy(IOU)= 0.2587377
# step) 345 Accuracy(IOU)= 0.25815138
# step) 346 Accuracy(IOU)= 0.25780255
# step) 347 Accuracy(IOU)= 0.25569516
# step) 348 Accuracy(IOU)= 0.2537716
# step) 349 Accuracy(IOU)= 0.25446865
# step) 350 Accuracy(IOU)= 0.25580248
# step) 351 Accuracy(IOU)= 0.2580372
# step) 352 Accuracy(IOU)= 0.25756732
# step) 353 Accuracy(IOU)= 0.2638023
# step) 354 Accuracy(IOU)= 0.2629109
# step) 355 Accuracy(IOU)= 0.26070878
# step) 356 Accuracy(IOU)= 0.25953898
# step) 357 Accuracy(IOU)= 0.25955427
# step) 358 Accuracy(IOU)= 0.26028895
# step) 359 Accuracy(IOU)= 0.26230767
# step) 360 Accuracy(IOU)= 0.2651798
# step) 361 Accuracy(IOU)= 0.26339498
# step) 362 Accuracy(IOU)= 0.2636403
# step) 363 Accuracy(IOU)= 0.26180345
# step) 364 Accuracy(IOU)= 0.26050046
# step) 365 Accuracy(IOU)= 0.2621078
# step) 366 Accuracy(IOU)= 0.26195058
# step) 367 Accuracy(IOU)= 0.26280957
# step) 368 Accuracy(IOU)= 0.26514712
# step) 369 Accuracy(IOU)= 0.26712534
# step) 370 Accuracy(IOU)= 0.26454848
# step) 371 Accuracy(IOU)= 0.263899
# step) 372 Accuracy(IOU)= 0.26437327
# step) 373 Accuracy(IOU)= 0.26684415
# step) 374 Accuracy(IOU)= 0.26578835
# step) 375 Accuracy(IOU)= 0.26447567
# step) 376 Accuracy(IOU)= 0.26356038
# step) 377 Accuracy(IOU)= 0.26591405
# step) 378 Accuracy(IOU)= 0.2651161
# step) 379 Accuracy(IOU)= 0.2659463
# step) 380 Accuracy(IOU)= 0.2654626
# step) 381 Accuracy(IOU)= 0.26431555
# step) 382 Accuracy(IOU)= 0.26472253
# step) 383 Accuracy(IOU)= 0.26527336
# step) 384 Accuracy(IOU)= 0.26629707
# step) 385 Accuracy(IOU)= 0.2665866
# step) 386 Accuracy(IOU)= 0.2646145
# step) 387 Accuracy(IOU)= 0.2646757
# step) 388 Accuracy(IOU)= 0.26568037
# step) 389 Accuracy(IOU)= 0.26464033
# step) 390 Accuracy(IOU)= 0.2634464
# step) 391 Accuracy(IOU)= 0.26399013
# step) 392 Accuracy(IOU)= 0.26354846
# step) 393 Accuracy(IOU)= 0.26270577
# step) 394 Accuracy(IOU)= 0.2610872
# step) 395 Accuracy(IOU)= 0.26079068
# step) 396 Accuracy(IOU)= 0.26202762
# step) 397 Accuracy(IOU)= 0.26363125
# step) 398 Accuracy(IOU)= 0.2641395
# step) 399 Accuracy(IOU)= 0.2643392
# step) 400 Accuracy(IOU)= 0.26294026
# step) 401 Accuracy(IOU)= 0.26388225
# step) 402 Accuracy(IOU)= 0.26237488
# step) 403 Accuracy(IOU)= 0.26017147
# step) 404 Accuracy(IOU)= 0.25828752
# step) 405 Accuracy(IOU)= 0.25817326
# step) 406 Accuracy(IOU)= 0.25670213
# step) 407 Accuracy(IOU)= 0.2576906
# step) 408 Accuracy(IOU)= 0.25906798
# step) 409 Accuracy(IOU)= 0.25923312
# step) 410 Accuracy(IOU)= 0.25815856
# step) 411 Accuracy(IOU)= 0.25833866
# step) 412 Accuracy(IOU)= 0.25959322
# step) 413 Accuracy(IOU)= 0.26060593
# step) 414 Accuracy(IOU)= 0.25840566
# step) 415 Accuracy(IOU)= 0.2588598
# step) 416 Accuracy(IOU)= 0.2596268
# step) 417 Accuracy(IOU)= 0.25923237
# step) 418 Accuracy(IOU)= 0.2609927
# step) 419 Accuracy(IOU)= 0.25920108
# step) 420 Accuracy(IOU)= 0.2584769
# step) 421 Accuracy(IOU)= 0.25767538
# step) 422 Accuracy(IOU)= 0.2579633
# step) 423 Accuracy(IOU)= 0.25852066
# step) 424 Accuracy(IOU)= 0.26055095
# step) 425 Accuracy(IOU)= 0.26057187
# step) 426 Accuracy(IOU)= 0.260099
# step) 427 Accuracy(IOU)= 0.2583085
# step) 428 Accuracy(IOU)= 0.25863197
# step) 429 Accuracy(IOU)= 0.26206884
# step) 430 Accuracy(IOU)= 0.2618659
# step) 431 Accuracy(IOU)= 0.2593051
# step) 432 Accuracy(IOU)= 0.26034382
# step) 433 Accuracy(IOU)= 0.260185
# step) 434 Accuracy(IOU)= 0.25868908
# step) 435 Accuracy(IOU)= 0.2597699
# step) 436 Accuracy(IOU)= 0.261331
# step) 437 Accuracy(IOU)= 0.26229355
# step) 438 Accuracy(IOU)= 0.2607663
# step) 439 Accuracy(IOU)= 0.26092756
# step) 440 Accuracy(IOU)= 0.26050597
# step) 441 Accuracy(IOU)= 0.26077113
# step) 442 Accuracy(IOU)= 0.25975767
# step) 443 Accuracy(IOU)= 0.26075622
# step) 444 Accuracy(IOU)= 0.26807955
# step) 445 Accuracy(IOU)= 0.2687414
# step) 446 Accuracy(IOU)= 0.26937816
# step) 447 Accuracy(IOU)= 0.2689385
# step) 448 Accuracy(IOU)= 0.27032083
# step) 449 Accuracy(IOU)= 0.27291167
# step) 450 Accuracy(IOU)= 0.2703289
# step) 451 Accuracy(IOU)= 0.27085483
# step) 452 Accuracy(IOU)= 0.27217296
# step) 453 Accuracy(IOU)= 0.27264616
# step) 454 Accuracy(IOU)= 0.27353093
# step) 455 Accuracy(IOU)= 0.2730481
# step) 456 Accuracy(IOU)= 0.27424634
# step) 457 Accuracy(IOU)= 0.27241203
# step) 458 Accuracy(IOU)= 0.27169454
# step) 459 Accuracy(IOU)= 0.27210158
# step) 461 Accuracy(IOU)= 0.2708614
# step) 462 Accuracy(IOU)= 0.27112612
# step) 463 Accuracy(IOU)= 0.270003
# step) 464 Accuracy(IOU)= 0.26748788
# step) 465 Accuracy(IOU)= 0.26570928
# step) 466 Accuracy(IOU)= 0.26945478
# step) 467 Accuracy(IOU)= 0.26796058
# step) 468 Accuracy(IOU)= 0.26602098
# step) 469 Accuracy(IOU)= 0.26393256
# step) 470 Accuracy(IOU)= 0.26312673
# step) 471 Accuracy(IOU)= 0.26318166
# step) 472 Accuracy(IOU)= 0.26241714
# step) 473 Accuracy(IOU)= 0.261548
# step) 474 Accuracy(IOU)= 0.26404148
# step) 475 Accuracy(IOU)= 0.26570547
# step) 476 Accuracy(IOU)= 0.26575547
# step) 477 Accuracy(IOU)= 0.2641145
# step) 478 Accuracy(IOU)= 0.26316926
# step) 479 Accuracy(IOU)= 0.2612232
# step) 480 Accuracy(IOU)= 0.26003057
# step) 481 Accuracy(IOU)= 0.26103354
# step) 482 Accuracy(IOU)= 0.2591355
# step) 483 Accuracy(IOU)= 0.26501948
# step) 484 Accuracy(IOU)= 0.26536626
# step) 485 Accuracy(IOU)= 0.26675355
# step) 486 Accuracy(IOU)= 0.26456168
# step) 487 Accuracy(IOU)= 0.26373705
# step) 488 Accuracy(IOU)= 0.2621368
# step) 489 Accuracy(IOU)= 0.26366797
# step) 490 Accuracy(IOU)= 0.26191387
# step) 491 Accuracy(IOU)= 0.26025414
# step) 492 Accuracy(IOU)= 0.26239198
# step) 493 Accuracy(IOU)= 0.26239613
# step) 494 Accuracy(IOU)= 0.26268256
# step) 495 Accuracy(IOU)= 0.26318005
# step) 496 Accuracy(IOU)= 0.2613985
# step) 497 Accuracy(IOU)= 0.2602011
# step) 498 Accuracy(IOU)= 0.25838965
# step) 499 Accuracy(IOU)= 0.25737986
# step) 500 Accuracy(IOU)= 0.25755146
# step) 501 Accuracy(IOU)= 0.26163325
# step) 502 Accuracy(IOU)= 0.25924578
# step) 503 Accuracy(IOU)= 0.25776556
# step) 504 Accuracy(IOU)= 0.25717285
# step) 505 Accuracy(IOU)= 0.25845236
# step) 506 Accuracy(IOU)= 0.25864357
# step) 507 Accuracy(IOU)= 0.2596322
# step) 508 Accuracy(IOU)= 0.26061326
# step) 509 Accuracy(IOU)= 0.2596176
# step) 510 Accuracy(IOU)= 0.26047325
# step) 511 Accuracy(IOU)= 0.25913364
# step) 512 Accuracy(IOU)= 0.25736803
# step) 513 Accuracy(IOU)= 0.25572255
# step) 514 Accuracy(IOU)= 0.25601554
# step) 515 Accuracy(IOU)= 0.255985
# step) 516 Accuracy(IOU)= 0.2550238
# step) 518 Accuracy(IOU)= 0.25451216
# step) 519 Accuracy(IOU)= 0.25879318
# step) 520 Accuracy(IOU)= 0.2592841
# step) 521 Accuracy(IOU)= 0.26208088
# step) 522 Accuracy(IOU)= 0.25980917
# step) 523 Accuracy(IOU)= 0.25940973
# step) 524 Accuracy(IOU)= 0.25825548
# step) 525 Accuracy(IOU)= 0.2567626
# step) 526 Accuracy(IOU)= 0.2567976
# step) 527 Accuracy(IOU)= 0.25894696
# step) 528 Accuracy(IOU)= 0.25905535
# step) 529 Accuracy(IOU)= 0.25790116
# step) 530 Accuracy(IOU)= 0.25930113
# step) 531 Accuracy(IOU)= 0.25842604
# step) 532 Accuracy(IOU)= 0.2573344
# step) 533 Accuracy(IOU)= 0.25858653
# step) 534 Accuracy(IOU)= 0.25735122
# step) 535 Accuracy(IOU)= 0.2582055
# step) 536 Accuracy(IOU)= 0.255775
# step) 537 Accuracy(IOU)= 0.25487405
# step) 538 Accuracy(IOU)= 0.25397113
# step) 539 Accuracy(IOU)= 0.2547398
# step) 540 Accuracy(IOU)= 0.25397125
# step) 541 Accuracy(IOU)= 0.25256073
# step) 542 Accuracy(IOU)= 0.25342667
# step) 543 Accuracy(IOU)= 0.25356334
# step) 544 Accuracy(IOU)= 0.2515911
# step) 545 Accuracy(IOU)= 0.25019163
# step) 546 Accuracy(IOU)= 0.25230196
# step) 547 Accuracy(IOU)= 0.25139898
# step) 548 Accuracy(IOU)= 0.25104076
# step) 549 Accuracy(IOU)= 0.25262082
# step) 550 Accuracy(IOU)= 0.2543442
# step) 551 Accuracy(IOU)= 0.25302687
# step) 552 Accuracy(IOU)= 0.25308302
# step) 553 Accuracy(IOU)= 0.2600226
# step) 554 Accuracy(IOU)= 0.26325637
# step) 555 Accuracy(IOU)= 0.26328728
# step) 556 Accuracy(IOU)= 0.26214802
# step) 557 Accuracy(IOU)= 0.2631275
# step) 558 Accuracy(IOU)= 0.2627624
# step) 559 Accuracy(IOU)= 0.26266268
# step) 560 Accuracy(IOU)= 0.26433456
# step) 561 Accuracy(IOU)= 0.2657643
# step) 562 Accuracy(IOU)= 0.26474902
# step) 563 Accuracy(IOU)= 0.2656012
# step) 564 Accuracy(IOU)= 0.26565373
# step) 565 Accuracy(IOU)= 0.26365975
# step) 566 Accuracy(IOU)= 0.26411682
# step) 567 Accuracy(IOU)= 0.26480094
# step) 568 Accuracy(IOU)= 0.26349896
# step) 569 Accuracy(IOU)= 0.26297778
# step) 570 Accuracy(IOU)= 0.2608178
# step) 571 Accuracy(IOU)= 0.25963828
# step) 572 Accuracy(IOU)= 0.25791615
# step) 573 Accuracy(IOU)= 0.25815538
# step) 574 Accuracy(IOU)= 0.25981537
# step) 575 Accuracy(IOU)= 0.2604402
# step) 576 Accuracy(IOU)= 0.26630244
# step) 577 Accuracy(IOU)= 0.26698068
# step) 578 Accuracy(IOU)= 0.26653033
# step) 579 Accuracy(IOU)= 0.2692688
# step) 580 Accuracy(IOU)= 0.2688783
# step) 581 Accuracy(IOU)= 0.2674739
# step) 582 Accuracy(IOU)= 0.26996177
# step) 583 Accuracy(IOU)= 0.26957175
# step) 584 Accuracy(IOU)= 0.26951277
# step) 585 Accuracy(IOU)= 0.270855
# step) 586 Accuracy(IOU)= 0.2713774
# step) 587 Accuracy(IOU)= 0.2716944
# step) 588 Accuracy(IOU)= 0.27061215
# step) 589 Accuracy(IOU)= 0.27265334
# step) 590 Accuracy(IOU)= 0.2716015
# step) 591 Accuracy(IOU)= 0.270794
# step) 592 Accuracy(IOU)= 0.27190676
# step) 593 Accuracy(IOU)= 0.27179018
# step) 594 Accuracy(IOU)= 0.26965192
# step) 595 Accuracy(IOU)= 0.2676884
# step) 596 Accuracy(IOU)= 0.26634607
# step) 597 Accuracy(IOU)= 0.26475775
# step) 598 Accuracy(IOU)= 0.2658586
# step) 599 Accuracy(IOU)= 0.26514566
# step) 600 Accuracy(IOU)= 0.26617774
# step) 601 Accuracy(IOU)= 0.26988554
# step) 602 Accuracy(IOU)= 0.27057335
# step) 603 Accuracy(IOU)= 0.26993823
# step) 604 Accuracy(IOU)= 0.27066687
# step) 605 Accuracy(IOU)= 0.27163014
# step) 606 Accuracy(IOU)= 0.2724056
# step) 607 Accuracy(IOU)= 0.27393678
# step) 608 Accuracy(IOU)= 0.2730809
# step) 609 Accuracy(IOU)= 0.2731112
# step) 610 Accuracy(IOU)= 0.2764073
# step) 611 Accuracy(IOU)= 0.2797109
# step) 612 Accuracy(IOU)= 0.27849522
# step) 613 Accuracy(IOU)= 0.27613842
# step) 614 Accuracy(IOU)= 0.27540517
# step) 615 Accuracy(IOU)= 0.27576482
# step) 616 Accuracy(IOU)= 0.27611697
# step) 617 Accuracy(IOU)= 0.27461502
# step) 618 Accuracy(IOU)= 0.27532697
# step) 619 Accuracy(IOU)= 0.2746812
# step) 620 Accuracy(IOU)= 0.27438626
# step) 621 Accuracy(IOU)= 0.27192152
# step) 622 Accuracy(IOU)= 0.26974046
# step) 623 Accuracy(IOU)= 0.2698487
# step) 624 Accuracy(IOU)= 0.26930183
# step) 625 Accuracy(IOU)= 0.27000752
# step) 626 Accuracy(IOU)= 0.2738944
# step) 627 Accuracy(IOU)= 0.2731106
# step) 628 Accuracy(IOU)= 0.2716382
# step) 629 Accuracy(IOU)= 0.27128112
# step) 630 Accuracy(IOU)= 0.271832
# step) 631 Accuracy(IOU)= 0.2734421
# step) 632 Accuracy(IOU)= 0.27208656
# step) 633 Accuracy(IOU)= 0.27062252
# step) 634 Accuracy(IOU)= 0.2691581
# step) 635 Accuracy(IOU)= 0.26912153
# step) 636 Accuracy(IOU)= 0.2702148
# step) 637 Accuracy(IOU)= 0.2685228
# step) 638 Accuracy(IOU)= 0.27258298
# step) 639 Accuracy(IOU)= 0.27014035
# step) 640 Accuracy(IOU)= 0.27153927
# step) 641 Accuracy(IOU)= 0.27232707
# step) 642 Accuracy(IOU)= 0.27329317
# step) 643 Accuracy(IOU)= 0.27414697
# step) 644 Accuracy(IOU)= 0.27442643
# step) 645 Accuracy(IOU)= 0.27372742
# step) 646 Accuracy(IOU)= 0.2750923
# step) 647 Accuracy(IOU)= 0.2757081
# step) 648 Accuracy(IOU)= 0.27404496
# step) 649 Accuracy(IOU)= 0.27223003
# step) 650 Accuracy(IOU)= 0.27164772
# step) 651 Accuracy(IOU)= 0.27163357
# step) 652 Accuracy(IOU)= 0.27017453
# step) 653 Accuracy(IOU)= 0.2699841
# step) 654 Accuracy(IOU)= 0.27245495
# step) 655 Accuracy(IOU)= 0.27344385
# step) 656 Accuracy(IOU)= 0.2740081
# step) 657 Accuracy(IOU)= 0.27314773
# step) 658 Accuracy(IOU)= 0.27356923
# step) 659 Accuracy(IOU)= 0.27247146
# step) 660 Accuracy(IOU)= 0.27282155
# step) 661 Accuracy(IOU)= 0.2709296
# step) 662 Accuracy(IOU)= 0.26838693
# step) 663 Accuracy(IOU)= 0.2676854
# step) 664 Accuracy(IOU)= 0.26705045
# step) 665 Accuracy(IOU)= 0.26628938
# step) 666 Accuracy(IOU)= 0.26478004
# step) 667 Accuracy(IOU)= 0.26463246
# step) 668 Accuracy(IOU)= 0.26406965
# step) 669 Accuracy(IOU)= 0.2649406
# step) 670 Accuracy(IOU)= 0.2643813
# step) 671 Accuracy(IOU)= 0.2619487
# step) 672 Accuracy(IOU)= 0.2626928
# step) 673 Accuracy(IOU)= 0.26691768
# step) 674 Accuracy(IOU)= 0.26772112
# step) 675 Accuracy(IOU)= 0.2694512
# step) 676 Accuracy(IOU)= 0.27061182
# step) 677 Accuracy(IOU)= 0.26881763
# step) 678 Accuracy(IOU)= 0.2697273
# step) 679 Accuracy(IOU)= 0.27079335
# step) 680 Accuracy(IOU)= 0.27498698
# step) 681 Accuracy(IOU)= 0.27639088
# step) 682 Accuracy(IOU)= 0.2769993
# step) 683 Accuracy(IOU)= 0.278052
# step) 684 Accuracy(IOU)= 0.27618912
# step) 685 Accuracy(IOU)= 0.274827
# step) 686 Accuracy(IOU)= 0.27402887
# step) 687 Accuracy(IOU)= 0.2745174
# step) 688 Accuracy(IOU)= 0.27515602
# step) 689 Accuracy(IOU)= 0.27351543
# step) 690 Accuracy(IOU)= 0.27713436
# step) 691 Accuracy(IOU)= 0.27931958
# step) 692 Accuracy(IOU)= 0.27713475
# step) 693 Accuracy(IOU)= 0.27762288
# step) 694 Accuracy(IOU)= 0.2785493
# step) 695 Accuracy(IOU)= 0.27959895
# step) 696 Accuracy(IOU)= 0.28211606
# step) 697 Accuracy(IOU)= 0.28209522
# step) 698 Accuracy(IOU)= 0.28197417
# step) 699 Accuracy(IOU)= 0.28101695
# step) 700 Accuracy(IOU)= 0.27925542
# step) 701 Accuracy(IOU)= 0.27975267
# step) 702 Accuracy(IOU)= 0.27935454
# step) 703 Accuracy(IOU)= 0.28008184
# step) 704 Accuracy(IOU)= 0.28406152
# step) 705 Accuracy(IOU)= 0.28529152
# step) 706 Accuracy(IOU)= 0.28505212
# step) 707 Accuracy(IOU)= 0.2846131
# step) 708 Accuracy(IOU)= 0.28432348
# step) 709 Accuracy(IOU)= 0.28377876
# step) 710 Accuracy(IOU)= 0.28329358
# step) 711 Accuracy(IOU)= 0.28455955
# step) 712 Accuracy(IOU)= 0.2851418
# step) 713 Accuracy(IOU)= 0.28472674
# step) 714 Accuracy(IOU)= 0.2823012
# step) 715 Accuracy(IOU)= 0.28140834
# step) 716 Accuracy(IOU)= 0.28209385
# step) 717 Accuracy(IOU)= 0.2832075
# step) 718 Accuracy(IOU)= 0.284589
# step) 719 Accuracy(IOU)= 0.28282526
# step) 720 Accuracy(IOU)= 0.28727993
# step) 721 Accuracy(IOU)= 0.29434317
# step) 722 Accuracy(IOU)= 0.2916589
# step) 723 Accuracy(IOU)= 0.29264748
# step) 724 Accuracy(IOU)= 0.2915743
# step) 725 Accuracy(IOU)= 0.28971007
# step) 726 Accuracy(IOU)= 0.28966448
# step) 727 Accuracy(IOU)= 0.28965256
# step) 728 Accuracy(IOU)= 0.2903735
# step) 729 Accuracy(IOU)= 0.290005
# step) 730 Accuracy(IOU)= 0.2921643
# step) 731 Accuracy(IOU)= 0.29298183
# step) 732 Accuracy(IOU)= 0.29284927
# step) 733 Accuracy(IOU)= 0.2929112
# step) 734 Accuracy(IOU)= 0.2938539
# step) 735 Accuracy(IOU)= 0.29440036
# step) 736 Accuracy(IOU)= 0.2946902
# step) 737 Accuracy(IOU)= 0.29501027
# step) 738 Accuracy(IOU)= 0.29411107
# step) 739 Accuracy(IOU)= 0.29472655
# step) 740 Accuracy(IOU)= 0.29321846
# step) 741 Accuracy(IOU)= 0.29603
# step) 742 Accuracy(IOU)= 0.2944818
# step) 743 Accuracy(IOU)= 0.29312629
# step) 744 Accuracy(IOU)= 0.29167658
# step) 745 Accuracy(IOU)= 0.29093936
# step) 746 Accuracy(IOU)= 0.29201475
# step) 747 Accuracy(IOU)= 0.29418114
# step) 748 Accuracy(IOU)= 0.29269484
# step) 749 Accuracy(IOU)= 0.2929812
# step) 750 Accuracy(IOU)= 0.2908539
# step) 751 Accuracy(IOU)= 0.28921646
# step) 752 Accuracy(IOU)= 0.2894995
# step) 753 Accuracy(IOU)= 0.287597
# step) 754 Accuracy(IOU)= 0.28935516
# step) 755 Accuracy(IOU)= 0.2900771
# step) 756 Accuracy(IOU)= 0.2904657
# step) 757 Accuracy(IOU)= 0.28880873
# step) 758 Accuracy(IOU)= 0.2892602
# step) 759 Accuracy(IOU)= 0.2886828
# step) 760 Accuracy(IOU)= 0.2867115
# step) 761 Accuracy(IOU)= 0.28759465
# step) 762 Accuracy(IOU)= 0.28510132
# step) 763 Accuracy(IOU)= 0.28311956
# step) 764 Accuracy(IOU)= 0.28352165
# step) 765 Accuracy(IOU)= 0.2813707
# step) 766 Accuracy(IOU)= 0.2805178
# step) 767 Accuracy(IOU)= 0.27998346
# step) 768 Accuracy(IOU)= 0.28309512
# step) 769 Accuracy(IOU)= 0.2829385
# step) 770 Accuracy(IOU)= 0.28594315
# step) 771 Accuracy(IOU)= 0.28620195
# step) 772 Accuracy(IOU)= 0.28742054
# step) 773 Accuracy(IOU)= 0.28507096
# step) 774 Accuracy(IOU)= 0.28380573
# step) 775 Accuracy(IOU)= 0.28419286
# step) 776 Accuracy(IOU)= 0.28389418
# step) 778 Accuracy(IOU)= 0.28502494
# step) 779 Accuracy(IOU)= 0.28749073
# step) 780 Accuracy(IOU)= 0.28771225
# step) 781 Accuracy(IOU)= 0.2888712
# step) 782 Accuracy(IOU)= 0.28860012
# step) 783 Accuracy(IOU)= 0.28614992
# step) 784 Accuracy(IOU)= 0.2852371
# step) 785 Accuracy(IOU)= 0.28520843
# step) 786 Accuracy(IOU)= 0.28420362
# step) 787 Accuracy(IOU)= 0.2840196
# step) 788 Accuracy(IOU)= 0.28191492
# step) 789 Accuracy(IOU)= 0.28187343
# step) 790 Accuracy(IOU)= 0.28017735
# step) 791 Accuracy(IOU)= 0.28148225
# step) 792 Accuracy(IOU)= 0.28237358
# step) 793 Accuracy(IOU)= 0.28204715
# step) 794 Accuracy(IOU)= 0.2844696
# step) 795 Accuracy(IOU)= 0.28413978
# step) 796 Accuracy(IOU)= 0.28324345
# step) 797 Accuracy(IOU)= 0.28304288
# step) 798 Accuracy(IOU)= 0.2837307
# step) 799 Accuracy(IOU)= 0.28260434
# step) 800 Accuracy(IOU)= 0.28404063
# step) 801 Accuracy(IOU)= 0.28303105
# step) 802 Accuracy(IOU)= 0.28271183
# step) 803 Accuracy(IOU)= 0.28156826
# step) 804 Accuracy(IOU)= 0.28069097
# step) 805 Accuracy(IOU)= 0.2824723
# step) 806 Accuracy(IOU)= 0.28108278
# step) 807 Accuracy(IOU)= 0.27890193
# step) 808 Accuracy(IOU)= 0.27649128
# step) 809 Accuracy(IOU)= 0.27739802
# step) 810 Accuracy(IOU)= 0.27823326
# step) 811 Accuracy(IOU)= 0.2759093
# step) 812 Accuracy(IOU)= 0.2759472
# step) 813 Accuracy(IOU)= 0.27581155
# step) 814 Accuracy(IOU)= 0.27312824
# step) 815 Accuracy(IOU)= 0.27544916
# step) 816 Accuracy(IOU)= 0.27343762
# step) 817 Accuracy(IOU)= 0.2732845
# step) 818 Accuracy(IOU)= 0.27285933
# step) 819 Accuracy(IOU)= 0.27207512
# step) 820 Accuracy(IOU)= 0.2712845
# step) 821 Accuracy(IOU)= 0.2690487
# step) 822 Accuracy(IOU)= 0.26998496
# step) 823 Accuracy(IOU)= 0.2687647
# step) 824 Accuracy(IOU)= 0.26912275
# step) 825 Accuracy(IOU)= 0.27044812
# step) 826 Accuracy(IOU)= 0.27182567
# step) 827 Accuracy(IOU)= 0.27408928
# step) 828 Accuracy(IOU)= 0.27302006
# step) 829 Accuracy(IOU)= 0.2730251
# step) 830 Accuracy(IOU)= 0.27319852
# step) 831 Accuracy(IOU)= 0.2733774
# step) 832 Accuracy(IOU)= 0.2727788
# step) 833 Accuracy(IOU)= 0.27471918
# step) 834 Accuracy(IOU)= 0.27276054
# step) 835 Accuracy(IOU)= 0.27318913
# step) 836 Accuracy(IOU)= 0.27539757
# step) 837 Accuracy(IOU)= 0.27384838
# step) 838 Accuracy(IOU)= 0.27387473
# step) 839 Accuracy(IOU)= 0.27270013
# step) 840 Accuracy(IOU)= 0.2733588
# step) 841 Accuracy(IOU)= 0.27418607
# step) 842 Accuracy(IOU)= 0.27406496
# step) 843 Accuracy(IOU)= 0.27395144
# step) 844 Accuracy(IOU)= 0.27426666
# step) 845 Accuracy(IOU)= 0.27525234
# step) 846 Accuracy(IOU)= 0.2792475
# step) 847 Accuracy(IOU)= 0.27931422
# step) 848 Accuracy(IOU)= 0.28022695
# step) 849 Accuracy(IOU)= 0.27951437
# step) 850 Accuracy(IOU)= 0.2787159
# step) 851 Accuracy(IOU)= 0.27895695
# step) 852 Accuracy(IOU)= 0.2794829
# step) 853 Accuracy(IOU)= 0.2779545
# step) 854 Accuracy(IOU)= 0.27785957
# step) 855 Accuracy(IOU)= 0.2759589
# step) 856 Accuracy(IOU)= 0.27573436
# step) 857 Accuracy(IOU)= 0.27527666
# step) 858 Accuracy(IOU)= 0.27514687
# step) 859 Accuracy(IOU)= 0.2736946
# step) 860 Accuracy(IOU)= 0.27571765
# step) 861 Accuracy(IOU)= 0.27502465
# step) 862 Accuracy(IOU)= 0.2743764
# step) 863 Accuracy(IOU)= 0.27447513
# step) 864 Accuracy(IOU)= 0.2747753
# step) 865 Accuracy(IOU)= 0.27507895
# step) 866 Accuracy(IOU)= 0.27329326
# step) 867 Accuracy(IOU)= 0.27180487
# step) 868 Accuracy(IOU)= 0.27121767
# step) 869 Accuracy(IOU)= 0.26877213
# step) 870 Accuracy(IOU)= 0.27191228
# step) 871 Accuracy(IOU)= 0.2734511
# step) 872 Accuracy(IOU)= 0.27474058
# step) 873 Accuracy(IOU)= 0.27443936
# step) 874 Accuracy(IOU)= 0.27498186
# step) 875 Accuracy(IOU)= 0.27408773
# step) 876 Accuracy(IOU)= 0.27243754
# step) 877 Accuracy(IOU)= 0.27202472
# step) 878 Accuracy(IOU)= 0.2729703
# step) 879 Accuracy(IOU)= 0.2768707
# step) 880 Accuracy(IOU)= 0.2761701
# step) 881 Accuracy(IOU)= 0.27650994
# step) 882 Accuracy(IOU)= 0.27623114
# step) 883 Accuracy(IOU)= 0.2761831
# step) 884 Accuracy(IOU)= 0.27546337
# step) 885 Accuracy(IOU)= 0.27774793
# step) 886 Accuracy(IOU)= 0.2848263
# step) 887 Accuracy(IOU)= 0.28309262
# step) 888 Accuracy(IOU)= 0.2831821
# step) 889 Accuracy(IOU)= 0.28345123
# step) 890 Accuracy(IOU)= 0.2825103
# step) 891 Accuracy(IOU)= 0.28090063
# step) 892 Accuracy(IOU)= 0.28558004
# step) 893 Accuracy(IOU)= 0.28386015
# step) 894 Accuracy(IOU)= 0.2830443
# step) 895 Accuracy(IOU)= 0.2838889
# step) 896 Accuracy(IOU)= 0.28437656
# step) 897 Accuracy(IOU)= 0.28951663
# step) 898 Accuracy(IOU)= 0.28963083
# step) 899 Accuracy(IOU)= 0.28816375
# step) 900 Accuracy(IOU)= 0.28710058
# step) 901 Accuracy(IOU)= 0.2856658
# step) 902 Accuracy(IOU)= 0.28525293
# step) 903 Accuracy(IOU)= 0.28774354
# step) 904 Accuracy(IOU)= 0.2891955
# step) 905 Accuracy(IOU)= 0.28981534
# step) 906 Accuracy(IOU)= 0.2907342
# step) 907 Accuracy(IOU)= 0.29065153
# step) 908 Accuracy(IOU)= 0.29113564
# step) 909 Accuracy(IOU)= 0.29088446
# step) 910 Accuracy(IOU)= 0.28846627
# step) 911 Accuracy(IOU)= 0.28693205
# step) 912 Accuracy(IOU)= 0.28508347
# step) 913 Accuracy(IOU)= 0.2839383
# step) 914 Accuracy(IOU)= 0.28170824
# step) 915 Accuracy(IOU)= 0.28125793
# step) 916 Accuracy(IOU)= 0.2820914
# step) 917 Accuracy(IOU)= 0.2819592
# step) 918 Accuracy(IOU)= 0.28184366
# step) 919 Accuracy(IOU)= 0.28286874
# step) 920 Accuracy(IOU)= 0.2826299
# step) 921 Accuracy(IOU)= 0.28424162
# step) 922 Accuracy(IOU)= 0.28556478
# step) 923 Accuracy(IOU)= 0.2847035
# step) 924 Accuracy(IOU)= 0.28333917
# step) 925 Accuracy(IOU)= 0.2840895
# step) 926 Accuracy(IOU)= 0.2854689
# step) 927 Accuracy(IOU)= 0.28292066
# step) 928 Accuracy(IOU)= 0.283443
# step) 929 Accuracy(IOU)= 0.28352314
# step) 930 Accuracy(IOU)= 0.28266302
# step) 931 Accuracy(IOU)= 0.28413588
# step) 932 Accuracy(IOU)= 0.28325355
# step) 933 Accuracy(IOU)= 0.28385046
# step) 934 Accuracy(IOU)= 0.2851719
# step) 935 Accuracy(IOU)= 0.28281602
# step) 936 Accuracy(IOU)= 0.28438255
# step) 937 Accuracy(IOU)= 0.2871609
# step) 938 Accuracy(IOU)= 0.28875074
# step) 939 Accuracy(IOU)= 0.2888094
# step) 940 Accuracy(IOU)= 0.2881575
# step) 941 Accuracy(IOU)= 0.28920764
# step) 942 Accuracy(IOU)= 0.28713632
# step) 943 Accuracy(IOU)= 0.28669474
# step) 944 Accuracy(IOU)= 0.2863336
# step) 945 Accuracy(IOU)= 0.28555667
# step) 946 Accuracy(IOU)= 0.28459078
# step) 947 Accuracy(IOU)= 0.28524157
# step) 948 Accuracy(IOU)= 0.28775638
# step) 949 Accuracy(IOU)= 0.2871526
# step) 950 Accuracy(IOU)= 0.2875225
# step) 951 Accuracy(IOU)= 0.28795582
# step) 952 Accuracy(IOU)= 0.28801578
# step) 953 Accuracy(IOU)= 0.2861867
# step) 954 Accuracy(IOU)= 0.28735834
# step) 955 Accuracy(IOU)= 0.28794307
# step) 956 Accuracy(IOU)= 0.28843036
# step) 957 Accuracy(IOU)= 0.28784448
# step) 958 Accuracy(IOU)= 0.28747058
# step) 959 Accuracy(IOU)= 0.28759155
# step) 960 Accuracy(IOU)= 0.28647113
# step) 961 Accuracy(IOU)= 0.2881004
# step) 962 Accuracy(IOU)= 0.28761545
# step) 963 Accuracy(IOU)= 0.2856659
# step) 964 Accuracy(IOU)= 0.28573793
# step) 965 Accuracy(IOU)= 0.28574017
# step) 966 Accuracy(IOU)= 0.28735816
# step) 967 Accuracy(IOU)= 0.28707907
# step) 968 Accuracy(IOU)= 0.2867067
# step) 969 Accuracy(IOU)= 0.28556734
# step) 970 Accuracy(IOU)= 0.28362703
# step) 971 Accuracy(IOU)= 0.28397176
# step) 972 Accuracy(IOU)= 0.28318956
# step) 973 Accuracy(IOU)= 0.28302863
# step) 974 Accuracy(IOU)= 0.2842436
# step) 975 Accuracy(IOU)= 0.28394458
# step) 976 Accuracy(IOU)= 0.28477612
# step) 977 Accuracy(IOU)= 0.28713146
# step) 978 Accuracy(IOU)= 0.28916755
# step) 979 Accuracy(IOU)= 0.2893472
# step) 980 Accuracy(IOU)= 0.29227972
# step) 981 Accuracy(IOU)= 0.29198226
# step) 982 Accuracy(IOU)= 0.29030982
# step) 983 Accuracy(IOU)= 0.2896124
# step) 984 Accuracy(IOU)= 0.29085347
# step) 985 Accuracy(IOU)= 0.29755113
# step) 986 Accuracy(IOU)= 0.29968396
# step) 987 Accuracy(IOU)= 0.2995897
# step) 988 Accuracy(IOU)= 0.300258
# step) 989 Accuracy(IOU)= 0.3027015
# step) 990 Accuracy(IOU)= 0.30432078
# step) 991 Accuracy(IOU)= 0.30399293
# step) 992 Accuracy(IOU)= 0.3026346
# step) 993 Accuracy(IOU)= 0.3031997
# step) 994 Accuracy(IOU)= 0.30234483
# step) 995 Accuracy(IOU)= 0.30894616
# step) 996 Accuracy(IOU)= 0.3073724
# step) 997 Accuracy(IOU)= 0.30764523
# step) 998 Accuracy(IOU)= 0.30587447
# step) 999 Accuracy(IOU)= 0.30518872
# save model
# step) 1000 Accuracy(IOU)= 0.3060919
# step) 1001 Accuracy(IOU)= 0.3061325
# step) 1002 Accuracy(IOU)= 0.3046782
# step) 1003 Accuracy(IOU)= 0.3034337
# step) 1004 Accuracy(IOU)= 0.3023829
# step) 1005 Accuracy(IOU)= 0.3022805
# step) 1006 Accuracy(IOU)= 0.30047092
# step) 1007 Accuracy(IOU)= 0.29901797
# step) 1008 Accuracy(IOU)= 0.29977083
# step) 1009 Accuracy(IOU)= 0.2998873
# step) 1010 Accuracy(IOU)= 0.30130723
# step) 1011 Accuracy(IOU)= 0.3029829
# step) 1012 Accuracy(IOU)= 0.3030113
# step) 1013 Accuracy(IOU)= 0.3037647
# step) 1014 Accuracy(IOU)= 0.30146423
# step) 1015 Accuracy(IOU)= 0.30185628
# step) 1016 Accuracy(IOU)= 0.30188784
# step) 1017 Accuracy(IOU)= 0.3001705
# step) 1018 Accuracy(IOU)= 0.29916722
# step) 1019 Accuracy(IOU)= 0.29995868
# step) 1020 Accuracy(IOU)= 0.29937074
# step) 1021 Accuracy(IOU)= 0.29704988
# step) 1022 Accuracy(IOU)= 0.29829702
# step) 1023 Accuracy(IOU)= 0.2984402
# step) 1024 Accuracy(IOU)= 0.29702732
# step) 1025 Accuracy(IOU)= 0.29683557
# step) 1026 Accuracy(IOU)= 0.29691947
# step) 1027 Accuracy(IOU)= 0.29748324
# step) 1028 Accuracy(IOU)= 0.29578972
# step) 1029 Accuracy(IOU)= 0.30271366
# step) 1030 Accuracy(IOU)= 0.30187052
# step) 1031 Accuracy(IOU)= 0.3029377
# step) 1032 Accuracy(IOU)= 0.30116946
# step) 1033 Accuracy(IOU)= 0.29906398
# step) 1034 Accuracy(IOU)= 0.3006828
# step) 1035 Accuracy(IOU)= 0.3010068
# step) 1036 Accuracy(IOU)= 0.30115327
# step) 1037 Accuracy(IOU)= 0.30055535
# step) 1038 Accuracy(IOU)= 0.301757
# step) 1039 Accuracy(IOU)= 0.3018031
# step) 1040 Accuracy(IOU)= 0.29983488
# step) 1041 Accuracy(IOU)= 0.29986578
# step) 1042 Accuracy(IOU)= 0.29930344
# step) 1043 Accuracy(IOU)= 0.30083722
# step) 1044 Accuracy(IOU)= 0.30084363
# step) 1045 Accuracy(IOU)= 0.29843146
# step) 1046 Accuracy(IOU)= 0.29823762
# step) 1047 Accuracy(IOU)= 0.29959098
# step) 1048 Accuracy(IOU)= 0.29900885
# step) 1049 Accuracy(IOU)= 0.3031311
# step) 1050 Accuracy(IOU)= 0.30999234
# step) 1051 Accuracy(IOU)= 0.3118244
# step) 1052 Accuracy(IOU)= 0.31338835
# step) 1053 Accuracy(IOU)= 0.31560153
# step) 1054 Accuracy(IOU)= 0.3188762
# step) 1055 Accuracy(IOU)= 0.3161044
# step) 1056 Accuracy(IOU)= 0.31301022
# step) 1057 Accuracy(IOU)= 0.31219158
# step) 1058 Accuracy(IOU)= 0.3100261
# step) 1059 Accuracy(IOU)= 0.30990803
# step) 1060 Accuracy(IOU)= 0.3124103
# step) 1062 Accuracy(IOU)= 0.31177473
# step) 1063 Accuracy(IOU)= 0.3133075
# step) 1064 Accuracy(IOU)= 0.31296468
# step) 1065 Accuracy(IOU)= 0.31230563
# step) 1066 Accuracy(IOU)= 0.3123112
# step) 1067 Accuracy(IOU)= 0.31164718
# step) 1068 Accuracy(IOU)= 0.31129995
# step) 1069 Accuracy(IOU)= 0.31223857
# step) 1070 Accuracy(IOU)= 0.31188604
# step) 1071 Accuracy(IOU)= 0.31363398
# step) 1072 Accuracy(IOU)= 0.31464624
# step) 1073 Accuracy(IOU)= 0.31645045
# step) 1074 Accuracy(IOU)= 0.3167203
# step) 1075 Accuracy(IOU)= 0.31730855
# step) 1076 Accuracy(IOU)= 0.3195424
# step) 1077 Accuracy(IOU)= 0.3206118
# step) 1078 Accuracy(IOU)= 0.320165
# step) 1079 Accuracy(IOU)= 0.3237155
# step) 1080 Accuracy(IOU)= 0.32378468
# step) 1081 Accuracy(IOU)= 0.3233422
# step) 1082 Accuracy(IOU)= 0.32170284
# step) 1083 Accuracy(IOU)= 0.321921
# step) 1084 Accuracy(IOU)= 0.320806
# step) 1085 Accuracy(IOU)= 0.3196075
# step) 1086 Accuracy(IOU)= 0.31915084
# step) 1087 Accuracy(IOU)= 0.31894448
# step) 1088 Accuracy(IOU)= 0.32073423
# step) 1089 Accuracy(IOU)= 0.32323104
# step) 1090 Accuracy(IOU)= 0.32609206
# step) 1091 Accuracy(IOU)= 0.3278346
# step) 1092 Accuracy(IOU)= 0.32849538
# step) 1093 Accuracy(IOU)= 0.33047304
# step) 1094 Accuracy(IOU)= 0.3299148
# step) 1095 Accuracy(IOU)= 0.32855567
# step) 1096 Accuracy(IOU)= 0.32881185
# step) 1097 Accuracy(IOU)= 0.32817277
# step) 1098 Accuracy(IOU)= 0.32697874
# step) 1099 Accuracy(IOU)= 0.32696486
# step) 1100 Accuracy(IOU)= 0.32540172
# step) 1101 Accuracy(IOU)= 0.32556704
# step) 1102 Accuracy(IOU)= 0.32643184
# step) 1103 Accuracy(IOU)= 0.32517293
# step) 1104 Accuracy(IOU)= 0.32779735
# step) 1105 Accuracy(IOU)= 0.3274545
# step) 1106 Accuracy(IOU)= 0.3278841
# step) 1107 Accuracy(IOU)= 0.32482693
# step) 1108 Accuracy(IOU)= 0.32610044
# step) 1109 Accuracy(IOU)= 0.3281822
# step) 1110 Accuracy(IOU)= 0.3257454
# step) 1111 Accuracy(IOU)= 0.32459635
# step) 1112 Accuracy(IOU)= 0.32478487
# step) 1113 Accuracy(IOU)= 0.32377425
# step) 1114 Accuracy(IOU)= 0.32378823
# step) 1115 Accuracy(IOU)= 0.3258192
# step) 1116 Accuracy(IOU)= 0.3237593
# step) 1117 Accuracy(IOU)= 0.32359615
# step) 1118 Accuracy(IOU)= 0.32168424
# step) 1119 Accuracy(IOU)= 0.31943613
# step) 1120 Accuracy(IOU)= 0.319843
# step) 1121 Accuracy(IOU)= 0.31942016
# step) 1122 Accuracy(IOU)= 0.31910715
# step) 1123 Accuracy(IOU)= 0.31833822
# step) 1124 Accuracy(IOU)= 0.31793588
# step) 1125 Accuracy(IOU)= 0.31827155
# step) 1126 Accuracy(IOU)= 0.31680533
# step) 1127 Accuracy(IOU)= 0.32341382
# step) 1128 Accuracy(IOU)= 0.32222128
# step) 1129 Accuracy(IOU)= 0.3219412
# step) 1130 Accuracy(IOU)= 0.32010916
# step) 1131 Accuracy(IOU)= 0.31994244
# step) 1132 Accuracy(IOU)= 0.32037985
# step) 1133 Accuracy(IOU)= 0.31951982
# step) 1134 Accuracy(IOU)= 0.31912905
# step) 1135 Accuracy(IOU)= 0.31825373
# step) 1136 Accuracy(IOU)= 0.31644726
# step) 1137 Accuracy(IOU)= 0.32227623
# step) 1138 Accuracy(IOU)= 0.32353988
# step) 1139 Accuracy(IOU)= 0.3233911
# step) 1140 Accuracy(IOU)= 0.32392934
# step) 1141 Accuracy(IOU)= 0.32289198
# step) 1142 Accuracy(IOU)= 0.3225358
# step) 1143 Accuracy(IOU)= 0.3222405
# step) 1144 Accuracy(IOU)= 0.32036418
# step) 1145 Accuracy(IOU)= 0.31894508
# step) 1146 Accuracy(IOU)= 0.3196372
# step) 1147 Accuracy(IOU)= 0.32218122
# step) 1148 Accuracy(IOU)= 0.32470423
# step) 1149 Accuracy(IOU)= 0.3251315
# step) 1150 Accuracy(IOU)= 0.32633644
# step) 1151 Accuracy(IOU)= 0.33182672
# step) 1152 Accuracy(IOU)= 0.3315024
# step) 1153 Accuracy(IOU)= 0.3336938
# step) 1154 Accuracy(IOU)= 0.33489853
# step) 1155 Accuracy(IOU)= 0.33205435
# step) 1156 Accuracy(IOU)= 0.33489037
# step) 1157 Accuracy(IOU)= 0.33216062
# step) 1158 Accuracy(IOU)= 0.33179396
# step) 1159 Accuracy(IOU)= 0.33077973
# step) 1160 Accuracy(IOU)= 0.3339994
# step) 1161 Accuracy(IOU)= 0.33177498
# step) 1162 Accuracy(IOU)= 0.33297896
# step) 1163 Accuracy(IOU)= 0.33180332
# step) 1164 Accuracy(IOU)= 0.3316714
# step) 1165 Accuracy(IOU)= 0.33191922
# step) 1166 Accuracy(IOU)= 0.33139122
# step) 1167 Accuracy(IOU)= 0.3302606
# step) 1168 Accuracy(IOU)= 0.33051512
# step) 1169 Accuracy(IOU)= 0.32842806
# step) 1170 Accuracy(IOU)= 0.32764164
# step) 1171 Accuracy(IOU)= 0.3285479
# step) 1172 Accuracy(IOU)= 0.32803482
# step) 1173 Accuracy(IOU)= 0.32828805
# step) 1174 Accuracy(IOU)= 0.32777637
# step) 1175 Accuracy(IOU)= 0.32656363
# step) 1176 Accuracy(IOU)= 0.32591453
# step) 1177 Accuracy(IOU)= 0.3281842
# step) 1178 Accuracy(IOU)= 0.326887
# step) 1179 Accuracy(IOU)= 0.32680368
# step) 1180 Accuracy(IOU)= 0.32729435
# step) 1181 Accuracy(IOU)= 0.32613644
# step) 1182 Accuracy(IOU)= 0.3236163
# step) 1183 Accuracy(IOU)= 0.32504636
# step) 1184 Accuracy(IOU)= 0.32454726
# step) 1185 Accuracy(IOU)= 0.32435232
# step) 1186 Accuracy(IOU)= 0.3229295
# step) 1187 Accuracy(IOU)= 0.32713228
# step) 1188 Accuracy(IOU)= 0.32580596
# step) 1189 Accuracy(IOU)= 0.32603553
# step) 1190 Accuracy(IOU)= 0.32573435
# step) 1191 Accuracy(IOU)= 0.32393053
# step) 1192 Accuracy(IOU)= 0.32332408
# step) 1193 Accuracy(IOU)= 0.32331723
# step) 1194 Accuracy(IOU)= 0.32201487
# step) 1195 Accuracy(IOU)= 0.32147557
# step) 1196 Accuracy(IOU)= 0.3234378
# step) 1197 Accuracy(IOU)= 0.3223484
# step) 1198 Accuracy(IOU)= 0.32097873
# step) 1199 Accuracy(IOU)= 0.32069287
# step) 1200 Accuracy(IOU)= 0.3201769
# step) 1201 Accuracy(IOU)= 0.31914964
# step) 1202 Accuracy(IOU)= 0.32116625
# step) 1203 Accuracy(IOU)= 0.31877425
# step) 1204 Accuracy(IOU)= 0.31892297
# step) 1205 Accuracy(IOU)= 0.3169787
# step) 1206 Accuracy(IOU)= 0.31755245
# step) 1207 Accuracy(IOU)= 0.31718397
# step) 1208 Accuracy(IOU)= 0.31643426
# step) 1209 Accuracy(IOU)= 0.31759426
# step) 1210 Accuracy(IOU)= 0.31738502
# step) 1211 Accuracy(IOU)= 0.31786433
# step) 1212 Accuracy(IOU)= 0.31658432
# step) 1213 Accuracy(IOU)= 0.31526944
# step) 1214 Accuracy(IOU)= 0.31749687
# step) 1215 Accuracy(IOU)= 0.31748584
# step) 1216 Accuracy(IOU)= 0.318579
# step) 1217 Accuracy(IOU)= 0.31946728
# step) 1218 Accuracy(IOU)= 0.32071346
# step) 1219 Accuracy(IOU)= 0.31907347
# step) 1220 Accuracy(IOU)= 0.3184495
# step) 1221 Accuracy(IOU)= 0.3173355
# step) 1222 Accuracy(IOU)= 0.31737363
# step) 1223 Accuracy(IOU)= 0.3171518
# step) 1224 Accuracy(IOU)= 0.31474823
# step) 1225 Accuracy(IOU)= 0.3137537
# step) 1226 Accuracy(IOU)= 0.31195584
# step) 1227 Accuracy(IOU)= 0.31101695
# step) 1228 Accuracy(IOU)= 0.3098793
# step) 1229 Accuracy(IOU)= 0.30878356
# step) 1230 Accuracy(IOU)= 0.30754507
# step) 1231 Accuracy(IOU)= 0.3064706
# step) 1232 Accuracy(IOU)= 0.30654386
# step) 1233 Accuracy(IOU)= 0.30483162
# step) 1234 Accuracy(IOU)= 0.30279782
# step) 1235 Accuracy(IOU)= 0.30015212
# step) 1236 Accuracy(IOU)= 0.29893747
# step) 1237 Accuracy(IOU)= 0.29841197
# step) 1238 Accuracy(IOU)= 0.29706553
# step) 1239 Accuracy(IOU)= 0.29819
# step) 1240 Accuracy(IOU)= 0.2959004
# step) 1241 Accuracy(IOU)= 0.29706672
# step) 1242 Accuracy(IOU)= 0.29468405
# step) 1243 Accuracy(IOU)= 0.29727113
# step) 1244 Accuracy(IOU)= 0.29757833
# step) 1245 Accuracy(IOU)= 0.29751432
# step) 1246 Accuracy(IOU)= 0.29771796
# step) 1247 Accuracy(IOU)= 0.29675627
# step) 1248 Accuracy(IOU)= 0.29516768
# step) 1249 Accuracy(IOU)= 0.29506597
# step) 1250 Accuracy(IOU)= 0.29252544
# step) 1251 Accuracy(IOU)= 0.29242197
# step) 1252 Accuracy(IOU)= 0.29249066
# step) 1253 Accuracy(IOU)= 0.29209834
# step) 1254 Accuracy(IOU)= 0.28960082
# step) 1255 Accuracy(IOU)= 0.2897854
# step) 1256 Accuracy(IOU)= 0.28793073
# step) 1257 Accuracy(IOU)= 0.28982952
# step) 1258 Accuracy(IOU)= 0.29216903
# step) 1259 Accuracy(IOU)= 0.29342276
# step) 1260 Accuracy(IOU)= 0.29192826
# step) 1261 Accuracy(IOU)= 0.29051873
# step) 1262 Accuracy(IOU)= 0.28994626
# step) 1263 Accuracy(IOU)= 0.2893156
# step) 1264 Accuracy(IOU)= 0.28950968
# step) 1265 Accuracy(IOU)= 0.29043198
# step) 1266 Accuracy(IOU)= 0.29154968
# step) 1267 Accuracy(IOU)= 0.29059204
# step) 1268 Accuracy(IOU)= 0.28985053
# step) 1269 Accuracy(IOU)= 0.28935984
# step) 1270 Accuracy(IOU)= 0.28993118
# step) 1271 Accuracy(IOU)= 0.2918338
# step) 1272 Accuracy(IOU)= 0.29230163
# step) 1273 Accuracy(IOU)= 0.29219127
# step) 1274 Accuracy(IOU)= 0.29102224
# step) 1275 Accuracy(IOU)= 0.29019555
# step) 1276 Accuracy(IOU)= 0.2894791
# step) 1277 Accuracy(IOU)= 0.28807712
# step) 1278 Accuracy(IOU)= 0.28874284
# step) 1279 Accuracy(IOU)= 0.28890637
# step) 1280 Accuracy(IOU)= 0.28687388
# step) 1281 Accuracy(IOU)= 0.28511745
# step) 1282 Accuracy(IOU)= 0.28634986
# step) 1283 Accuracy(IOU)= 0.28690127
# step) 1284 Accuracy(IOU)= 0.28881028
# step) 1285 Accuracy(IOU)= 0.28968877
# step) 1286 Accuracy(IOU)= 0.28688973
# step) 1287 Accuracy(IOU)= 0.2850967
# step) 1288 Accuracy(IOU)= 0.2859361
# step) 1289 Accuracy(IOU)= 0.28724617
# step) 1290 Accuracy(IOU)= 0.28689736
# step) 1291 Accuracy(IOU)= 0.2874895
# step) 1292 Accuracy(IOU)= 0.28901637
# step) 1293 Accuracy(IOU)= 0.2873675
# step) 1294 Accuracy(IOU)= 0.2879336
# step) 1295 Accuracy(IOU)= 0.28917852
# step) 1296 Accuracy(IOU)= 0.28864703
# step) 1297 Accuracy(IOU)= 0.2866912
# step) 1298 Accuracy(IOU)= 0.2852281
# step) 1300 Accuracy(IOU)= 0.28698412
# step) 1301 Accuracy(IOU)= 0.28677768
# step) 1302 Accuracy(IOU)= 0.28535065
# step) 1303 Accuracy(IOU)= 0.2830249
# step) 1304 Accuracy(IOU)= 0.28215498
# step) 1305 Accuracy(IOU)= 0.28184372
# step) 1306 Accuracy(IOU)= 0.28131312
# step) 1307 Accuracy(IOU)= 0.28015587
# step) 1308 Accuracy(IOU)= 0.27774262
# step) 1309 Accuracy(IOU)= 0.2763652
# step) 1310 Accuracy(IOU)= 0.2776109
# step) 1311 Accuracy(IOU)= 0.2774527
# step) 1312 Accuracy(IOU)= 0.27593544
# step) 1313 Accuracy(IOU)= 0.27644914
# step) 1314 Accuracy(IOU)= 0.27606308
# step) 1315 Accuracy(IOU)= 0.27632555
# step) 1316 Accuracy(IOU)= 0.27705383
# step) 1317 Accuracy(IOU)= 0.2780463
# step) 1318 Accuracy(IOU)= 0.27747336
# step) 1319 Accuracy(IOU)= 0.27608863
# step) 1320 Accuracy(IOU)= 0.2770467
# step) 1321 Accuracy(IOU)= 0.27819526
# step) 1322 Accuracy(IOU)= 0.27766445
# step) 1323 Accuracy(IOU)= 0.2762427
# step) 1324 Accuracy(IOU)= 0.27813676
# step) 1325 Accuracy(IOU)= 0.27791244
# step) 1326 Accuracy(IOU)= 0.27795452
# step) 1327 Accuracy(IOU)= 0.27627504
# step) 1328 Accuracy(IOU)= 0.2773997
# step) 1329 Accuracy(IOU)= 0.2780717
# step) 1330 Accuracy(IOU)= 0.28038612
# step) 1331 Accuracy(IOU)= 0.28037858
# step) 1332 Accuracy(IOU)= 0.27904648
# step) 1333 Accuracy(IOU)= 0.27858064
# step) 1334 Accuracy(IOU)= 0.2763775
# step) 1335 Accuracy(IOU)= 0.2753633
# step) 1336 Accuracy(IOU)= 0.2745826
# step) 1337 Accuracy(IOU)= 0.2749668
# step) 1338 Accuracy(IOU)= 0.27726188
# step) 1339 Accuracy(IOU)= 0.27845985
# step) 1340 Accuracy(IOU)= 0.27746964
# step) 1341 Accuracy(IOU)= 0.27789798
# ...
# step) 99576 Accuracy(IOU)= 0.42830604
# step) 99577 Accuracy(IOU)= 0.42614052
# step) 99578 Accuracy(IOU)= 0.42775398
# step) 99579 Accuracy(IOU)= 0.42762128
# step) 99580 Accuracy(IOU)= 0.42623562
# step) 99581 Accuracy(IOU)= 0.42629924
# step) 99582 Accuracy(IOU)= 0.42534506
# step) 99583 Accuracy(IOU)= 0.42562136
# step) 99584 Accuracy(IOU)= 0.42430258
# step) 99585 Accuracy(IOU)= 0.4258619
# step) 99586 Accuracy(IOU)= 0.42322546
# step) 99587 Accuracy(IOU)= 0.42245957
# step) 99588 Accuracy(IOU)= 0.42821583
# step) 99589 Accuracy(IOU)= 0.42724213
# step) 99590 Accuracy(IOU)= 0.4278155
# step) 99591 Accuracy(IOU)= 0.42549878
# step) 99592 Accuracy(IOU)= 0.4256172
# step) 99593 Accuracy(IOU)= 0.42527553
# step) 99594 Accuracy(IOU)= 0.42219064
# step) 99595 Accuracy(IOU)= 0.42127034
# step) 99596 Accuracy(IOU)= 0.42369992
# step) 99597 Accuracy(IOU)= 0.42572796
# step) 99598 Accuracy(IOU)= 0.42491364
# step) 99599 Accuracy(IOU)= 0.42512655
# step) 99600 Accuracy(IOU)= 0.4248472
# step) 99601 Accuracy(IOU)= 0.42691106
# step) 99602 Accuracy(IOU)= 0.426287
# step) 99603 Accuracy(IOU)= 0.4242424
# step) 99604 Accuracy(IOU)= 0.4261849
# step) 99605 Accuracy(IOU)= 0.42959827
# step) 99606 Accuracy(IOU)= 0.43113086
# step) 99607 Accuracy(IOU)= 0.43433985
# step) 99608 Accuracy(IOU)= 0.43344936
# step) 99609 Accuracy(IOU)= 0.43453082
# step) 99610 Accuracy(IOU)= 0.4342046
# step) 99611 Accuracy(IOU)= 0.4354557
# step) 99612 Accuracy(IOU)= 0.4368393
# step) 99613 Accuracy(IOU)= 0.43588382
# step) 99614 Accuracy(IOU)= 0.4357112
# step) 99615 Accuracy(IOU)= 0.43484384
# step) 99616 Accuracy(IOU)= 0.4342846
# step) 99617 Accuracy(IOU)= 0.43393308
# step) 99618 Accuracy(IOU)= 0.4368179
# step) 99619 Accuracy(IOU)= 0.43684006
# step) 99620 Accuracy(IOU)= 0.4370157
# step) 99621 Accuracy(IOU)= 0.43485498
# step) 99622 Accuracy(IOU)= 0.43501535
# step) 99623 Accuracy(IOU)= 0.4353616
# step) 99624 Accuracy(IOU)= 0.4394109
# step) 99625 Accuracy(IOU)= 0.43962488
# step) 99626 Accuracy(IOU)= 0.43640697
# step) 99627 Accuracy(IOU)= 0.43520302
# step) 99628 Accuracy(IOU)= 0.43337253
# step) 99629 Accuracy(IOU)= 0.4340853
# step) 99630 Accuracy(IOU)= 0.43603495
# step) 99631 Accuracy(IOU)= 0.4371405
# step) 99632 Accuracy(IOU)= 0.43785268
# step) 99633 Accuracy(IOU)= 0.43834463
# step) 99634 Accuracy(IOU)= 0.4383286
# step) 99635 Accuracy(IOU)= 0.4365806
# step) 99636 Accuracy(IOU)= 0.43708655
# step) 99637 Accuracy(IOU)= 0.43459496
# step) 99638 Accuracy(IOU)= 0.43522164
# step) 99639 Accuracy(IOU)= 0.4339608
# step) 99640 Accuracy(IOU)= 0.43521535
# step) 99641 Accuracy(IOU)= 0.43689388
# step) 99642 Accuracy(IOU)= 0.43549278
# step) 99643 Accuracy(IOU)= 0.43335256
# step) 99644 Accuracy(IOU)= 0.43448764
# step) 99645 Accuracy(IOU)= 0.43458727
# step) 99646 Accuracy(IOU)= 0.43559712
# step) 99647 Accuracy(IOU)= 0.43572608
# step) 99648 Accuracy(IOU)= 0.43540508
# step) 99649 Accuracy(IOU)= 0.43351346
# step) 99650 Accuracy(IOU)= 0.43509948
# step) 99651 Accuracy(IOU)= 0.43496802
# step) 99652 Accuracy(IOU)= 0.4368265
# step) 99653 Accuracy(IOU)= 0.43955725
# step) 99654 Accuracy(IOU)= 0.4389179
# step) 99655 Accuracy(IOU)= 0.4386699
# step) 99656 Accuracy(IOU)= 0.44042873
# step) 99657 Accuracy(IOU)= 0.4374946
# step) 99658 Accuracy(IOU)= 0.43813905
# step) 99659 Accuracy(IOU)= 0.43831426
# step) 99660 Accuracy(IOU)= 0.43667322
# step) 99661 Accuracy(IOU)= 0.43710995
# step) 99662 Accuracy(IOU)= 0.43762007
# step) 99663 Accuracy(IOU)= 0.43894637
# step) 99664 Accuracy(IOU)= 0.43897992
# step) 99665 Accuracy(IOU)= 0.43686062
# step) 99666 Accuracy(IOU)= 0.43814108
# step) 99667 Accuracy(IOU)= 0.43820682
# step) 99668 Accuracy(IOU)= 0.43861622
# step) 99669 Accuracy(IOU)= 0.43755054
# step) 99670 Accuracy(IOU)= 0.43788838
# step) 99671 Accuracy(IOU)= 0.43691924
# step) 99672 Accuracy(IOU)= 0.4358598
# step) 99673 Accuracy(IOU)= 0.43509585
# step) 99674 Accuracy(IOU)= 0.43249238
# step) 99675 Accuracy(IOU)= 0.43402675
# step) 99676 Accuracy(IOU)= 0.43243575
# step) 99677 Accuracy(IOU)= 0.43165115
# step) 99678 Accuracy(IOU)= 0.4322541
# step) 99679 Accuracy(IOU)= 0.43537602
# step) 99680 Accuracy(IOU)= 0.43529978
# step) 99681 Accuracy(IOU)= 0.43564463
# step) 99682 Accuracy(IOU)= 0.43474212
# step) 99683 Accuracy(IOU)= 0.43615317
# step) 99684 Accuracy(IOU)= 0.434987
# step) 99685 Accuracy(IOU)= 0.4343123
# step) 99686 Accuracy(IOU)= 0.43282184
# step) 99687 Accuracy(IOU)= 0.43174887
# step) 99688 Accuracy(IOU)= 0.43301082
# step) 99689 Accuracy(IOU)= 0.4325616
# step) 99690 Accuracy(IOU)= 0.431031
# step) 99691 Accuracy(IOU)= 0.43171653
# step) 99692 Accuracy(IOU)= 0.43265802
# step) 99693 Accuracy(IOU)= 0.43497315
# step) 99694 Accuracy(IOU)= 0.43439814
# step) 99695 Accuracy(IOU)= 0.4351211
# step) 99696 Accuracy(IOU)= 0.43466595
# step) 99697 Accuracy(IOU)= 0.4343082
# step) 99698 Accuracy(IOU)= 0.43576825
# step) 99699 Accuracy(IOU)= 0.43681118
# step) 99700 Accuracy(IOU)= 0.43266693
# step) 99701 Accuracy(IOU)= 0.43274823
# step) 99702 Accuracy(IOU)= 0.4326466
# step) 99703 Accuracy(IOU)= 0.43275627
# step) 99704 Accuracy(IOU)= 0.43238083
# step) 99705 Accuracy(IOU)= 0.43316835
# step) 99706 Accuracy(IOU)= 0.43615997
# step) 99707 Accuracy(IOU)= 0.43647984
# step) 99708 Accuracy(IOU)= 0.43658787
# step) 99709 Accuracy(IOU)= 0.43730298
# step) 99710 Accuracy(IOU)= 0.43539512
# step) 99711 Accuracy(IOU)= 0.43589437
# step) 99712 Accuracy(IOU)= 0.43618396
# step) 99713 Accuracy(IOU)= 0.43409947
# step) 99714 Accuracy(IOU)= 0.43143263
# step) 99715 Accuracy(IOU)= 0.43073615
# step) 99716 Accuracy(IOU)= 0.43141305
# step) 99717 Accuracy(IOU)= 0.43240848
# step) 99718 Accuracy(IOU)= 0.43421206
# step) 99719 Accuracy(IOU)= 0.43242627
# step) 99720 Accuracy(IOU)= 0.43190494
# step) 99721 Accuracy(IOU)= 0.4318818
# step) 99722 Accuracy(IOU)= 0.43232805
# step) 99723 Accuracy(IOU)= 0.43318138
# step) 99724 Accuracy(IOU)= 0.43374193
# step) 99725 Accuracy(IOU)= 0.43442604
# step) 99726 Accuracy(IOU)= 0.4326493
# step) 99727 Accuracy(IOU)= 0.43140614
# step) 99728 Accuracy(IOU)= 0.43144983
# step) 99729 Accuracy(IOU)= 0.43039486
# step) 99730 Accuracy(IOU)= 0.4318016
# step) 99731 Accuracy(IOU)= 0.43154976
# step) 99732 Accuracy(IOU)= 0.4296428
# step) 99733 Accuracy(IOU)= 0.4299481
# step) 99734 Accuracy(IOU)= 0.42798987
# step) 99735 Accuracy(IOU)= 0.42954636
# step) 99736 Accuracy(IOU)= 0.43209207
# step) 99737 Accuracy(IOU)= 0.43445998
# step) 99738 Accuracy(IOU)= 0.43514606
# step) 99739 Accuracy(IOU)= 0.4327334
# step) 99740 Accuracy(IOU)= 0.43212712
# step) 99741 Accuracy(IOU)= 0.43585083
# step) 99742 Accuracy(IOU)= 0.43411142
# step) 99743 Accuracy(IOU)= 0.43523878
# step) 99744 Accuracy(IOU)= 0.43339074
# step) 99745 Accuracy(IOU)= 0.4331385
# step) 99746 Accuracy(IOU)= 0.43289042
# step) 99747 Accuracy(IOU)= 0.43307096
# step) 99748 Accuracy(IOU)= 0.43873128
# step) 99749 Accuracy(IOU)= 0.43888232
# step) 99750 Accuracy(IOU)= 0.4373035
# step) 99751 Accuracy(IOU)= 0.4370896
# step) 99752 Accuracy(IOU)= 0.43589017
# step) 99753 Accuracy(IOU)= 0.4378024
# step) 99754 Accuracy(IOU)= 0.43957335
# step) 99755 Accuracy(IOU)= 0.43833816
# step) 99756 Accuracy(IOU)= 0.43844587
# step) 99757 Accuracy(IOU)= 0.43937117
# step) 99758 Accuracy(IOU)= 0.43652356
# step) 99759 Accuracy(IOU)= 0.43578833
# step) 99760 Accuracy(IOU)= 0.43792197
# step) 99761 Accuracy(IOU)= 0.43582758
# step) 99762 Accuracy(IOU)= 0.43656272
# step) 99763 Accuracy(IOU)= 0.43569663
# step) 99764 Accuracy(IOU)= 0.43239015
# step) 99765 Accuracy(IOU)= 0.4315566
# step) 99766 Accuracy(IOU)= 0.43359336
# step) 99767 Accuracy(IOU)= 0.43486893
# step) 99768 Accuracy(IOU)= 0.43686992
# step) 99769 Accuracy(IOU)= 0.43590832
# step) 99770 Accuracy(IOU)= 0.4359645
# step) 99771 Accuracy(IOU)= 0.4361421
# step) 99772 Accuracy(IOU)= 0.4349682
# step) 99773 Accuracy(IOU)= 0.43299866
# step) 99774 Accuracy(IOU)= 0.43403783
# step) 99775 Accuracy(IOU)= 0.4331491
# step) 99776 Accuracy(IOU)= 0.4328992
# step) 99777 Accuracy(IOU)= 0.43471137
# step) 99778 Accuracy(IOU)= 0.43501163
# step) 99779 Accuracy(IOU)= 0.43372184
# step) 99780 Accuracy(IOU)= 0.4321648
# step) 99781 Accuracy(IOU)= 0.4331709
# step) 99782 Accuracy(IOU)= 0.43418464
# step) 99783 Accuracy(IOU)= 0.4333079
# step) 99784 Accuracy(IOU)= 0.43386286
# step) 99785 Accuracy(IOU)= 0.43275765
# step) 99786 Accuracy(IOU)= 0.4308104
# step) 99787 Accuracy(IOU)= 0.4304071
# step) 99788 Accuracy(IOU)= 0.43308082
# step) 99789 Accuracy(IOU)= 0.4335879
# step) 99790 Accuracy(IOU)= 0.43154505
# step) 99791 Accuracy(IOU)= 0.43183568
# step) 99792 Accuracy(IOU)= 0.43307316
# step) 99793 Accuracy(IOU)= 0.43292794
# step) 99794 Accuracy(IOU)= 0.43412304
# step) 99795 Accuracy(IOU)= 0.43532902
# step) 99796 Accuracy(IOU)= 0.43399644
# step) 99797 Accuracy(IOU)= 0.43372473
# step) 99798 Accuracy(IOU)= 0.43483034
# step) 99799 Accuracy(IOU)= 0.43454197
# step) 99800 Accuracy(IOU)= 0.4334581
# step) 99801 Accuracy(IOU)= 0.43356302
# step) 99802 Accuracy(IOU)= 0.4345175
# step) 99803 Accuracy(IOU)= 0.43419316
# step) 99804 Accuracy(IOU)= 0.43308994
# step) 99805 Accuracy(IOU)= 0.43501663
# step) 99806 Accuracy(IOU)= 0.43410847
# step) 99807 Accuracy(IOU)= 0.43345279
# step) 99808 Accuracy(IOU)= 0.4323822
# step) 99809 Accuracy(IOU)= 0.432025
# step) 99810 Accuracy(IOU)= 0.43076286
# step) 99811 Accuracy(IOU)= 0.42998633
# step) 99812 Accuracy(IOU)= 0.4287129
# step) 99813 Accuracy(IOU)= 0.42867225
# step) 99814 Accuracy(IOU)= 0.4264283
# step) 99815 Accuracy(IOU)= 0.42682454
# step) 99816 Accuracy(IOU)= 0.42702428
# step) 99817 Accuracy(IOU)= 0.42852473
# step) 99818 Accuracy(IOU)= 0.4292874
# step) 99819 Accuracy(IOU)= 0.42789683
# step) 99820 Accuracy(IOU)= 0.4271173
# step) 99821 Accuracy(IOU)= 0.42854083
# step) 99822 Accuracy(IOU)= 0.42918757
# step) 99823 Accuracy(IOU)= 0.43018055
# step) 99824 Accuracy(IOU)= 0.43024316
# step) 99825 Accuracy(IOU)= 0.42949447
# step) 99826 Accuracy(IOU)= 0.42850634
# step) 99827 Accuracy(IOU)= 0.42872775
# step) 99828 Accuracy(IOU)= 0.4295888
# step) 99829 Accuracy(IOU)= 0.43220803
# step) 99830 Accuracy(IOU)= 0.4302674
# step) 99831 Accuracy(IOU)= 0.43011743
# step) 99832 Accuracy(IOU)= 0.43022004
# step) 99833 Accuracy(IOU)= 0.4279518
# step) 99834 Accuracy(IOU)= 0.42671254
# step) 99835 Accuracy(IOU)= 0.426726
# step) 99836 Accuracy(IOU)= 0.42600635
# step) 99837 Accuracy(IOU)= 0.4252622
# step) 99838 Accuracy(IOU)= 0.4245423
# step) 99839 Accuracy(IOU)= 0.42890158
# step) 99840 Accuracy(IOU)= 0.42929032
# step) 99841 Accuracy(IOU)= 0.428658
# step) 99842 Accuracy(IOU)= 0.4276672
# step) 99843 Accuracy(IOU)= 0.42768434
# step) 99844 Accuracy(IOU)= 0.42908308
# step) 99845 Accuracy(IOU)= 0.4297323
# step) 99846 Accuracy(IOU)= 0.43134898
# step) 99847 Accuracy(IOU)= 0.43030787
# step) 99848 Accuracy(IOU)= 0.430885
# step) 99849 Accuracy(IOU)= 0.43134725
# step) 99850 Accuracy(IOU)= 0.43077034
# step) 99851 Accuracy(IOU)= 0.43111876
# step) 99852 Accuracy(IOU)= 0.43331164
# step) 99853 Accuracy(IOU)= 0.43325186
# step) 99854 Accuracy(IOU)= 0.4336436
# step) 99855 Accuracy(IOU)= 0.43116376
# step) 99856 Accuracy(IOU)= 0.43150765
# step) 99857 Accuracy(IOU)= 0.42987865
# step) 99858 Accuracy(IOU)= 0.4275036
# step) 99859 Accuracy(IOU)= 0.42773652
# step) 99860 Accuracy(IOU)= 0.42678803
# step) 99861 Accuracy(IOU)= 0.42775342
# step) 99862 Accuracy(IOU)= 0.42788482
# step) 99863 Accuracy(IOU)= 0.42787805
# step) 99864 Accuracy(IOU)= 0.42503572
# step) 99865 Accuracy(IOU)= 0.42608598
# step) 99866 Accuracy(IOU)= 0.4273504
# step) 99867 Accuracy(IOU)= 0.42807627
# step) 99868 Accuracy(IOU)= 0.42413005
# step) 99869 Accuracy(IOU)= 0.4254788
# step) 99870 Accuracy(IOU)= 0.42632988
# step) 99871 Accuracy(IOU)= 0.4263885
# step) 99872 Accuracy(IOU)= 0.4263403
# step) 99873 Accuracy(IOU)= 0.42718565
# step) 99874 Accuracy(IOU)= 0.42528614
# step) 99875 Accuracy(IOU)= 0.4262341
# step) 99876 Accuracy(IOU)= 0.42563784
# step) 99877 Accuracy(IOU)= 0.42601755
# step) 99878 Accuracy(IOU)= 0.42658886
# step) 99879 Accuracy(IOU)= 0.42577353
# step) 99880 Accuracy(IOU)= 0.42735574
# step) 99881 Accuracy(IOU)= 0.42796445
# step) 99882 Accuracy(IOU)= 0.42999992
# step) 99883 Accuracy(IOU)= 0.42877883
# step) 99884 Accuracy(IOU)= 0.42934343
# step) 99885 Accuracy(IOU)= 0.42600182
# step) 99886 Accuracy(IOU)= 0.4238216
# step) 99887 Accuracy(IOU)= 0.42455944
# step) 99888 Accuracy(IOU)= 0.42696413
# step) 99889 Accuracy(IOU)= 0.42760372
# step) 99890 Accuracy(IOU)= 0.42968285
# step) 99891 Accuracy(IOU)= 0.43045002
# step) 99892 Accuracy(IOU)= 0.42954355
# step) 99893 Accuracy(IOU)= 0.42981374
# step) 99894 Accuracy(IOU)= 0.42940164
# step) 99895 Accuracy(IOU)= 0.43011618
# step) 99896 Accuracy(IOU)= 0.43075106
# step) 99897 Accuracy(IOU)= 0.43642402
# step) 99898 Accuracy(IOU)= 0.43697137
# step) 99899 Accuracy(IOU)= 0.43770185
# step) 99900 Accuracy(IOU)= 0.43829304
# step) 99901 Accuracy(IOU)= 0.43742076
# step) 99902 Accuracy(IOU)= 0.4352079
# step) 99903 Accuracy(IOU)= 0.43638784
# step) 99904 Accuracy(IOU)= 0.43699655
# step) 99905 Accuracy(IOU)= 0.4348932
# step) 99906 Accuracy(IOU)= 0.43365788
# step) 99907 Accuracy(IOU)= 0.43345654
# step) 99908 Accuracy(IOU)= 0.43234387
# step) 99909 Accuracy(IOU)= 0.43154892
# step) 99910 Accuracy(IOU)= 0.43093562
# step) 99911 Accuracy(IOU)= 0.43019152
# step) 99912 Accuracy(IOU)= 0.43081522
# step) 99913 Accuracy(IOU)= 0.43180278
# step) 99914 Accuracy(IOU)= 0.43141538
# step) 99915 Accuracy(IOU)= 0.4334219
# step) 99916 Accuracy(IOU)= 0.43432075
# step) 99917 Accuracy(IOU)= 0.43345624
# step) 99918 Accuracy(IOU)= 0.43403766
# step) 99919 Accuracy(IOU)= 0.43141308
# step) 99920 Accuracy(IOU)= 0.4298751
# step) 99921 Accuracy(IOU)= 0.4275958
# step) 99922 Accuracy(IOU)= 0.42764038
# step) 99923 Accuracy(IOU)= 0.4281791
# step) 99924 Accuracy(IOU)= 0.42741036
# step) 99925 Accuracy(IOU)= 0.42760423
# step) 99926 Accuracy(IOU)= 0.42627317
# step) 99927 Accuracy(IOU)= 0.4262622
# step) 99928 Accuracy(IOU)= 0.42556903
# step) 99929 Accuracy(IOU)= 0.42377034
# step) 99930 Accuracy(IOU)= 0.42533517
# step) 99931 Accuracy(IOU)= 0.42619595
# step) 99932 Accuracy(IOU)= 0.42840013
# step) 99933 Accuracy(IOU)= 0.43016148
# step) 99934 Accuracy(IOU)= 0.4279523
# step) 99935 Accuracy(IOU)= 0.42869216
# step) 99936 Accuracy(IOU)= 0.4265511
# step) 99937 Accuracy(IOU)= 0.4261184
# step) 99938 Accuracy(IOU)= 0.42572263
# step) 99939 Accuracy(IOU)= 0.424833
# step) 99940 Accuracy(IOU)= 0.42359123
# step) 99941 Accuracy(IOU)= 0.42418176
# step) 99942 Accuracy(IOU)= 0.42380223
# step) 99943 Accuracy(IOU)= 0.4251431
# step) 99944 Accuracy(IOU)= 0.42598924
# step) 99945 Accuracy(IOU)= 0.42573416
# step) 99946 Accuracy(IOU)= 0.42679742
# step) 99947 Accuracy(IOU)= 0.424673
# step) 99948 Accuracy(IOU)= 0.42640582
# step) 99949 Accuracy(IOU)= 0.42708313
# step) 99950 Accuracy(IOU)= 0.42593127
# step) 99951 Accuracy(IOU)= 0.42668226
# step) 99952 Accuracy(IOU)= 0.427318
# step) 99953 Accuracy(IOU)= 0.42584807
# step) 99954 Accuracy(IOU)= 0.427564
# step) 99955 Accuracy(IOU)= 0.42782414
# step) 99956 Accuracy(IOU)= 0.42651123
# step) 99957 Accuracy(IOU)= 0.42705327
# step) 99958 Accuracy(IOU)= 0.42536637
# step) 99959 Accuracy(IOU)= 0.42655
# step) 99960 Accuracy(IOU)= 0.42425677
# step) 99961 Accuracy(IOU)= 0.4243386
# step) 99962 Accuracy(IOU)= 0.4273059
# step) 99963 Accuracy(IOU)= 0.42669693
# step) 99964 Accuracy(IOU)= 0.42593506
# step) 99965 Accuracy(IOU)= 0.42396155
# step) 99966 Accuracy(IOU)= 0.42284107
# step) 99967 Accuracy(IOU)= 0.42173946
# step) 99968 Accuracy(IOU)= 0.4227671
# step) 99969 Accuracy(IOU)= 0.42476457
# step) 99970 Accuracy(IOU)= 0.4250849
# step) 99971 Accuracy(IOU)= 0.42165548
# step) 99972 Accuracy(IOU)= 0.4221676
# step) 99973 Accuracy(IOU)= 0.42040104
# step) 99974 Accuracy(IOU)= 0.42114392
# step) 99975 Accuracy(IOU)= 0.42144638
# step) 99976 Accuracy(IOU)= 0.4210864
# step) 99977 Accuracy(IOU)= 0.42047074
# step) 99978 Accuracy(IOU)= 0.41957775
# step) 99979 Accuracy(IOU)= 0.41739097
# step) 99980 Accuracy(IOU)= 0.4180225
# step) 99981 Accuracy(IOU)= 0.41897434
# step) 99982 Accuracy(IOU)= 0.41768184
# step) 99983 Accuracy(IOU)= 0.41814956
# step) 99984 Accuracy(IOU)= 0.41941273
# step) 99985 Accuracy(IOU)= 0.41963303
# step) 99986 Accuracy(IOU)= 0.4183839
# step) 99987 Accuracy(IOU)= 0.41803214
# step) 99988 Accuracy(IOU)= 0.42367372
# step) 99989 Accuracy(IOU)= 0.42606232
# step) 99990 Accuracy(IOU)= 0.4265205
# step) 99991 Accuracy(IOU)= 0.42536524
# step) 99992 Accuracy(IOU)= 0.42568317
# step) 99993 Accuracy(IOU)= 0.42434913
# step) 99994 Accuracy(IOU)= 0.42398566
# step) 99995 Accuracy(IOU)= 0.4235256
# step) 99996 Accuracy(IOU)= 0.42350808
# step) 99997 Accuracy(IOU)= 0.42225137
# step) 99998 Accuracy(IOU)= 0.42039907
# step) 99999 Accuracy(IOU)= 0.42053

# %% [markdown]
# ## 调用微调后的模型

# %%
import numpy as np
import torch
import cv2
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor

# use bfloat16 for the entire script (memory efficient)
torch.autocast(device_type="cuda", dtype=torch.bfloat16).__enter__()

# %%
# Load image

image_path = r"./EarthVQA/Test/images_png/4191.png" # path to image
mask_path = r"./EarthVQA/Test/masks_png/4191.png" # path to mask, the mask will define the image region to segment

def read_image(image_path, mask_path): # read and resize image and mask
        img = cv2.imread(image_path)[...,::-1]  # read image as rgb
        mask = cv2.imread(mask_path,0) # mask of the region we want to segment

        # Resize image to maximum size of 1024

        r = np.min([1024 / img.shape[1], 1024 / img.shape[0]])
        img = cv2.resize(img, (int(img.shape[1] * r), int(img.shape[0] * r)))
        mask = cv2.resize(mask, (int(mask.shape[1] * r), int(mask.shape[0] * r)),interpolation=cv2.INTER_NEAREST)
        return img, mask
image,mask = read_image(image_path, mask_path)
num_samples = 30 # number of points/segment to sample
def get_points(mask,num_points): # Sample points inside the input mask
        points=[]
        for i in range(num_points):
            coords = np.argwhere(mask > 0)
            yx = np.array(coords[np.random.randint(len(coords))])
            points.append([[yx[1], yx[0]]])
        return np.array(points)
input_points = get_points(mask,num_samples)
# read image and sample points

# %%
# Load model
sam2_checkpoint = "./checkpoints/sam2.1_hiera_tiny.pt" # "sam2_hiera_large.pt"
model_cfg = "configs/sam2.1/sam2.1_hiera_t.yaml" # "sam2_hiera_l.yaml"
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda")

# Build net and load weights
predictor = SAM2ImagePredictor(sam2_model)
predictor.model.load_state_dict(torch.load("model_t.torch"))
# Out:
# <All keys matched successfully>

# %%
# predict mask

with torch.no_grad():
        predictor.set_image(image)
        masks, scores, logits = predictor.predict(
            point_coords=input_points,
            point_labels=np.ones([input_points.shape[0],1])
        )

# Short predicted masks from high to low score

masks=masks[:,0].astype(bool)
shorted_masks = masks[np.argsort(scores[:,0])][::-1].astype(bool)

# Stitch predicted mask into one segmentation mask

seg_map = np.zeros_like(shorted_masks[0],dtype=np.uint8)
occupancy_mask = np.zeros_like(shorted_masks[0],dtype=bool)
for i in range(shorted_masks.shape[0]):
    mask = shorted_masks[i]
    if (mask*occupancy_mask).sum()/mask.sum()>0.15: continue
    mask[occupancy_mask]=0
    seg_map[mask]=i+1
    occupancy_mask[mask]=1

# create colored annotation map
height, width = seg_map.shape

# Create an empty RGB image for the colored annotation
rgb_image = np.zeros((seg_map.shape[0], seg_map.shape[1], 3), dtype=np.uint8)
for id_class in range(1,seg_map.max()+1):
    rgb_image[seg_map == id_class] = [np.random.randint(255), np.random.randint(255), np.random.randint(255)]

# %%
# save and display

cv2.imwrite("annotation.png",rgb_image)
cv2.imwrite("mix.png",(rgb_image/2+image/2).astype(np.uint8))

cv2.imshow("annotation",rgb_image)
cv2.imshow("mix",(rgb_image/2+image/2).astype(np.uint8))
cv2.imshow("image",image)
