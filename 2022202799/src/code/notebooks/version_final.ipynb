# %% [markdown]
# # 人工智能引论大作业——遥感图像土地利用分类
# ## 2022202799
# ## Segment anything2 模型微调

# %%
import numpy as np
import torch
import cv2
import os
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor

# %%
# import data
os.chdir(r"D:\code\PycharmProjects\sam2-main")

data_dir=r"./EarthVQA/" # Path to dataset
data=[] # list of files in dataset
for ff, name in enumerate(os.listdir(data_dir+"Train/images_png/")):  # go over all folder annotation
    data.append({"image":data_dir+"Train/images_png/"+name,
                 "annotation":data_dir+"Train/masks_png/"+name})

# %%
def read_batch(data): # read random image and its annotaion from the dataset

   #  select image

        ent  = data[np.random.randint(len(data))] # choose random entry
        Img = cv2.imread(ent["image"])[...,::-1]  # read image
        ann_map = cv2.imread(ent["annotation"]) # read annotation

   # resize image

        r = np.min([1024 / Img.shape[1], 1024 / Img.shape[0]]) # scalling factor
        Img = cv2.resize(Img, (int(Img.shape[1] * r), int(Img.shape[0] * r)))
        ann_map = cv2.resize(ann_map, (int(ann_map.shape[1] * r), int(ann_map.shape[0] * r)),interpolation=cv2.INTER_NEAREST)

   # merge vessels and materials annotations

        mat_map = ann_map[:,:,0] # material annotation map
        ves_map = ann_map[:,:,2] # vessel  annotaion map
        mat_map[mat_map==0] = ves_map[mat_map==0]*(mat_map.max()+1) # merge maps

   # Get binary masks and points

        inds = np.unique(mat_map)[1:] # load all indices
        points= []
        masks = []
        for ind in inds:
            mask=(mat_map == ind).astype(np.uint8) # make binary mask corresponding to index ind
            masks.append(mask)
            coords = np.argwhere(mask > 0) # get all coordinates in mask
            yx = np.array(coords[np.random.randint(len(coords))]) # choose random point/coordinate
            points.append([[yx[1], yx[0]]])
        return Img,np.array(masks),np.array(points), np.ones([len(masks),1])

# %%
# Load model

sam2_checkpoint = "./checkpoints/sam2.1_hiera_tiny.pt" # path to model weight
model_cfg = "configs/sam2.1/sam2.1_hiera_t.yaml" #  model config
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda") # load model
predictor = SAM2ImagePredictor(sam2_model)

# %%
# Set training parameters

predictor.model.sam_mask_decoder.train(True) # enable training of mask decoder
predictor.model.sam_prompt_encoder.train(True) # enable training of prompt encoder
predictor.model.image_encoder.train(True) # enable training of image encoder

optimizer=torch.optim.AdamW(params=predictor.model.parameters(),lr=1e-5,weight_decay=4e-5)
scaler = torch.cuda.amp.GradScaler() # mixed precision

# %%
# Training loop

for itr in range(100000):
    with torch.cuda.amp.autocast(): # cast to mix precision
            image,mask,input_point, input_label = read_batch(data) # load data batch
            if mask.shape[0]==0: continue # ignore empty batches
            predictor.set_image(image) # apply SAM image encoder to the image

            # prompt encoding

            mask_input, unnorm_coords, labels, unnorm_box = predictor._prep_prompts(input_point, input_label, box=None, mask_logits=None, normalize_coords=True)
            sparse_embeddings, dense_embeddings = predictor.model.sam_prompt_encoder(points=(unnorm_coords, labels),boxes=None,masks=None,)

            # mask decoder

            batched_mode = unnorm_coords.shape[0] > 1 # multi object prediction
            high_res_features = [feat_level[-1].unsqueeze(0) for feat_level in predictor._features["high_res_feats"]]
            low_res_masks, prd_scores, _, _ = predictor.model.sam_mask_decoder(image_embeddings=predictor._features["image_embed"][-1].unsqueeze(0),image_pe=predictor.model.sam_prompt_encoder.get_dense_pe(),sparse_prompt_embeddings=sparse_embeddings,dense_prompt_embeddings=dense_embeddings,multimask_output=True,repeat_image=batched_mode,high_res_features=high_res_features,)
            prd_masks = predictor._transforms.postprocess_masks(low_res_masks, predictor._orig_hw[-1])# Upscale the masks to the original image resolution

            # Segmentaion Loss caclulation

            gt_mask = torch.tensor(mask.astype(np.float32)).cuda()
            prd_mask = torch.sigmoid(prd_masks[:, 0])# Turn logit map to probability map
            seg_loss = (-gt_mask * torch.log(prd_mask + 0.00001) - (1 - gt_mask) * torch.log((1 - prd_mask) + 0.00001)).mean() # cross entropy loss

            # Score loss calculation (intersection over union) IOU

            inter = (gt_mask * (prd_mask > 0.5)).sum(1).sum(1)
            iou = inter / (gt_mask.sum(1).sum(1) + (prd_mask > 0.5).sum(1).sum(1) - inter)
            score_loss = torch.abs(prd_scores[:, 0] - iou).mean()
            loss=seg_loss+score_loss*0.05  # mix losses

            # apply back propogation

            predictor.model.zero_grad() # empty gradient
            scaler.scale(loss).backward()  # Backpropogate
            scaler.step(optimizer)
            scaler.update() # Mix precision

            if itr%1000==0: torch.save(predictor.model.state_dict(), "model_t2.torch");print("save model")

            # Display results

            if itr==0: mean_iou=0
            mean_iou = mean_iou * 0.99 + 0.01 * np.mean(iou.cpu().detach().numpy())
            print("step)",itr, "Accuracy(IOU)=",mean_iou)
# Out:
# D:\applications\anaconda3\envs\seganything\Lib\site-packages\torch\autograd\graph.py:825: UserWarning: cuDNN SDPA backward got grad_output.strides() != output.strides(), attempting to materialize a grad_output with matching strides... (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\MHA.cpp:676.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# save model
# step) 0 Accuracy(IOU)= 0.001490251
# step) 1 Accuracy(IOU)= 0.0040940316
# step) 2 Accuracy(IOU)= 0.010401096
# step) 3 Accuracy(IOU)= 0.011958793
# step) 4 Accuracy(IOU)= 0.014766296
# step) 5 Accuracy(IOU)= 0.015562567
# step) 6 Accuracy(IOU)= 0.017849896
# step) 7 Accuracy(IOU)= 0.019079225
# step) 8 Accuracy(IOU)= 0.021858137
# step) 9 Accuracy(IOU)= 0.023235913
# step) 10 Accuracy(IOU)= 0.023809602
# step) 11 Accuracy(IOU)= 0.024385735
# step) 12 Accuracy(IOU)= 0.026455464
# step) 13 Accuracy(IOU)= 0.030895375
# step) 14 Accuracy(IOU)= 0.03622091
# step) 15 Accuracy(IOU)= 0.037712913
# step) 16 Accuracy(IOU)= 0.042635895
# step) 17 Accuracy(IOU)= 0.043978583
# step) 18 Accuracy(IOU)= 0.045517705
# step) 19 Accuracy(IOU)= 0.0464286
# step) 20 Accuracy(IOU)= 0.047168393
# step) 21 Accuracy(IOU)= 0.048368137
# step) 22 Accuracy(IOU)= 0.052247807
# step) 23 Accuracy(IOU)= 0.05302471
# step) 24 Accuracy(IOU)= 0.053973183
# step) 25 Accuracy(IOU)= 0.057672173
# step) 26 Accuracy(IOU)= 0.05969706
# step) 27 Accuracy(IOU)= 0.060045917
# step) 28 Accuracy(IOU)= 0.06360283
# step) 29 Accuracy(IOU)= 0.065804265
# step) 30 Accuracy(IOU)= 0.06756956
# step) 31 Accuracy(IOU)= 0.06768872
# step) 32 Accuracy(IOU)= 0.06955075
# step) 33 Accuracy(IOU)= 0.07065656
# step) 34 Accuracy(IOU)= 0.07477998
# step) 35 Accuracy(IOU)= 0.0762965
# step) 36 Accuracy(IOU)= 0.0791924
# step) 37 Accuracy(IOU)= 0.08248117
# step) 38 Accuracy(IOU)= 0.0838209
# step) 39 Accuracy(IOU)= 0.085035056
# step) 40 Accuracy(IOU)= 0.08724176
# step) 41 Accuracy(IOU)= 0.08859435
# step) 42 Accuracy(IOU)= 0.0908682
# step) 43 Accuracy(IOU)= 0.093260825
# step) 44 Accuracy(IOU)= 0.09381867
# step) 45 Accuracy(IOU)= 0.094090424
# step) 46 Accuracy(IOU)= 0.096460305
# step) 47 Accuracy(IOU)= 0.10024553
# step) 48 Accuracy(IOU)= 0.101111785
# step) 49 Accuracy(IOU)= 0.10590102
# step) 50 Accuracy(IOU)= 0.106323116
# step) 51 Accuracy(IOU)= 0.10730357
# step) 52 Accuracy(IOU)= 0.10726902
# step) 53 Accuracy(IOU)= 0.1072624
# step) 54 Accuracy(IOU)= 0.10757739
# step) 55 Accuracy(IOU)= 0.10976785
# step) 56 Accuracy(IOU)= 0.111160524
# step) 57 Accuracy(IOU)= 0.1139059
# step) 58 Accuracy(IOU)= 0.11459552
# step) 59 Accuracy(IOU)= 0.11624578
# step) 60 Accuracy(IOU)= 0.11753891
# step) 61 Accuracy(IOU)= 0.11839304
# step) 62 Accuracy(IOU)= 0.1189645
# step) 63 Accuracy(IOU)= 0.120652534
# step) 64 Accuracy(IOU)= 0.12138344
# step) 65 Accuracy(IOU)= 0.123201296
# step) 66 Accuracy(IOU)= 0.12779002
# step) 67 Accuracy(IOU)= 0.1284379
# step) 68 Accuracy(IOU)= 0.13135621
# step) 69 Accuracy(IOU)= 0.1332169
# step) 70 Accuracy(IOU)= 0.13374135
# step) 71 Accuracy(IOU)= 0.13645364
# step) 72 Accuracy(IOU)= 0.13635087
# step) 73 Accuracy(IOU)= 0.13811651
# step) 74 Accuracy(IOU)= 0.13834624
# step) 75 Accuracy(IOU)= 0.14219747
# step) 76 Accuracy(IOU)= 0.14379376
# step) 77 Accuracy(IOU)= 0.14524502
# step) 78 Accuracy(IOU)= 0.14806014
# step) 79 Accuracy(IOU)= 0.14939661
# step) 80 Accuracy(IOU)= 0.1515837
# step) 81 Accuracy(IOU)= 0.15698461
# step) 82 Accuracy(IOU)= 0.15899107
# step) 83 Accuracy(IOU)= 0.15857328
# step) 84 Accuracy(IOU)= 0.15957612
# step) 85 Accuracy(IOU)= 0.16023368
# step) 86 Accuracy(IOU)= 0.15909767
# step) 87 Accuracy(IOU)= 0.15867762
# step) 88 Accuracy(IOU)= 0.15761387
# step) 89 Accuracy(IOU)= 0.15841769
# step) 90 Accuracy(IOU)= 0.15802157
# step) 91 Accuracy(IOU)= 0.16062726
# step) 92 Accuracy(IOU)= 0.16134146
# step) 93 Accuracy(IOU)= 0.16244145
# step) 94 Accuracy(IOU)= 0.16252387
# step) 95 Accuracy(IOU)= 0.16280967
# step) 96 Accuracy(IOU)= 0.16146402
# step) 97 Accuracy(IOU)= 0.1629793
# step) 98 Accuracy(IOU)= 0.16303393
# step) 99 Accuracy(IOU)= 0.16386315
# step) 100 Accuracy(IOU)= 0.16536951
# step) 101 Accuracy(IOU)= 0.16656761
# step) 102 Accuracy(IOU)= 0.16704628
# step) 103 Accuracy(IOU)= 0.16860968
# step) 104 Accuracy(IOU)= 0.17117889
# step) 105 Accuracy(IOU)= 0.17117888
# step) 106 Accuracy(IOU)= 0.17187671
# step) 107 Accuracy(IOU)= 0.17202134
# step) 108 Accuracy(IOU)= 0.1734381
# step) 109 Accuracy(IOU)= 0.17489809
# step) 110 Accuracy(IOU)= 0.17631413
# step) 111 Accuracy(IOU)= 0.17865194
# step) 112 Accuracy(IOU)= 0.17910287
# step) 113 Accuracy(IOU)= 0.18315679
# step) 114 Accuracy(IOU)= 0.18413812
# step) 115 Accuracy(IOU)= 0.1849401
# step) 116 Accuracy(IOU)= 0.18489304
# step) 117 Accuracy(IOU)= 0.18488097
# step) 118 Accuracy(IOU)= 0.18820056
# step) 119 Accuracy(IOU)= 0.18721426
# step) 120 Accuracy(IOU)= 0.18597105
# step) 121 Accuracy(IOU)= 0.18587896
# step) 122 Accuracy(IOU)= 0.1855311
# step) 123 Accuracy(IOU)= 0.18652806
# step) 124 Accuracy(IOU)= 0.1855782
# step) 125 Accuracy(IOU)= 0.18575992
# step) 126 Accuracy(IOU)= 0.18565036
# step) 127 Accuracy(IOU)= 0.1870668
# step) 128 Accuracy(IOU)= 0.18824029
# step) 129 Accuracy(IOU)= 0.1909635
# step) 130 Accuracy(IOU)= 0.19238155
# step) 131 Accuracy(IOU)= 0.1919418
# step) 132 Accuracy(IOU)= 0.19256434
# step) 133 Accuracy(IOU)= 0.19351517
# step) 134 Accuracy(IOU)= 0.19275722
# step) 135 Accuracy(IOU)= 0.19610316
# step) 136 Accuracy(IOU)= 0.19697222
# step) 137 Accuracy(IOU)= 0.19622204
# step) 138 Accuracy(IOU)= 0.195563
# step) 139 Accuracy(IOU)= 0.19717248
# step) 140 Accuracy(IOU)= 0.19739753
# step) 141 Accuracy(IOU)= 0.19632868
# step) 142 Accuracy(IOU)= 0.19734366
# step) 143 Accuracy(IOU)= 0.19768223
# step) 144 Accuracy(IOU)= 0.19841528
# step) 145 Accuracy(IOU)= 0.20201734
# step) 146 Accuracy(IOU)= 0.20170859
# step) 147 Accuracy(IOU)= 0.20363037
# step) 148 Accuracy(IOU)= 0.20617667
# step) 149 Accuracy(IOU)= 0.20487921
# step) 150 Accuracy(IOU)= 0.20522279
# step) 151 Accuracy(IOU)= 0.20634833
# step) 152 Accuracy(IOU)= 0.20828578
# step) 153 Accuracy(IOU)= 0.20775831
# step) 154 Accuracy(IOU)= 0.21169224
# step) 155 Accuracy(IOU)= 0.21406513
# step) 156 Accuracy(IOU)= 0.21442471
# step) 157 Accuracy(IOU)= 0.21361543
# step) 158 Accuracy(IOU)= 0.21418117
# step) 159 Accuracy(IOU)= 0.21364158
# step) 160 Accuracy(IOU)= 0.21608813
# step) 161 Accuracy(IOU)= 0.2150713
# step) 162 Accuracy(IOU)= 0.21600157
# step) 163 Accuracy(IOU)= 0.21514754
# step) 164 Accuracy(IOU)= 0.21606195
# step) 165 Accuracy(IOU)= 0.21656324
# step) 166 Accuracy(IOU)= 0.21485792
# step) 167 Accuracy(IOU)= 0.21660887
# step) 168 Accuracy(IOU)= 0.21589164
# step) 169 Accuracy(IOU)= 0.21799214
# step) 170 Accuracy(IOU)= 0.2182779
# step) 171 Accuracy(IOU)= 0.21714675
# step) 172 Accuracy(IOU)= 0.21823658
# step) 173 Accuracy(IOU)= 0.21669413
# step) 174 Accuracy(IOU)= 0.21918735
# step) 175 Accuracy(IOU)= 0.22094133
# step) 176 Accuracy(IOU)= 0.22302243
# step) 177 Accuracy(IOU)= 0.22364691
# step) 178 Accuracy(IOU)= 0.22241959
# step) 179 Accuracy(IOU)= 0.22554371
# step) 180 Accuracy(IOU)= 0.22381562
# step) 181 Accuracy(IOU)= 0.2217872
# step) 182 Accuracy(IOU)= 0.22240725
# step) 183 Accuracy(IOU)= 0.22247607
# step) 184 Accuracy(IOU)= 0.22168885
# step) 185 Accuracy(IOU)= 0.22340101
# step) 186 Accuracy(IOU)= 0.22443548
# step) 187 Accuracy(IOU)= 0.22339568
# step) 188 Accuracy(IOU)= 0.22384727
# step) 189 Accuracy(IOU)= 0.22225279
# step) 190 Accuracy(IOU)= 0.22178937
# step) 191 Accuracy(IOU)= 0.22181207
# step) 192 Accuracy(IOU)= 0.22185816
# step) 193 Accuracy(IOU)= 0.22093777
# step) 194 Accuracy(IOU)= 0.22151043
# step) 195 Accuracy(IOU)= 0.22288305
# step) 196 Accuracy(IOU)= 0.2232513
# step) 197 Accuracy(IOU)= 0.22184445
# step) 198 Accuracy(IOU)= 0.2228743
# step) 199 Accuracy(IOU)= 0.22417139
# step) 200 Accuracy(IOU)= 0.2233236
# step) 201 Accuracy(IOU)= 0.22312067
# step) 202 Accuracy(IOU)= 0.22321594
# step) 203 Accuracy(IOU)= 0.22212523
# step) 204 Accuracy(IOU)= 0.22064327
# step) 205 Accuracy(IOU)= 0.2207058
# step) 206 Accuracy(IOU)= 0.22057109
# step) 207 Accuracy(IOU)= 0.22244336
# step) 208 Accuracy(IOU)= 0.2223051
# step) 209 Accuracy(IOU)= 0.2242865
# step) 210 Accuracy(IOU)= 0.2263629
# step) 211 Accuracy(IOU)= 0.22487992
# step) 212 Accuracy(IOU)= 0.22448397
# step) 213 Accuracy(IOU)= 0.22244748
# step) 214 Accuracy(IOU)= 0.22287622
# step) 215 Accuracy(IOU)= 0.22247031
# step) 216 Accuracy(IOU)= 0.22400506
# step) 217 Accuracy(IOU)= 0.22479953
# step) 218 Accuracy(IOU)= 0.22536288
# step) 219 Accuracy(IOU)= 0.22802715
# step) 220 Accuracy(IOU)= 0.23272438
# step) 221 Accuracy(IOU)= 0.23465556
# step) 222 Accuracy(IOU)= 0.23465495
# step) 223 Accuracy(IOU)= 0.23311193
# step) 224 Accuracy(IOU)= 0.23303136
# step) 225 Accuracy(IOU)= 0.23284653
# step) 226 Accuracy(IOU)= 0.23161903
# step) 227 Accuracy(IOU)= 0.23177189
# step) 228 Accuracy(IOU)= 0.23107219
# step) 229 Accuracy(IOU)= 0.22960198
# step) 230 Accuracy(IOU)= 0.23376459
# step) 231 Accuracy(IOU)= 0.23483695
# step) 232 Accuracy(IOU)= 0.2344746
# step) 233 Accuracy(IOU)= 0.23434676
# step) 234 Accuracy(IOU)= 0.23470728
# step) 235 Accuracy(IOU)= 0.23451492
# step) 236 Accuracy(IOU)= 0.23402935
# step) 237 Accuracy(IOU)= 0.2329197
# step) 238 Accuracy(IOU)= 0.23394814
# step) 239 Accuracy(IOU)= 0.23447242
# step) 240 Accuracy(IOU)= 0.23430139
# step) 241 Accuracy(IOU)= 0.23397823
# step) 242 Accuracy(IOU)= 0.2382618
# step) 243 Accuracy(IOU)= 0.23702969
# step) 244 Accuracy(IOU)= 0.23688784
# step) 245 Accuracy(IOU)= 0.23547451
# step) 246 Accuracy(IOU)= 0.23780417
# step) 247 Accuracy(IOU)= 0.23845235
# step) 248 Accuracy(IOU)= 0.23658206
# step) 249 Accuracy(IOU)= 0.23501009
# step) 250 Accuracy(IOU)= 0.23499481
# step) 251 Accuracy(IOU)= 0.23626664
# step) 252 Accuracy(IOU)= 0.2361839
# step) 253 Accuracy(IOU)= 0.23681742
# step) 254 Accuracy(IOU)= 0.2378077
# step) 255 Accuracy(IOU)= 0.23741376
# step) 256 Accuracy(IOU)= 0.23713063
# step) 257 Accuracy(IOU)= 0.23551829
# step) 258 Accuracy(IOU)= 0.233881
# step) 259 Accuracy(IOU)= 0.23472086
# step) 260 Accuracy(IOU)= 0.23458368
# step) 261 Accuracy(IOU)= 0.23790886
# step) 262 Accuracy(IOU)= 0.23587768
# step) 263 Accuracy(IOU)= 0.23885897
# step) 264 Accuracy(IOU)= 0.24027744
# step) 265 Accuracy(IOU)= 0.24124199
# step) 266 Accuracy(IOU)= 0.23944904
# step) 267 Accuracy(IOU)= 0.24047233
# step) 268 Accuracy(IOU)= 0.23885643
# step) 269 Accuracy(IOU)= 0.2405865
# step) 270 Accuracy(IOU)= 0.24112241
# step) 271 Accuracy(IOU)= 0.23930973
# step) 272 Accuracy(IOU)= 0.239951
# step) 273 Accuracy(IOU)= 0.24020523
# step) 274 Accuracy(IOU)= 0.2393308
# step) 275 Accuracy(IOU)= 0.2394124
# step) 276 Accuracy(IOU)= 0.23901209
# step) 277 Accuracy(IOU)= 0.24220802
# step) 278 Accuracy(IOU)= 0.2412672
# step) 279 Accuracy(IOU)= 0.23930363
# step) 280 Accuracy(IOU)= 0.24047104
# step) 281 Accuracy(IOU)= 0.239362
# step) 282 Accuracy(IOU)= 0.23854172
# step) 283 Accuracy(IOU)= 0.23819084
# step) 284 Accuracy(IOU)= 0.23765372
# step) 285 Accuracy(IOU)= 0.2368578
# step) 286 Accuracy(IOU)= 0.23770034
# step) 287 Accuracy(IOU)= 0.23857251
# step) 288 Accuracy(IOU)= 0.2421275
# step) 289 Accuracy(IOU)= 0.2434703
# step) 290 Accuracy(IOU)= 0.24298069
# step) 291 Accuracy(IOU)= 0.24419875
# step) 292 Accuracy(IOU)= 0.24387364
# step) 293 Accuracy(IOU)= 0.244969
# step) 294 Accuracy(IOU)= 0.24622545
# step) 295 Accuracy(IOU)= 0.2517793
# step) 296 Accuracy(IOU)= 0.25134724
# step) 297 Accuracy(IOU)= 0.25061306
# step) 298 Accuracy(IOU)= 0.251165
# step) 299 Accuracy(IOU)= 0.24957602
# step) 300 Accuracy(IOU)= 0.25188786
# step) 301 Accuracy(IOU)= 0.2518016
# step) 302 Accuracy(IOU)= 0.25039014
# step) 303 Accuracy(IOU)= 0.2509161
# step) 304 Accuracy(IOU)= 0.25138593
# step) 305 Accuracy(IOU)= 0.25084525
# step) 306 Accuracy(IOU)= 0.25223705
# step) 307 Accuracy(IOU)= 0.2546482
# step) 308 Accuracy(IOU)= 0.25474185
# step) 309 Accuracy(IOU)= 0.25410494
# step) 310 Accuracy(IOU)= 0.25387877
# step) 311 Accuracy(IOU)= 0.25225276
# step) 312 Accuracy(IOU)= 0.25248143
# step) 313 Accuracy(IOU)= 0.25121
# step) 314 Accuracy(IOU)= 0.25090656
# step) 315 Accuracy(IOU)= 0.25064808
# step) 316 Accuracy(IOU)= 0.25183225
# step) 317 Accuracy(IOU)= 0.25241756
# step) 318 Accuracy(IOU)= 0.25281084
# step) 319 Accuracy(IOU)= 0.25290215
# step) 320 Accuracy(IOU)= 0.25384143
# step) 321 Accuracy(IOU)= 0.2543406
# step) 322 Accuracy(IOU)= 0.2539061
# step) 323 Accuracy(IOU)= 0.2525451
# step) 324 Accuracy(IOU)= 0.25242728
# step) 325 Accuracy(IOU)= 0.25117254
# step) 326 Accuracy(IOU)= 0.24905457
# step) 327 Accuracy(IOU)= 0.24949962
# step) 328 Accuracy(IOU)= 0.24973908
# step) 329 Accuracy(IOU)= 0.25068372
# step) 330 Accuracy(IOU)= 0.25266036
# step) 331 Accuracy(IOU)= 0.25316572
# step) 332 Accuracy(IOU)= 0.25312662
# step) 333 Accuracy(IOU)= 0.25276744
# step) 334 Accuracy(IOU)= 0.25238514
# step) 335 Accuracy(IOU)= 0.25377294
# step) 336 Accuracy(IOU)= 0.25501487
# step) 337 Accuracy(IOU)= 0.25461525
# step) 338 Accuracy(IOU)= 0.2531671
# step) 339 Accuracy(IOU)= 0.25356582
# step) 340 Accuracy(IOU)= 0.25313035
# step) 341 Accuracy(IOU)= 0.25233057
# step) 342 Accuracy(IOU)= 0.2509208
# step) 343 Accuracy(IOU)= 0.24909215
# step) 344 Accuracy(IOU)= 0.24900278
# step) 345 Accuracy(IOU)= 0.24885271
# step) 346 Accuracy(IOU)= 0.25059453
# step) 347 Accuracy(IOU)= 0.25263733
# step) 348 Accuracy(IOU)= 0.25530744
# step) 349 Accuracy(IOU)= 0.25541857
# step) 350 Accuracy(IOU)= 0.25307816
# step) 351 Accuracy(IOU)= 0.25249085
# step) 352 Accuracy(IOU)= 0.25353056
# step) 353 Accuracy(IOU)= 0.25208485
# step) 354 Accuracy(IOU)= 0.2519694
# step) 355 Accuracy(IOU)= 0.25266925
# step) 356 Accuracy(IOU)= 0.2519158
# step) 357 Accuracy(IOU)= 0.25218216
# step) 358 Accuracy(IOU)= 0.25349826
# step) 359 Accuracy(IOU)= 0.25421152
# step) 360 Accuracy(IOU)= 0.2544311
# step) 361 Accuracy(IOU)= 0.25411537
# step) 362 Accuracy(IOU)= 0.25516486
# step) 363 Accuracy(IOU)= 0.25567037
# step) 364 Accuracy(IOU)= 0.25582245
# step) 365 Accuracy(IOU)= 0.2552855
# step) 366 Accuracy(IOU)= 0.25592387
# step) 367 Accuracy(IOU)= 0.25666893
# step) 368 Accuracy(IOU)= 0.2564527
# step) 369 Accuracy(IOU)= 0.2567948
# step) 370 Accuracy(IOU)= 0.25781843
# step) 371 Accuracy(IOU)= 0.25691512
# step) 372 Accuracy(IOU)= 0.2615976
# step) 373 Accuracy(IOU)= 0.26271078
# step) 374 Accuracy(IOU)= 0.2614527
# step) 375 Accuracy(IOU)= 0.2599193
# step) 376 Accuracy(IOU)= 0.26040846
# step) 377 Accuracy(IOU)= 0.26062286
# step) 378 Accuracy(IOU)= 0.25956827
# step) 379 Accuracy(IOU)= 0.25807852
# step) 380 Accuracy(IOU)= 0.26050368
# step) 381 Accuracy(IOU)= 0.26038438
# step) 382 Accuracy(IOU)= 0.25996453
# step) 383 Accuracy(IOU)= 0.25922042
# step) 384 Accuracy(IOU)= 0.25793713
# step) 385 Accuracy(IOU)= 0.25631264
# step) 386 Accuracy(IOU)= 0.2557832
# step) 387 Accuracy(IOU)= 0.2562183
# step) 388 Accuracy(IOU)= 0.25786656
# step) 389 Accuracy(IOU)= 0.2578148
# step) 390 Accuracy(IOU)= 0.25814763
# step) 391 Accuracy(IOU)= 0.25659546
# step) 392 Accuracy(IOU)= 0.25944647
# step) 393 Accuracy(IOU)= 0.26354277
# step) 394 Accuracy(IOU)= 0.26501486
# step) 395 Accuracy(IOU)= 0.26439616
# step) 396 Accuracy(IOU)= 0.26428258
# step) 397 Accuracy(IOU)= 0.26660138
# step) 398 Accuracy(IOU)= 0.26652935
# step) 399 Accuracy(IOU)= 0.26503566
# step) 400 Accuracy(IOU)= 0.2654653
# step) 401 Accuracy(IOU)= 0.26536533
# step) 402 Accuracy(IOU)= 0.26513213
# step) 403 Accuracy(IOU)= 0.26561415
# step) 404 Accuracy(IOU)= 0.26741588
# step) 405 Accuracy(IOU)= 0.2650553
# step) 406 Accuracy(IOU)= 0.2647482
# step) 407 Accuracy(IOU)= 0.26423988
# step) 408 Accuracy(IOU)= 0.26389927
# step) 409 Accuracy(IOU)= 0.26742053
# step) 410 Accuracy(IOU)= 0.26578575
# step) 411 Accuracy(IOU)= 0.26479837
# step) 412 Accuracy(IOU)= 0.26326007
# step) 413 Accuracy(IOU)= 0.26114094
# step) 414 Accuracy(IOU)= 0.26510614
# step) 415 Accuracy(IOU)= 0.26374066
# step) 416 Accuracy(IOU)= 0.26496285
# step) 417 Accuracy(IOU)= 0.26415572
# step) 418 Accuracy(IOU)= 0.26436454
# step) 419 Accuracy(IOU)= 0.2643007
# step) 420 Accuracy(IOU)= 0.2646992
# step) 421 Accuracy(IOU)= 0.26525325
# step) 422 Accuracy(IOU)= 0.26435995
# step) 423 Accuracy(IOU)= 0.26387537
# step) 424 Accuracy(IOU)= 0.2638705
# step) 425 Accuracy(IOU)= 0.26194948
# step) 426 Accuracy(IOU)= 0.26016453
# step) 427 Accuracy(IOU)= 0.25968665
# step) 428 Accuracy(IOU)= 0.2588952
# step) 429 Accuracy(IOU)= 0.25812784
# step) 430 Accuracy(IOU)= 0.25947362
# step) 431 Accuracy(IOU)= 0.25962502
# step) 432 Accuracy(IOU)= 0.2598477
# step) 433 Accuracy(IOU)= 0.26042083
# step) 434 Accuracy(IOU)= 0.2611661
# step) 435 Accuracy(IOU)= 0.25917178
# step) 436 Accuracy(IOU)= 0.25780883
# step) 437 Accuracy(IOU)= 0.26087487
# step) 438 Accuracy(IOU)= 0.261509
# step) 439 Accuracy(IOU)= 0.26022264
# step) 440 Accuracy(IOU)= 0.25809672
# step) 441 Accuracy(IOU)= 0.25807536
# step) 442 Accuracy(IOU)= 0.25825557
# step) 443 Accuracy(IOU)= 0.25581098
# step) 444 Accuracy(IOU)= 0.25400934
# step) 445 Accuracy(IOU)= 0.25457796
# step) 446 Accuracy(IOU)= 0.25299492
# step) 447 Accuracy(IOU)= 0.2513429
# step) 448 Accuracy(IOU)= 0.2508711
# step) 449 Accuracy(IOU)= 0.2523206
# step) 450 Accuracy(IOU)= 0.25068298
# step) 451 Accuracy(IOU)= 0.25083992
# step) 452 Accuracy(IOU)= 0.2503471
# step) 453 Accuracy(IOU)= 0.25007564
# step) 454 Accuracy(IOU)= 0.25381818
# step) 455 Accuracy(IOU)= 0.25557357
# step) 456 Accuracy(IOU)= 0.25701013
# step) 457 Accuracy(IOU)= 0.2607812
# step) 458 Accuracy(IOU)= 0.2625755
# step) 459 Accuracy(IOU)= 0.2644145
# step) 460 Accuracy(IOU)= 0.26271558
# step) 461 Accuracy(IOU)= 0.26268443
# step) 462 Accuracy(IOU)= 0.2647988
# step) 463 Accuracy(IOU)= 0.26437467
# step) 464 Accuracy(IOU)= 0.2650098
# step) 465 Accuracy(IOU)= 0.26661095
# step) 466 Accuracy(IOU)= 0.2678451
# step) 467 Accuracy(IOU)= 0.26959705
# step) 468 Accuracy(IOU)= 0.27086088
# step) 469 Accuracy(IOU)= 0.27051315
# step) 470 Accuracy(IOU)= 0.27157483
# step) 471 Accuracy(IOU)= 0.27373666
# step) 472 Accuracy(IOU)= 0.27437663
# step) 473 Accuracy(IOU)= 0.27395666
# step) 474 Accuracy(IOU)= 0.27666664
# step) 475 Accuracy(IOU)= 0.2762077
# step) 476 Accuracy(IOU)= 0.278364
# step) 477 Accuracy(IOU)= 0.27572376
# step) 478 Accuracy(IOU)= 0.27770507
# step) 479 Accuracy(IOU)= 0.2754895
# step) 480 Accuracy(IOU)= 0.2775261
# step) 481 Accuracy(IOU)= 0.27650326
# step) 482 Accuracy(IOU)= 0.27618232
# step) 483 Accuracy(IOU)= 0.27467954
# step) 484 Accuracy(IOU)= 0.2751811
# step) 485 Accuracy(IOU)= 0.27663866
# step) 486 Accuracy(IOU)= 0.2752338
# step) 487 Accuracy(IOU)= 0.2779125
# step) 488 Accuracy(IOU)= 0.2803211
# step) 489 Accuracy(IOU)= 0.28107318
# step) 490 Accuracy(IOU)= 0.28034094
# step) 491 Accuracy(IOU)= 0.27999145
# step) 492 Accuracy(IOU)= 0.27951705
# step) 493 Accuracy(IOU)= 0.28066537
# step) 494 Accuracy(IOU)= 0.28365824
# step) 495 Accuracy(IOU)= 0.28323892
# step) 496 Accuracy(IOU)= 0.28172123
# step) 497 Accuracy(IOU)= 0.28199932
# step) 498 Accuracy(IOU)= 0.28233424
# step) 499 Accuracy(IOU)= 0.28224733
# step) 500 Accuracy(IOU)= 0.28159714
# step) 501 Accuracy(IOU)= 0.2876218
# step) 502 Accuracy(IOU)= 0.28983566
# step) 503 Accuracy(IOU)= 0.29245093
# step) 504 Accuracy(IOU)= 0.2909047
# step) 505 Accuracy(IOU)= 0.2899965
# step) 506 Accuracy(IOU)= 0.28863746
# step) 507 Accuracy(IOU)= 0.2871369
# step) 508 Accuracy(IOU)= 0.28683984
# step) 509 Accuracy(IOU)= 0.28662255
# step) 510 Accuracy(IOU)= 0.2858235
# step) 511 Accuracy(IOU)= 0.2862367
# step) 512 Accuracy(IOU)= 0.28500912
# step) 513 Accuracy(IOU)= 0.28381965
# step) 514 Accuracy(IOU)= 0.28193244
# step) 515 Accuracy(IOU)= 0.2835756
# step) 516 Accuracy(IOU)= 0.2811899
# step) 517 Accuracy(IOU)= 0.28390563
# step) 518 Accuracy(IOU)= 0.282709
# step) 519 Accuracy(IOU)= 0.28069612
# step) 520 Accuracy(IOU)= 0.27935296
# step) 521 Accuracy(IOU)= 0.27782366
# step) 522 Accuracy(IOU)= 0.27636847
# step) 523 Accuracy(IOU)= 0.28175226
# step) 524 Accuracy(IOU)= 0.2862427
# step) 525 Accuracy(IOU)= 0.28753033
# step) 526 Accuracy(IOU)= 0.28555867
# step) 527 Accuracy(IOU)= 0.28508577
# step) 528 Accuracy(IOU)= 0.2851538
# step) 529 Accuracy(IOU)= 0.28241965
# step) 530 Accuracy(IOU)= 0.2852216
# step) 531 Accuracy(IOU)= 0.2836576
# step) 532 Accuracy(IOU)= 0.28379974
# step) 533 Accuracy(IOU)= 0.28184518
# step) 534 Accuracy(IOU)= 0.2806639
# step) 535 Accuracy(IOU)= 0.28047928
# step) 536 Accuracy(IOU)= 0.2829373
# step) 537 Accuracy(IOU)= 0.2803801
# step) 538 Accuracy(IOU)= 0.2793375
# step) 539 Accuracy(IOU)= 0.27891114
# step) 540 Accuracy(IOU)= 0.27899614
# step) 541 Accuracy(IOU)= 0.28083923
# step) 542 Accuracy(IOU)= 0.27970412
# step) 543 Accuracy(IOU)= 0.286839
# step) 544 Accuracy(IOU)= 0.2847266
# step) 545 Accuracy(IOU)= 0.28380048
# step) 546 Accuracy(IOU)= 0.28337973
# step) 547 Accuracy(IOU)= 0.28158835
# step) 548 Accuracy(IOU)= 0.28336778
# step) 549 Accuracy(IOU)= 0.28202406
# step) 550 Accuracy(IOU)= 0.28187528
# step) 551 Accuracy(IOU)= 0.279993
# step) 552 Accuracy(IOU)= 0.2784941
# step) 553 Accuracy(IOU)= 0.27743286
# step) 554 Accuracy(IOU)= 0.27575576
# step) 555 Accuracy(IOU)= 0.27432582
# step) 556 Accuracy(IOU)= 0.27471185
# step) 557 Accuracy(IOU)= 0.27347043
# step) 558 Accuracy(IOU)= 0.27409172
# step) 559 Accuracy(IOU)= 0.27330205
# step) 560 Accuracy(IOU)= 0.2737704
# step) 561 Accuracy(IOU)= 0.27386302
# step) 562 Accuracy(IOU)= 0.2734188
# step) 563 Accuracy(IOU)= 0.27305546
# step) 564 Accuracy(IOU)= 0.27280977
# step) 565 Accuracy(IOU)= 0.27207473
# step) 566 Accuracy(IOU)= 0.2716413
# step) 567 Accuracy(IOU)= 0.27024361
# step) 568 Accuracy(IOU)= 0.27119726
# step) 569 Accuracy(IOU)= 0.27060646
# step) 570 Accuracy(IOU)= 0.27210465
# step) 571 Accuracy(IOU)= 0.27072176
# step) 572 Accuracy(IOU)= 0.2713188
# step) 573 Accuracy(IOU)= 0.27089942
# step) 574 Accuracy(IOU)= 0.2737418
# step) 575 Accuracy(IOU)= 0.27338174
# step) 576 Accuracy(IOU)= 0.27416092
# step) 577 Accuracy(IOU)= 0.27176532
# step) 578 Accuracy(IOU)= 0.27146202
# step) 579 Accuracy(IOU)= 0.271371
# step) 580 Accuracy(IOU)= 0.27127823
# step) 581 Accuracy(IOU)= 0.26985186
# step) 582 Accuracy(IOU)= 0.2771035
# step) 583 Accuracy(IOU)= 0.2757232
# step) 584 Accuracy(IOU)= 0.27606642
# step) 585 Accuracy(IOU)= 0.2783646
# step) 586 Accuracy(IOU)= 0.27641684
# step) 587 Accuracy(IOU)= 0.27599463
# step) 589 Accuracy(IOU)= 0.27548096
# step) 590 Accuracy(IOU)= 0.28095493
# step) 591 Accuracy(IOU)= 0.28172225
# step) 592 Accuracy(IOU)= 0.28381938
# step) 593 Accuracy(IOU)= 0.28493327
# step) 594 Accuracy(IOU)= 0.28511918
# step) 595 Accuracy(IOU)= 0.28277415
# step) 596 Accuracy(IOU)= 0.28144357
# step) 597 Accuracy(IOU)= 0.27878588
# step) 598 Accuracy(IOU)= 0.27954906
# step) 599 Accuracy(IOU)= 0.27964506
# step) 600 Accuracy(IOU)= 0.28168377
# step) 601 Accuracy(IOU)= 0.28080335
# step) 602 Accuracy(IOU)= 0.28143364
# step) 603 Accuracy(IOU)= 0.28096265
# step) 604 Accuracy(IOU)= 0.27886993
# step) 605 Accuracy(IOU)= 0.27810878
# step) 606 Accuracy(IOU)= 0.2763021
# step) 607 Accuracy(IOU)= 0.27618408
# step) 608 Accuracy(IOU)= 0.27636757
# step) 609 Accuracy(IOU)= 0.2742912
# step) 610 Accuracy(IOU)= 0.2768903
# step) 611 Accuracy(IOU)= 0.27785218
# step) 612 Accuracy(IOU)= 0.27638432
# step) 613 Accuracy(IOU)= 0.27567402
# step) 614 Accuracy(IOU)= 0.28001282
# step) 615 Accuracy(IOU)= 0.28048596
# step) 616 Accuracy(IOU)= 0.28755403
# step) 617 Accuracy(IOU)= 0.28518426
# step) 618 Accuracy(IOU)= 0.2848716
# step) 619 Accuracy(IOU)= 0.28386173
# step) 620 Accuracy(IOU)= 0.28478992
# step) 621 Accuracy(IOU)= 0.28748772
# step) 622 Accuracy(IOU)= 0.28891405
# step) 623 Accuracy(IOU)= 0.28640273
# step) 624 Accuracy(IOU)= 0.28418285
# step) 625 Accuracy(IOU)= 0.28173485
# step) 626 Accuracy(IOU)= 0.28110904
# step) 627 Accuracy(IOU)= 0.280586
# step) 628 Accuracy(IOU)= 0.2784067
# step) 629 Accuracy(IOU)= 0.28047565
# step) 630 Accuracy(IOU)= 0.2803213
# step) 631 Accuracy(IOU)= 0.28730664
# step) 632 Accuracy(IOU)= 0.2892755
# step) 633 Accuracy(IOU)= 0.28763703
# step) 634 Accuracy(IOU)= 0.2856863
# step) 635 Accuracy(IOU)= 0.28675067
# step) 636 Accuracy(IOU)= 0.28460643
# step) 637 Accuracy(IOU)= 0.2866672
# step) 638 Accuracy(IOU)= 0.28732148
# step) 639 Accuracy(IOU)= 0.2856323
# step) 640 Accuracy(IOU)= 0.28484234
# step) 641 Accuracy(IOU)= 0.28465506
# step) 642 Accuracy(IOU)= 0.2848259
# step) 643 Accuracy(IOU)= 0.2862505
# step) 644 Accuracy(IOU)= 0.28791168
# step) 645 Accuracy(IOU)= 0.2866768
# step) 646 Accuracy(IOU)= 0.28754398
# step) 647 Accuracy(IOU)= 0.28938478
# step) 648 Accuracy(IOU)= 0.2869261
# step) 649 Accuracy(IOU)= 0.28779644
# step) 650 Accuracy(IOU)= 0.28891942
# step) 651 Accuracy(IOU)= 0.29001096
# step) 652 Accuracy(IOU)= 0.29177222
# step) 653 Accuracy(IOU)= 0.28904667
# step) 654 Accuracy(IOU)= 0.28952992
# step) 655 Accuracy(IOU)= 0.29063833
# step) 656 Accuracy(IOU)= 0.2890231
# step) 657 Accuracy(IOU)= 0.2914686
# step) 658 Accuracy(IOU)= 0.291671
# step) 659 Accuracy(IOU)= 0.29126024
# step) 660 Accuracy(IOU)= 0.2908738
# step) 661 Accuracy(IOU)= 0.2912698
# step) 662 Accuracy(IOU)= 0.28960526
# step) 663 Accuracy(IOU)= 0.2867786
# step) 664 Accuracy(IOU)= 0.28843126
# step) 665 Accuracy(IOU)= 0.28744072
# step) 666 Accuracy(IOU)= 0.28925055
# step) 667 Accuracy(IOU)= 0.28819624
# step) 668 Accuracy(IOU)= 0.2902999
# step) 669 Accuracy(IOU)= 0.29030752
# step) 670 Accuracy(IOU)= 0.28981823
# step) 671 Accuracy(IOU)= 0.2903194
# step) 672 Accuracy(IOU)= 0.29115328
# step) 673 Accuracy(IOU)= 0.29034537
# step) 674 Accuracy(IOU)= 0.2956364
# step) 675 Accuracy(IOU)= 0.29610282
# step) 676 Accuracy(IOU)= 0.2964191
# step) 677 Accuracy(IOU)= 0.29459113
# step) 678 Accuracy(IOU)= 0.29607642
# step) 679 Accuracy(IOU)= 0.294103
# step) 680 Accuracy(IOU)= 0.29306948
# step) 681 Accuracy(IOU)= 0.291679
# step) 682 Accuracy(IOU)= 0.2924919
# step) 683 Accuracy(IOU)= 0.29336387
# step) 684 Accuracy(IOU)= 0.29382128
# step) 685 Accuracy(IOU)= 0.29393598
# step) 686 Accuracy(IOU)= 0.294426
# step) 687 Accuracy(IOU)= 0.29511213
# step) 688 Accuracy(IOU)= 0.29465672
# step) 689 Accuracy(IOU)= 0.29502118
# step) 690 Accuracy(IOU)= 0.29532686
# step) 691 Accuracy(IOU)= 0.29420224
# step) 692 Accuracy(IOU)= 0.2948
# step) 693 Accuracy(IOU)= 0.2948751
# step) 694 Accuracy(IOU)= 0.29376256
# step) 695 Accuracy(IOU)= 0.29251236
# step) 696 Accuracy(IOU)= 0.2910954
# step) 697 Accuracy(IOU)= 0.2895014
# step) 698 Accuracy(IOU)= 0.28841883
# step) 699 Accuracy(IOU)= 0.28742203
# step) 700 Accuracy(IOU)= 0.2888242
# step) 701 Accuracy(IOU)= 0.28746355
# step) 702 Accuracy(IOU)= 0.28549883
# step) 703 Accuracy(IOU)= 0.28690475
# step) 704 Accuracy(IOU)= 0.28671065
# step) 705 Accuracy(IOU)= 0.2845588
# step) 706 Accuracy(IOU)= 0.28225234
# step) 707 Accuracy(IOU)= 0.27962992
# step) 708 Accuracy(IOU)= 0.2817977
# step) 709 Accuracy(IOU)= 0.28188574
# step) 710 Accuracy(IOU)= 0.2798076
# step) 711 Accuracy(IOU)= 0.27992937
# step) 712 Accuracy(IOU)= 0.27984932
# step) 713 Accuracy(IOU)= 0.2778947
# step) 714 Accuracy(IOU)= 0.27813113
# step) 715 Accuracy(IOU)= 0.278872
# step) 716 Accuracy(IOU)= 0.27902466
# step) 717 Accuracy(IOU)= 0.2821619
# step) 718 Accuracy(IOU)= 0.2830338
# step) 719 Accuracy(IOU)= 0.28094032
# step) 720 Accuracy(IOU)= 0.2798209
# step) 721 Accuracy(IOU)= 0.27967682
# step) 722 Accuracy(IOU)= 0.2788682
# step) 723 Accuracy(IOU)= 0.27791655
# step) 724 Accuracy(IOU)= 0.27538708
# step) 725 Accuracy(IOU)= 0.27461177
# step) 726 Accuracy(IOU)= 0.2742833
# step) 727 Accuracy(IOU)= 0.27562192
# step) 728 Accuracy(IOU)= 0.2743071
# step) 729 Accuracy(IOU)= 0.2745121
# step) 730 Accuracy(IOU)= 0.27548924
# step) 731 Accuracy(IOU)= 0.27485466
# step) 732 Accuracy(IOU)= 0.27512184
# step) 733 Accuracy(IOU)= 0.27579275
# step) 734 Accuracy(IOU)= 0.27346328
# step) 735 Accuracy(IOU)= 0.27247885
# step) 736 Accuracy(IOU)= 0.27554318
# step) 737 Accuracy(IOU)= 0.27473414
# step) 738 Accuracy(IOU)= 0.27403513
# step) 739 Accuracy(IOU)= 0.27470943
# step) 740 Accuracy(IOU)= 0.27231437
# step) 741 Accuracy(IOU)= 0.272157
# step) 742 Accuracy(IOU)= 0.27021825
# step) 743 Accuracy(IOU)= 0.27144083
# step) 744 Accuracy(IOU)= 0.26989788
# step) 745 Accuracy(IOU)= 0.26915482
# step) 746 Accuracy(IOU)= 0.26652154
# step) 747 Accuracy(IOU)= 0.26905397
# step) 748 Accuracy(IOU)= 0.2698373
# step) 749 Accuracy(IOU)= 0.2676018
# step) 750 Accuracy(IOU)= 0.26726058
# step) 751 Accuracy(IOU)= 0.26707542
# step) 752 Accuracy(IOU)= 0.26722255
# step) 753 Accuracy(IOU)= 0.26598626
# step) 754 Accuracy(IOU)= 0.2661667
# step) 755 Accuracy(IOU)= 0.26550213
# step) 756 Accuracy(IOU)= 0.26464012
# step) 757 Accuracy(IOU)= 0.26442245
# step) 758 Accuracy(IOU)= 0.26459065
# step) 759 Accuracy(IOU)= 0.26307043
# step) 760 Accuracy(IOU)= 0.2643908
# step) 761 Accuracy(IOU)= 0.261768
# step) 762 Accuracy(IOU)= 0.25968823
# step) 763 Accuracy(IOU)= 0.26023182
# step) 764 Accuracy(IOU)= 0.26304096
# step) 765 Accuracy(IOU)= 0.26432854
# step) 766 Accuracy(IOU)= 0.26454365
# step) 767 Accuracy(IOU)= 0.26785865
# step) 768 Accuracy(IOU)= 0.26714432
# step) 769 Accuracy(IOU)= 0.26646444
# step) 770 Accuracy(IOU)= 0.26562524
# step) 771 Accuracy(IOU)= 0.26621887
# step) 772 Accuracy(IOU)= 0.26673782
# step) 773 Accuracy(IOU)= 0.26976654
# step) 774 Accuracy(IOU)= 0.27000976
# step) 775 Accuracy(IOU)= 0.27116477
# step) 776 Accuracy(IOU)= 0.2716841
# step) 777 Accuracy(IOU)= 0.2719093
# step) 778 Accuracy(IOU)= 0.27012482
# step) 779 Accuracy(IOU)= 0.2723124
# step) 780 Accuracy(IOU)= 0.27343673
# step) 781 Accuracy(IOU)= 0.27305812
# step) 782 Accuracy(IOU)= 0.27326697
# step) 783 Accuracy(IOU)= 0.2753125
# step) 784 Accuracy(IOU)= 0.27318665
# step) 785 Accuracy(IOU)= 0.2728457
# step) 786 Accuracy(IOU)= 0.27180412
# step) 787 Accuracy(IOU)= 0.27172887
# step) 788 Accuracy(IOU)= 0.27389193
# step) 789 Accuracy(IOU)= 0.27403143
# step) 790 Accuracy(IOU)= 0.2763827
# step) 791 Accuracy(IOU)= 0.2750614
# step) 792 Accuracy(IOU)= 0.27500033
# step) 793 Accuracy(IOU)= 0.27613035
# step) 794 Accuracy(IOU)= 0.27793735
# step) 795 Accuracy(IOU)= 0.27794802
# step) 796 Accuracy(IOU)= 0.27774388
# step) 797 Accuracy(IOU)= 0.27779552
# step) 798 Accuracy(IOU)= 0.2781358
# step) 799 Accuracy(IOU)= 0.27891746
# step) 800 Accuracy(IOU)= 0.2766462
# step) 801 Accuracy(IOU)= 0.27594274
# step) 802 Accuracy(IOU)= 0.27367046
# step) 803 Accuracy(IOU)= 0.271876
# step) 804 Accuracy(IOU)= 0.27187148
# step) 805 Accuracy(IOU)= 0.27282602
# step) 806 Accuracy(IOU)= 0.2735205
# step) 807 Accuracy(IOU)= 0.27080426
# step) 808 Accuracy(IOU)= 0.27177137
# step) 809 Accuracy(IOU)= 0.27072832
# step) 810 Accuracy(IOU)= 0.2705243
# step) 811 Accuracy(IOU)= 0.27094942
# step) 812 Accuracy(IOU)= 0.2722753
# step) 813 Accuracy(IOU)= 0.27223358
# step) 814 Accuracy(IOU)= 0.27401322
# step) 815 Accuracy(IOU)= 0.2736405
# step) 816 Accuracy(IOU)= 0.27369455
# step) 817 Accuracy(IOU)= 0.27553916
# step) 818 Accuracy(IOU)= 0.27947408
# step) 819 Accuracy(IOU)= 0.28155562
# step) 820 Accuracy(IOU)= 0.28279945
# step) 821 Accuracy(IOU)= 0.28143224
# step) 822 Accuracy(IOU)= 0.2798146
# step) 823 Accuracy(IOU)= 0.28048715
# step) 824 Accuracy(IOU)= 0.28399277
# step) 825 Accuracy(IOU)= 0.28457728
# step) 826 Accuracy(IOU)= 0.2827503
# step) 827 Accuracy(IOU)= 0.28092635
# step) 828 Accuracy(IOU)= 0.28371972
# step) 829 Accuracy(IOU)= 0.2824754
# step) 830 Accuracy(IOU)= 0.28199166
# step) 831 Accuracy(IOU)= 0.28423536
# step) 832 Accuracy(IOU)= 0.2852566
# step) 833 Accuracy(IOU)= 0.28294063
# step) 834 Accuracy(IOU)= 0.2819582
# step) 835 Accuracy(IOU)= 0.28159934
# step) 836 Accuracy(IOU)= 0.2812234
# step) 837 Accuracy(IOU)= 0.28253278
# step) 838 Accuracy(IOU)= 0.28207633
# step) 839 Accuracy(IOU)= 0.28122663
# step) 840 Accuracy(IOU)= 0.27901065
# step) 841 Accuracy(IOU)= 0.27716178
# step) 842 Accuracy(IOU)= 0.27823788
# step) 843 Accuracy(IOU)= 0.28051385
# step) 844 Accuracy(IOU)= 0.2805926
# step) 845 Accuracy(IOU)= 0.28048304
# step) 846 Accuracy(IOU)= 0.27951422
# step) 847 Accuracy(IOU)= 0.28039697
# step) 848 Accuracy(IOU)= 0.27862787
# step) 849 Accuracy(IOU)= 0.27989534
# step) 850 Accuracy(IOU)= 0.2795569
# step) 851 Accuracy(IOU)= 0.27830166
# step) 852 Accuracy(IOU)= 0.27747613
# step) 853 Accuracy(IOU)= 0.27590063
# step) 854 Accuracy(IOU)= 0.27710915
# step) 855 Accuracy(IOU)= 0.27480334
# step) 856 Accuracy(IOU)= 0.27308264
# step) 857 Accuracy(IOU)= 0.27293387
# step) 858 Accuracy(IOU)= 0.27312258
# step) 859 Accuracy(IOU)= 0.27268356
# step) 860 Accuracy(IOU)= 0.27317503
# step) 861 Accuracy(IOU)= 0.27485886
# step) 862 Accuracy(IOU)= 0.27622855
# step) 863 Accuracy(IOU)= 0.27574426
# step) 864 Accuracy(IOU)= 0.27834654
# step) 865 Accuracy(IOU)= 0.2782063
# step) 866 Accuracy(IOU)= 0.27955267
# step) 867 Accuracy(IOU)= 0.27908227
# step) 868 Accuracy(IOU)= 0.27791005
# step) 869 Accuracy(IOU)= 0.27884403
# step) 870 Accuracy(IOU)= 0.27800962
# step) 871 Accuracy(IOU)= 0.27801868
# step) 872 Accuracy(IOU)= 0.27756637
# step) 873 Accuracy(IOU)= 0.27916434
# step) 874 Accuracy(IOU)= 0.27969274
# step) 875 Accuracy(IOU)= 0.2806803
# step) 876 Accuracy(IOU)= 0.2826933
# step) 877 Accuracy(IOU)= 0.2810221
# step) 878 Accuracy(IOU)= 0.27987266
# step) 880 Accuracy(IOU)= 0.2797464
# step) 881 Accuracy(IOU)= 0.2792102
# step) 882 Accuracy(IOU)= 0.27981967
# step) 883 Accuracy(IOU)= 0.2792985
# step) 884 Accuracy(IOU)= 0.28160995
# step) 885 Accuracy(IOU)= 0.28166392
# step) 886 Accuracy(IOU)= 0.28234455
# step) 887 Accuracy(IOU)= 0.28094953
# step) 888 Accuracy(IOU)= 0.27976426
# step) 889 Accuracy(IOU)= 0.2785956
# step) 890 Accuracy(IOU)= 0.2792664
# step) 891 Accuracy(IOU)= 0.28081235
# step) 892 Accuracy(IOU)= 0.28217268
# step) 893 Accuracy(IOU)= 0.28279188
# step) 894 Accuracy(IOU)= 0.28982893
# step) 895 Accuracy(IOU)= 0.29187807
# step) 896 Accuracy(IOU)= 0.2903188
# step) 897 Accuracy(IOU)= 0.29322916
# step) 898 Accuracy(IOU)= 0.2945706
# step) 899 Accuracy(IOU)= 0.29643148
# step) 900 Accuracy(IOU)= 0.29682124
# step) 901 Accuracy(IOU)= 0.2966374
# step) 902 Accuracy(IOU)= 0.2963494
# step) 903 Accuracy(IOU)= 0.2976522
# step) 904 Accuracy(IOU)= 0.29873782
# step) 905 Accuracy(IOU)= 0.29745543
# step) 906 Accuracy(IOU)= 0.29565597
# step) 907 Accuracy(IOU)= 0.2954921
# step) 908 Accuracy(IOU)= 0.29502034
# step) 909 Accuracy(IOU)= 0.29731315
# step) 910 Accuracy(IOU)= 0.297715
# step) 911 Accuracy(IOU)= 0.29874772
# step) 912 Accuracy(IOU)= 0.29892153
# step) 913 Accuracy(IOU)= 0.30245358
# step) 914 Accuracy(IOU)= 0.3049213
# step) 915 Accuracy(IOU)= 0.3042694
# step) 916 Accuracy(IOU)= 0.30413267
# step) 917 Accuracy(IOU)= 0.3060058
# step) 918 Accuracy(IOU)= 0.30549425
# step) 919 Accuracy(IOU)= 0.3048305
# step) 920 Accuracy(IOU)= 0.3045501
# step) 921 Accuracy(IOU)= 0.30520782
# step) 922 Accuracy(IOU)= 0.30388525
# step) 923 Accuracy(IOU)= 0.30501762
# step) 924 Accuracy(IOU)= 0.3049458
# step) 925 Accuracy(IOU)= 0.3033765
# step) 926 Accuracy(IOU)= 0.30619574
# step) 927 Accuracy(IOU)= 0.30547342
# step) 928 Accuracy(IOU)= 0.30537593
# step) 929 Accuracy(IOU)= 0.30671623
# step) 930 Accuracy(IOU)= 0.30732307
# step) 931 Accuracy(IOU)= 0.3071564
# step) 932 Accuracy(IOU)= 0.30680305
# step) 933 Accuracy(IOU)= 0.30525178
# step) 934 Accuracy(IOU)= 0.30271637
# step) 935 Accuracy(IOU)= 0.30031902
# step) 936 Accuracy(IOU)= 0.3016423
# step) 937 Accuracy(IOU)= 0.30156186
# step) 938 Accuracy(IOU)= 0.30281982
# step) 939 Accuracy(IOU)= 0.30014598
# step) 940 Accuracy(IOU)= 0.30006987
# step) 941 Accuracy(IOU)= 0.30031595
# step) 942 Accuracy(IOU)= 0.2989026
# step) 943 Accuracy(IOU)= 0.3000289
# step) 944 Accuracy(IOU)= 0.30233955
# step) 945 Accuracy(IOU)= 0.30298966
# step) 946 Accuracy(IOU)= 0.30432454
# step) 947 Accuracy(IOU)= 0.30359745
# step) 948 Accuracy(IOU)= 0.30111864
# step) 949 Accuracy(IOU)= 0.30028066
# step) 950 Accuracy(IOU)= 0.2982244
# step) 951 Accuracy(IOU)= 0.29825893
# step) 952 Accuracy(IOU)= 0.29555848
# step) 953 Accuracy(IOU)= 0.29706797
# step) 954 Accuracy(IOU)= 0.30131766
# step) 955 Accuracy(IOU)= 0.30123946
# step) 956 Accuracy(IOU)= 0.30419344
# step) 957 Accuracy(IOU)= 0.30836624
# step) 958 Accuracy(IOU)= 0.3084195
# step) 959 Accuracy(IOU)= 0.3078506
# step) 960 Accuracy(IOU)= 0.3097297
# step) 961 Accuracy(IOU)= 0.30873066
# step) 962 Accuracy(IOU)= 0.3080678
# step) 963 Accuracy(IOU)= 0.30551022
# step) 964 Accuracy(IOU)= 0.3054967
# step) 965 Accuracy(IOU)= 0.30499515
# step) 966 Accuracy(IOU)= 0.3026491
# step) 967 Accuracy(IOU)= 0.30306917
# step) 968 Accuracy(IOU)= 0.3050655
# step) 969 Accuracy(IOU)= 0.30271196
# step) 970 Accuracy(IOU)= 0.3034105
# step) 971 Accuracy(IOU)= 0.3048911
# step) 972 Accuracy(IOU)= 0.30358765
# step) 973 Accuracy(IOU)= 0.30070648
# step) 974 Accuracy(IOU)= 0.30186749
# step) 975 Accuracy(IOU)= 0.30107242
# step) 976 Accuracy(IOU)= 0.30153093
# step) 977 Accuracy(IOU)= 0.30070814
# step) 978 Accuracy(IOU)= 0.3018109
# step) 979 Accuracy(IOU)= 0.29975742
# step) 980 Accuracy(IOU)= 0.3008618
# step) 981 Accuracy(IOU)= 0.30265483
# step) 982 Accuracy(IOU)= 0.30052269
# step) 983 Accuracy(IOU)= 0.3019552
# step) 984 Accuracy(IOU)= 0.3029334
# step) 985 Accuracy(IOU)= 0.30200595
# step) 986 Accuracy(IOU)= 0.29944208
# step) 987 Accuracy(IOU)= 0.2992961
# step) 988 Accuracy(IOU)= 0.3008977
# step) 989 Accuracy(IOU)= 0.29857498
# step) 990 Accuracy(IOU)= 0.2975764
# step) 991 Accuracy(IOU)= 0.2987728
# step) 992 Accuracy(IOU)= 0.29866204
# step) 993 Accuracy(IOU)= 0.29995906
# step) 994 Accuracy(IOU)= 0.2987313
# step) 995 Accuracy(IOU)= 0.29723948
# step) 996 Accuracy(IOU)= 0.2968903
# step) 997 Accuracy(IOU)= 0.29660466
# step) 998 Accuracy(IOU)= 0.29495415
# step) 999 Accuracy(IOU)= 0.2938794
# save model
# step) 1000 Accuracy(IOU)= 0.29231697
# step) 1001 Accuracy(IOU)= 0.29069948
# step) 1002 Accuracy(IOU)= 0.29057717
# step) 1003 Accuracy(IOU)= 0.29270184
# step) 1004 Accuracy(IOU)= 0.29148895
# step) 1005 Accuracy(IOU)= 0.29241282
# step) 1006 Accuracy(IOU)= 0.2926854
# step) 1007 Accuracy(IOU)= 0.29195753
# step) 1008 Accuracy(IOU)= 0.29094255
# step) 1009 Accuracy(IOU)= 0.29322764
# step) 1010 Accuracy(IOU)= 0.29079267
# step) 1011 Accuracy(IOU)= 0.2920235
# step) 1012 Accuracy(IOU)= 0.2918016
# step) 1013 Accuracy(IOU)= 0.29210377
# step) 1014 Accuracy(IOU)= 0.29275006
# step) 1015 Accuracy(IOU)= 0.29205734
# step) 1016 Accuracy(IOU)= 0.29293537
# step) 1017 Accuracy(IOU)= 0.29017836
# step) 1018 Accuracy(IOU)= 0.29073158
# step) 1019 Accuracy(IOU)= 0.2918909
# step) 1020 Accuracy(IOU)= 0.29001516
# step) 1021 Accuracy(IOU)= 0.29286632
# step) 1022 Accuracy(IOU)= 0.29305857
# step) 1023 Accuracy(IOU)= 0.29206172
# step) 1024 Accuracy(IOU)= 0.29086795
# step) 1025 Accuracy(IOU)= 0.29169574
# step) 1026 Accuracy(IOU)= 0.29249766
# step) 1027 Accuracy(IOU)= 0.29301533
# step) 1028 Accuracy(IOU)= 0.2915634
# step) 1029 Accuracy(IOU)= 0.29337093
# step) 1030 Accuracy(IOU)= 0.29074773
# step) 1031 Accuracy(IOU)= 0.2898104
# step) 1032 Accuracy(IOU)= 0.28991678
# step) 1033 Accuracy(IOU)= 0.29059815
# step) 1034 Accuracy(IOU)= 0.28924832
# step) 1035 Accuracy(IOU)= 0.2901431
# step) 1036 Accuracy(IOU)= 0.28904462
# step) 1037 Accuracy(IOU)= 0.29026887
# step) 1038 Accuracy(IOU)= 0.28797308
# step) 1039 Accuracy(IOU)= 0.29017404
# step) 1040 Accuracy(IOU)= 0.28987205
# step) 1041 Accuracy(IOU)= 0.28949264
# step) 1042 Accuracy(IOU)= 0.2881391
# step) 1043 Accuracy(IOU)= 0.28599763
# step) 1044 Accuracy(IOU)= 0.28722313
# step) 1045 Accuracy(IOU)= 0.28465465
# step) 1046 Accuracy(IOU)= 0.2873884
# step) 1047 Accuracy(IOU)= 0.28689325
# step) 1048 Accuracy(IOU)= 0.2879214
# step) 1049 Accuracy(IOU)= 0.28725573
# step) 1050 Accuracy(IOU)= 0.29217607
# step) 1051 Accuracy(IOU)= 0.29090002
# step) 1052 Accuracy(IOU)= 0.29362476
# step) 1053 Accuracy(IOU)= 0.29478148
# step) 1054 Accuracy(IOU)= 0.29376516
# step) 1055 Accuracy(IOU)= 0.29264238
# step) 1056 Accuracy(IOU)= 0.2925232
# step) 1057 Accuracy(IOU)= 0.2903522
# step) 1058 Accuracy(IOU)= 0.28880763
# step) 1059 Accuracy(IOU)= 0.2894808
# step) 1060 Accuracy(IOU)= 0.29056966
# step) 1061 Accuracy(IOU)= 0.29035154
# step) 1062 Accuracy(IOU)= 0.28945863
# step) 1063 Accuracy(IOU)= 0.28840002
# step) 1064 Accuracy(IOU)= 0.28727755
# step) 1065 Accuracy(IOU)= 0.28991386
# step) 1066 Accuracy(IOU)= 0.2886987
# step) 1067 Accuracy(IOU)= 0.28762427
# step) 1068 Accuracy(IOU)= 0.28596044
# step) 1069 Accuracy(IOU)= 0.2853274
# step) 1070 Accuracy(IOU)= 0.28258157
# step) 1071 Accuracy(IOU)= 0.28250727
# step) 1072 Accuracy(IOU)= 0.2815035
# step) 1073 Accuracy(IOU)= 0.28178102
# step) 1074 Accuracy(IOU)= 0.2821933
# step) 1075 Accuracy(IOU)= 0.28017393
# step) 1076 Accuracy(IOU)= 0.28007627
# step) 1077 Accuracy(IOU)= 0.28110078
# step) 1078 Accuracy(IOU)= 0.279539
# step) 1079 Accuracy(IOU)= 0.27771696
# step) 1080 Accuracy(IOU)= 0.27713665
# step) 1081 Accuracy(IOU)= 0.27923912
# step) 1082 Accuracy(IOU)= 0.2779167
# step) 1083 Accuracy(IOU)= 0.27813703
# step) 1084 Accuracy(IOU)= 0.2804729
# step) 1085 Accuracy(IOU)= 0.27999097
# step) 1086 Accuracy(IOU)= 0.28172383
# step) 1087 Accuracy(IOU)= 0.28051776
# step) 1088 Accuracy(IOU)= 0.28060275
# step) 1089 Accuracy(IOU)= 0.27937627
# step) 1090 Accuracy(IOU)= 0.27900854
# step) 1091 Accuracy(IOU)= 0.2799348
# step) 1092 Accuracy(IOU)= 0.2806188
# step) 1093 Accuracy(IOU)= 0.28005558
# step) 1094 Accuracy(IOU)= 0.28135562
# step) 1095 Accuracy(IOU)= 0.28184983
# step) 1096 Accuracy(IOU)= 0.28181937
# step) 1097 Accuracy(IOU)= 0.28284308
# step) 1098 Accuracy(IOU)= 0.2849275
# step) 1099 Accuracy(IOU)= 0.283888
# step) 1100 Accuracy(IOU)= 0.28556895
# step) 1101 Accuracy(IOU)= 0.2842841
# step) 1102 Accuracy(IOU)= 0.28441653
# step) 1103 Accuracy(IOU)= 0.2832732
# step) 1104 Accuracy(IOU)= 0.2846148
# step) 1105 Accuracy(IOU)= 0.28431547
# step) 1106 Accuracy(IOU)= 0.28273195
# step) 1107 Accuracy(IOU)= 0.2833652
# step) 1108 Accuracy(IOU)= 0.2819133
# step) 1109 Accuracy(IOU)= 0.28132993
# step) 1110 Accuracy(IOU)= 0.28187424
# step) 1111 Accuracy(IOU)= 0.28062096
# step) 1112 Accuracy(IOU)= 0.28002846
# step) 1113 Accuracy(IOU)= 0.28001738
# step) 1114 Accuracy(IOU)= 0.279792
# step) 1115 Accuracy(IOU)= 0.28096902
# step) 1116 Accuracy(IOU)= 0.28274268
# step) 1117 Accuracy(IOU)= 0.2839214
# step) 1118 Accuracy(IOU)= 0.2846969
# step) 1119 Accuracy(IOU)= 0.28421044
# step) 1120 Accuracy(IOU)= 0.28465483
# step) 1121 Accuracy(IOU)= 0.28711203
# step) 1122 Accuracy(IOU)= 0.2903179
# step) 1123 Accuracy(IOU)= 0.29291886
# step) 1124 Accuracy(IOU)= 0.29164544
# step) 1125 Accuracy(IOU)= 0.2907917
# step) 1126 Accuracy(IOU)= 0.29079506
# step) 1127 Accuracy(IOU)= 0.29108238
# step) 1128 Accuracy(IOU)= 0.29042602
# step) 1129 Accuracy(IOU)= 0.2883698
# step) 1130 Accuracy(IOU)= 0.28591996
# step) 1131 Accuracy(IOU)= 0.28617358
# step) 1132 Accuracy(IOU)= 0.28413224
# step) 1133 Accuracy(IOU)= 0.28400517
# step) 1134 Accuracy(IOU)= 0.28475833
# step) 1135 Accuracy(IOU)= 0.28693077
# step) 1136 Accuracy(IOU)= 0.28848958
# step) 1137 Accuracy(IOU)= 0.28888696
# step) 1138 Accuracy(IOU)= 0.28847396
# step) 1139 Accuracy(IOU)= 0.2891247
# step) 1140 Accuracy(IOU)= 0.29035217
# step) 1141 Accuracy(IOU)= 0.29087287
# step) 1142 Accuracy(IOU)= 0.29459983
# step) 1143 Accuracy(IOU)= 0.29538837
# step) 1144 Accuracy(IOU)= 0.29480734
# step) 1145 Accuracy(IOU)= 0.2926936
# step) 1146 Accuracy(IOU)= 0.29250395
# step) 1147 Accuracy(IOU)= 0.28991482
# step) 1148 Accuracy(IOU)= 0.28961098
# step) 1149 Accuracy(IOU)= 0.28791845
# step) 1150 Accuracy(IOU)= 0.28796774
# step) 1151 Accuracy(IOU)= 0.2881301
# step) 1152 Accuracy(IOU)= 0.28868493
# step) 1153 Accuracy(IOU)= 0.2890097
# step) 1154 Accuracy(IOU)= 0.2877856
# step) 1155 Accuracy(IOU)= 0.28654826
# step) 1156 Accuracy(IOU)= 0.28587112
# step) 1157 Accuracy(IOU)= 0.28316513
# step) 1158 Accuracy(IOU)= 0.28687674
# step) 1159 Accuracy(IOU)= 0.28753406
# step) 1160 Accuracy(IOU)= 0.28560606
# step) 1161 Accuracy(IOU)= 0.28568769
# step) 1162 Accuracy(IOU)= 0.28396994
# step) 1163 Accuracy(IOU)= 0.2854071
# step) 1164 Accuracy(IOU)= 0.28564978
# step) 1165 Accuracy(IOU)= 0.28858873
# step) 1166 Accuracy(IOU)= 0.28754503
# step) 1167 Accuracy(IOU)= 0.28953815
# step) 1168 Accuracy(IOU)= 0.29102364
# step) 1169 Accuracy(IOU)= 0.2929992
# step) 1170 Accuracy(IOU)= 0.29463372
# step) 1171 Accuracy(IOU)= 0.29646757
# step) 1172 Accuracy(IOU)= 0.29553872
# step) 1173 Accuracy(IOU)= 0.2973905
# step) 1174 Accuracy(IOU)= 0.29741043
# step) 1175 Accuracy(IOU)= 0.301355
# step) 1176 Accuracy(IOU)= 0.3000104
# step) 1177 Accuracy(IOU)= 0.30104303
# step) 1178 Accuracy(IOU)= 0.300851
# step) 1179 Accuracy(IOU)= 0.30122322
# step) 1180 Accuracy(IOU)= 0.3013629
# step) 1181 Accuracy(IOU)= 0.30087575
# step) 1182 Accuracy(IOU)= 0.3009693
# step) 1183 Accuracy(IOU)= 0.30252686
# step) 1184 Accuracy(IOU)= 0.30384547
# step) 1185 Accuracy(IOU)= 0.3045794
# step) 1186 Accuracy(IOU)= 0.30696067
# step) 1187 Accuracy(IOU)= 0.30566323
# step) 1188 Accuracy(IOU)= 0.30477023
# step) 1189 Accuracy(IOU)= 0.30462784
# step) 1190 Accuracy(IOU)= 0.30586323
# step) 1191 Accuracy(IOU)= 0.30372792
# step) 1192 Accuracy(IOU)= 0.3055722
# step) 1193 Accuracy(IOU)= 0.30486497
# step) 1194 Accuracy(IOU)= 0.3037977
# step) 1195 Accuracy(IOU)= 0.30518934
# step) 1196 Accuracy(IOU)= 0.30276772
# step) 1197 Accuracy(IOU)= 0.30184364
# step) 1198 Accuracy(IOU)= 0.3031415
# step) 1199 Accuracy(IOU)= 0.3020268
# step) 1200 Accuracy(IOU)= 0.3006776
# step) 1201 Accuracy(IOU)= 0.30133256
# step) 1202 Accuracy(IOU)= 0.3022377
# step) 1203 Accuracy(IOU)= 0.30071557
# step) 1204 Accuracy(IOU)= 0.298354
# step) 1205 Accuracy(IOU)= 0.29951832
# step) 1206 Accuracy(IOU)= 0.30058736
# step) 1207 Accuracy(IOU)= 0.29975072
# step) 1208 Accuracy(IOU)= 0.3000543
# step) 1209 Accuracy(IOU)= 0.29967922
# step) 1210 Accuracy(IOU)= 0.3042941
# step) 1211 Accuracy(IOU)= 0.30145705
# step) 1212 Accuracy(IOU)= 0.30393577
# step) 1213 Accuracy(IOU)= 0.30464244
# step) 1214 Accuracy(IOU)= 0.30551934
# step) 1215 Accuracy(IOU)= 0.30854303
# step) 1216 Accuracy(IOU)= 0.30856937
# step) 1217 Accuracy(IOU)= 0.3078117
# step) 1218 Accuracy(IOU)= 0.30740848
# step) 1219 Accuracy(IOU)= 0.30647895
# step) 1220 Accuracy(IOU)= 0.3061134
# step) 1221 Accuracy(IOU)= 0.30760747
# step) 1222 Accuracy(IOU)= 0.30934614
# step) 1223 Accuracy(IOU)= 0.30752218
# step) 1224 Accuracy(IOU)= 0.30710375
# step) 1225 Accuracy(IOU)= 0.30793282
# step) 1226 Accuracy(IOU)= 0.3098977
# step) 1227 Accuracy(IOU)= 0.30957544
# step) 1228 Accuracy(IOU)= 0.31058115
# step) 1229 Accuracy(IOU)= 0.3114287
# step) 1230 Accuracy(IOU)= 0.31123844
# step) 1231 Accuracy(IOU)= 0.3087866
# step) 1232 Accuracy(IOU)= 0.3078267
# step) 1233 Accuracy(IOU)= 0.30779952
# step) 1234 Accuracy(IOU)= 0.30495033
# step) 1235 Accuracy(IOU)= 0.3070068
# step) 1236 Accuracy(IOU)= 0.30589515
# step) 1237 Accuracy(IOU)= 0.305066
# step) 1238 Accuracy(IOU)= 0.30403095
# step) 1239 Accuracy(IOU)= 0.30295384
# step) 1240 Accuracy(IOU)= 0.3031657
# step) 1241 Accuracy(IOU)= 0.30479738
# step) 1242 Accuracy(IOU)= 0.3036287
# step) 1243 Accuracy(IOU)= 0.30483994
# step) 1244 Accuracy(IOU)= 0.30429363
# step) 1245 Accuracy(IOU)= 0.30403653
# step) 1246 Accuracy(IOU)= 0.30383953
# step) 1247 Accuracy(IOU)= 0.3059907
# step) 1248 Accuracy(IOU)= 0.3060688
# step) 1249 Accuracy(IOU)= 0.30546644
# step) 1250 Accuracy(IOU)= 0.30457264
# step) 1251 Accuracy(IOU)= 0.30506155
# step) 1252 Accuracy(IOU)= 0.30547598
# step) 1253 Accuracy(IOU)= 0.30428752
# step) 1254 Accuracy(IOU)= 0.3048307
# step) 1255 Accuracy(IOU)= 0.3052375
# step) 1256 Accuracy(IOU)= 0.3050279
# step) 1257 Accuracy(IOU)= 0.3056455
# step) 1258 Accuracy(IOU)= 0.3043312
# step) 1259 Accuracy(IOU)= 0.30389258
# step) 1260 Accuracy(IOU)= 0.30177614
# step) 1261 Accuracy(IOU)= 0.30220425
# step) 1262 Accuracy(IOU)= 0.303568
# step) 1263 Accuracy(IOU)= 0.30213907
# step) 1264 Accuracy(IOU)= 0.3038617
# step) 1265 Accuracy(IOU)= 0.30380827
# step) 1266 Accuracy(IOU)= 0.30652332
# step) 1267 Accuracy(IOU)= 0.3043245
# step) 1268 Accuracy(IOU)= 0.30345568
# step) 1269 Accuracy(IOU)= 0.3031845
# step) 1270 Accuracy(IOU)= 0.3031836
# step) 1271 Accuracy(IOU)= 0.3034086
# step) 1272 Accuracy(IOU)= 0.30596337
# step) 1273 Accuracy(IOU)= 0.3039388
# step) 1274 Accuracy(IOU)= 0.3052543
# step) 1275 Accuracy(IOU)= 0.3048177
# step) 1276 Accuracy(IOU)= 0.30537733
# step) 1277 Accuracy(IOU)= 0.30439147
# step) 1278 Accuracy(IOU)= 0.30760148
# step) 1279 Accuracy(IOU)= 0.3073794
# step) 1280 Accuracy(IOU)= 0.3062768
# step) 1281 Accuracy(IOU)= 0.3049937
# step) 1282 Accuracy(IOU)= 0.30632976
# step) 1283 Accuracy(IOU)= 0.30811673
# step) 1284 Accuracy(IOU)= 0.30786481
# step) 1285 Accuracy(IOU)= 0.30863467
# step) 1286 Accuracy(IOU)= 0.31043574
# step) 1287 Accuracy(IOU)= 0.30877566
# step) 1288 Accuracy(IOU)= 0.30913287
# step) 1289 Accuracy(IOU)= 0.30907506
# step) 1290 Accuracy(IOU)= 0.3083879
# step) 1291 Accuracy(IOU)= 0.30577868
# step) 1292 Accuracy(IOU)= 0.30783325
# step) 1293 Accuracy(IOU)= 0.30924055
# step) 1294 Accuracy(IOU)= 0.30904374
# step) 1295 Accuracy(IOU)= 0.30900046
# step) 1296 Accuracy(IOU)= 0.3094675
# step) 1297 Accuracy(IOU)= 0.31191108
# step) 1298 Accuracy(IOU)= 0.310932
# step) 1299 Accuracy(IOU)= 0.30902335
# step) 1300 Accuracy(IOU)= 0.31091383
# step) 1301 Accuracy(IOU)= 0.31078798
# step) 1302 Accuracy(IOU)= 0.3104455
# step) 1303 Accuracy(IOU)= 0.31196177
# step) 1304 Accuracy(IOU)= 0.31244314
# step) 1305 Accuracy(IOU)= 0.31330025
# step) 1306 Accuracy(IOU)= 0.31165576
# step) 1307 Accuracy(IOU)= 0.31113407
# step) 1308 Accuracy(IOU)= 0.31229958
# step) 1309 Accuracy(IOU)= 0.3112341
# step) 1310 Accuracy(IOU)= 0.31147775
# step) 1311 Accuracy(IOU)= 0.31249255
# step) 1312 Accuracy(IOU)= 0.31107897
# step) 1313 Accuracy(IOU)= 0.31060767
# step) 1314 Accuracy(IOU)= 0.311065
# step) 1316 Accuracy(IOU)= 0.30999047
# step) 1317 Accuracy(IOU)= 0.30872163
# step) 1318 Accuracy(IOU)= 0.30891606
# step) 1319 Accuracy(IOU)= 0.307919
# step) 1320 Accuracy(IOU)= 0.30760992
# step) 1321 Accuracy(IOU)= 0.30680475
# step) 1322 Accuracy(IOU)= 0.30918553
# step) 1323 Accuracy(IOU)= 0.30878857
# step) 1324 Accuracy(IOU)= 0.31557164
# step) 1325 Accuracy(IOU)= 0.316111
# step) 1326 Accuracy(IOU)= 0.31562486
# ...
# step) 99576 Accuracy(IOU)= 0.42838147
# step) 99577 Accuracy(IOU)= 0.4320195
# step) 99578 Accuracy(IOU)= 0.43028346
# step) 99579 Accuracy(IOU)= 0.42901462
# step) 99580 Accuracy(IOU)= 0.42848802
# step) 99581 Accuracy(IOU)= 0.42971003
# step) 99582 Accuracy(IOU)= 0.42879462
# step) 99583 Accuracy(IOU)= 0.4266929
# step) 99584 Accuracy(IOU)= 0.4263565
# step) 99585 Accuracy(IOU)= 0.42582852
# step) 99586 Accuracy(IOU)= 0.42553836
# step) 99587 Accuracy(IOU)= 0.42420378
# step) 99588 Accuracy(IOU)= 0.42251855
# step) 99589 Accuracy(IOU)= 0.4221548
# step) 99590 Accuracy(IOU)= 0.42597753
# step) 99591 Accuracy(IOU)= 0.42582747
# step) 99592 Accuracy(IOU)= 0.42661405
# step) 99593 Accuracy(IOU)= 0.4268641
# step) 99594 Accuracy(IOU)= 0.425652
# step) 99595 Accuracy(IOU)= 0.425261
# step) 99596 Accuracy(IOU)= 0.42398745
# step) 99597 Accuracy(IOU)= 0.42436308
# step) 99598 Accuracy(IOU)= 0.42509425
# step) 99599 Accuracy(IOU)= 0.4248305
# step) 99600 Accuracy(IOU)= 0.42342874
# step) 99601 Accuracy(IOU)= 0.42329493
# step) 99602 Accuracy(IOU)= 0.42214185
# step) 99603 Accuracy(IOU)= 0.41976875
# step) 99604 Accuracy(IOU)= 0.42101613
# step) 99605 Accuracy(IOU)= 0.42135566
# step) 99606 Accuracy(IOU)= 0.4209271
# step) 99607 Accuracy(IOU)= 0.42130652
# step) 99608 Accuracy(IOU)= 0.4203242
# step) 99609 Accuracy(IOU)= 0.4208884
# step) 99610 Accuracy(IOU)= 0.4196085
# step) 99611 Accuracy(IOU)= 0.42045975
# step) 99612 Accuracy(IOU)= 0.42034414
# step) 99613 Accuracy(IOU)= 0.42098156
# step) 99614 Accuracy(IOU)= 0.41996607
# step) 99615 Accuracy(IOU)= 0.42191693
# step) 99616 Accuracy(IOU)= 0.42246735
# step) 99617 Accuracy(IOU)= 0.4221233
# step) 99618 Accuracy(IOU)= 0.4213272
# step) 99619 Accuracy(IOU)= 0.4214999
# step) 99620 Accuracy(IOU)= 0.42097682
# step) 99621 Accuracy(IOU)= 0.42013723
# step) 99622 Accuracy(IOU)= 0.41793978
# step) 99623 Accuracy(IOU)= 0.418163
# step) 99624 Accuracy(IOU)= 0.41699758
# step) 99625 Accuracy(IOU)= 0.41800928
# step) 99626 Accuracy(IOU)= 0.41837493
# step) 99627 Accuracy(IOU)= 0.4208198
# step) 99628 Accuracy(IOU)= 0.4204608
# step) 99629 Accuracy(IOU)= 0.42160675
# step) 99630 Accuracy(IOU)= 0.42282724
# step) 99631 Accuracy(IOU)= 0.42101726
# step) 99632 Accuracy(IOU)= 0.42233756
# step) 99633 Accuracy(IOU)= 0.42248783
# step) 99634 Accuracy(IOU)= 0.42328304
# step) 99635 Accuracy(IOU)= 0.42410985
# step) 99636 Accuracy(IOU)= 0.42337817
# step) 99637 Accuracy(IOU)= 0.4283979
# step) 99638 Accuracy(IOU)= 0.42699412
# step) 99639 Accuracy(IOU)= 0.42718112
# step) 99640 Accuracy(IOU)= 0.4245413
# step) 99641 Accuracy(IOU)= 0.4260563
# step) 99642 Accuracy(IOU)= 0.42743593
# step) 99643 Accuracy(IOU)= 0.42670113
# step) 99644 Accuracy(IOU)= 0.4282862
# step) 99645 Accuracy(IOU)= 0.4277401
# step) 99646 Accuracy(IOU)= 0.42681605
# step) 99647 Accuracy(IOU)= 0.42504087
# step) 99648 Accuracy(IOU)= 0.42554265
# step) 99649 Accuracy(IOU)= 0.4241619
# step) 99650 Accuracy(IOU)= 0.42375094
# step) 99651 Accuracy(IOU)= 0.42532304
# step) 99652 Accuracy(IOU)= 0.42610496
# step) 99653 Accuracy(IOU)= 0.42754823
# step) 99654 Accuracy(IOU)= 0.42735958
# step) 99655 Accuracy(IOU)= 0.42775604
# step) 99656 Accuracy(IOU)= 0.4324906
# step) 99657 Accuracy(IOU)= 0.42993337
# step) 99658 Accuracy(IOU)= 0.42986286
# step) 99659 Accuracy(IOU)= 0.43182564
# step) 99660 Accuracy(IOU)= 0.43161285
# step) 99661 Accuracy(IOU)= 0.4316924
# step) 99662 Accuracy(IOU)= 0.430535
# step) 99663 Accuracy(IOU)= 0.43052593
# step) 99664 Accuracy(IOU)= 0.4285856
# step) 99665 Accuracy(IOU)= 0.4275857
# step) 99666 Accuracy(IOU)= 0.42749304
# step) 99667 Accuracy(IOU)= 0.42788863
# step) 99668 Accuracy(IOU)= 0.42524332
# step) 99669 Accuracy(IOU)= 0.4261572
# step) 99670 Accuracy(IOU)= 0.42763802
# step) 99671 Accuracy(IOU)= 0.42942595
# step) 99672 Accuracy(IOU)= 0.42827302
# step) 99673 Accuracy(IOU)= 0.42857713
# step) 99674 Accuracy(IOU)= 0.42938355
# step) 99675 Accuracy(IOU)= 0.4286864
# step) 99676 Accuracy(IOU)= 0.42607394
# step) 99677 Accuracy(IOU)= 0.42572045
# step) 99678 Accuracy(IOU)= 0.4248868
# step) 99679 Accuracy(IOU)= 0.42842317
# step) 99680 Accuracy(IOU)= 0.4299284
# step) 99681 Accuracy(IOU)= 0.4282911
# step) 99682 Accuracy(IOU)= 0.42922232
# step) 99683 Accuracy(IOU)= 0.4316959
# step) 99684 Accuracy(IOU)= 0.43101588
# step) 99685 Accuracy(IOU)= 0.4304573
# step) 99686 Accuracy(IOU)= 0.42824143
# step) 99687 Accuracy(IOU)= 0.42896312
# step) 99688 Accuracy(IOU)= 0.43080455
# step) 99689 Accuracy(IOU)= 0.42997292
# step) 99690 Accuracy(IOU)= 0.4293649
# step) 99691 Accuracy(IOU)= 0.4294193
# step) 99692 Accuracy(IOU)= 0.4283447
# step) 99693 Accuracy(IOU)= 0.42798406
# step) 99694 Accuracy(IOU)= 0.42996562
# step) 99695 Accuracy(IOU)= 0.42951056
# step) 99696 Accuracy(IOU)= 0.4299485
# step) 99697 Accuracy(IOU)= 0.43042454
# step) 99698 Accuracy(IOU)= 0.4304348
# step) 99699 Accuracy(IOU)= 0.42890564
# step) 99700 Accuracy(IOU)= 0.42826444
# step) 99701 Accuracy(IOU)= 0.4297796
# step) 99702 Accuracy(IOU)= 0.42877203
# step) 99703 Accuracy(IOU)= 0.4273253
# step) 99704 Accuracy(IOU)= 0.4263651
# step) 99705 Accuracy(IOU)= 0.42518044
# step) 99706 Accuracy(IOU)= 0.42336023
# step) 99707 Accuracy(IOU)= 0.42698324
# step) 99708 Accuracy(IOU)= 0.42671764
# step) 99709 Accuracy(IOU)= 0.42603904
# step) 99710 Accuracy(IOU)= 0.42518383
# step) 99711 Accuracy(IOU)= 0.42409444
# step) 99712 Accuracy(IOU)= 0.4229577
# step) 99713 Accuracy(IOU)= 0.4224211
# step) 99714 Accuracy(IOU)= 0.42323673
# step) 99715 Accuracy(IOU)= 0.42315835
# step) 99716 Accuracy(IOU)= 0.42269057
# step) 99717 Accuracy(IOU)= 0.421043
# step) 99718 Accuracy(IOU)= 0.42005825
# step) 99719 Accuracy(IOU)= 0.41771427
# step) 99720 Accuracy(IOU)= 0.41758993
# step) 99721 Accuracy(IOU)= 0.41615632
# step) 99722 Accuracy(IOU)= 0.4166205
# step) 99723 Accuracy(IOU)= 0.41668862
# step) 99724 Accuracy(IOU)= 0.42111856
# step) 99725 Accuracy(IOU)= 0.4215378
# step) 99726 Accuracy(IOU)= 0.42441806
# step) 99727 Accuracy(IOU)= 0.42386562
# step) 99728 Accuracy(IOU)= 0.42461497
# step) 99729 Accuracy(IOU)= 0.42371
# step) 99730 Accuracy(IOU)= 0.42383057
# step) 99731 Accuracy(IOU)= 0.4241689
# step) 99732 Accuracy(IOU)= 0.42186543
# step) 99733 Accuracy(IOU)= 0.4232026
# step) 99734 Accuracy(IOU)= 0.42355323
# step) 99735 Accuracy(IOU)= 0.42378396
# step) 99736 Accuracy(IOU)= 0.42953858
# step) 99737 Accuracy(IOU)= 0.42756566
# step) 99738 Accuracy(IOU)= 0.42585105
# step) 99739 Accuracy(IOU)= 0.42601442
# step) 99740 Accuracy(IOU)= 0.42558035
# step) 99741 Accuracy(IOU)= 0.42354938
# step) 99742 Accuracy(IOU)= 0.42457983
# step) 99743 Accuracy(IOU)= 0.42350248
# step) 99744 Accuracy(IOU)= 0.42548674
# step) 99745 Accuracy(IOU)= 0.4267107
# step) 99746 Accuracy(IOU)= 0.429204
# step) 99747 Accuracy(IOU)= 0.4266215
# step) 99748 Accuracy(IOU)= 0.43047908
# step) 99749 Accuracy(IOU)= 0.42966884
# step) 99750 Accuracy(IOU)= 0.42808637
# step) 99751 Accuracy(IOU)= 0.42805684
# step) 99752 Accuracy(IOU)= 0.42874253
# step) 99753 Accuracy(IOU)= 0.42765275
# step) 99754 Accuracy(IOU)= 0.42885673
# step) 99755 Accuracy(IOU)= 0.42739016
# step) 99756 Accuracy(IOU)= 0.42616606
# step) 99757 Accuracy(IOU)= 0.42510763
# step) 99758 Accuracy(IOU)= 0.4271563
# step) 99759 Accuracy(IOU)= 0.42805016
# step) 99760 Accuracy(IOU)= 0.4276669
# step) 99761 Accuracy(IOU)= 0.42916834
# step) 99762 Accuracy(IOU)= 0.42816037
# step) 99763 Accuracy(IOU)= 0.4307723
# step) 99764 Accuracy(IOU)= 0.4298253
# step) 99765 Accuracy(IOU)= 0.43333584
# step) 99766 Accuracy(IOU)= 0.43133816
# step) 99767 Accuracy(IOU)= 0.43227112
# step) 99768 Accuracy(IOU)= 0.4311006
# step) 99769 Accuracy(IOU)= 0.43003517
# step) 99770 Accuracy(IOU)= 0.42955914
# step) 99771 Accuracy(IOU)= 0.42911345
# step) 99772 Accuracy(IOU)= 0.4262131
# step) 99773 Accuracy(IOU)= 0.42644763
# step) 99774 Accuracy(IOU)= 0.42619526
# step) 99775 Accuracy(IOU)= 0.42750397
# step) 99776 Accuracy(IOU)= 0.4263083
# step) 99777 Accuracy(IOU)= 0.42509145
# step) 99778 Accuracy(IOU)= 0.4286235
# step) 99779 Accuracy(IOU)= 0.42910063
# step) 99780 Accuracy(IOU)= 0.43048263
# step) 99781 Accuracy(IOU)= 0.4312407
# step) 99782 Accuracy(IOU)= 0.42985228
# step) 99783 Accuracy(IOU)= 0.43223932
# step) 99784 Accuracy(IOU)= 0.43193138
# step) 99785 Accuracy(IOU)= 0.43245316
# step) 99786 Accuracy(IOU)= 0.432163
# step) 99787 Accuracy(IOU)= 0.43190297
# step) 99788 Accuracy(IOU)= 0.43131006
# step) 99789 Accuracy(IOU)= 0.4303397
# step) 99790 Accuracy(IOU)= 0.42997083
# step) 99791 Accuracy(IOU)= 0.42905027
# step) 99792 Accuracy(IOU)= 0.4303482
# step) 99793 Accuracy(IOU)= 0.43251374
# step) 99794 Accuracy(IOU)= 0.4315853
# step) 99795 Accuracy(IOU)= 0.4305424
# step) 99796 Accuracy(IOU)= 0.4289033
# step) 99797 Accuracy(IOU)= 0.42915654
# step) 99798 Accuracy(IOU)= 0.42835745
# step) 99799 Accuracy(IOU)= 0.42683172
# step) 99800 Accuracy(IOU)= 0.42659038
# step) 99801 Accuracy(IOU)= 0.42368472
# step) 99802 Accuracy(IOU)= 0.4218173
# step) 99803 Accuracy(IOU)= 0.42180553
# step) 99804 Accuracy(IOU)= 0.4190873
# step) 99805 Accuracy(IOU)= 0.41899016
# step) 99806 Accuracy(IOU)= 0.4202177
# step) 99807 Accuracy(IOU)= 0.41991797
# step) 99808 Accuracy(IOU)= 0.41891557
# step) 99809 Accuracy(IOU)= 0.41726997
# step) 99810 Accuracy(IOU)= 0.4170295
# step) 99811 Accuracy(IOU)= 0.4178449
# step) 99812 Accuracy(IOU)= 0.4194882
# step) 99813 Accuracy(IOU)= 0.4197502
# step) 99814 Accuracy(IOU)= 0.42234534
# step) 99815 Accuracy(IOU)= 0.42405698
# step) 99816 Accuracy(IOU)= 0.42353228
# step) 99817 Accuracy(IOU)= 0.4222718
# step) 99818 Accuracy(IOU)= 0.42109767
# step) 99819 Accuracy(IOU)= 0.42339492
# step) 99820 Accuracy(IOU)= 0.42178476
# step) 99821 Accuracy(IOU)= 0.4187819
# step) 99822 Accuracy(IOU)= 0.41925213
# step) 99823 Accuracy(IOU)= 0.4209136
# step) 99824 Accuracy(IOU)= 0.42060363
# step) 99825 Accuracy(IOU)= 0.4217972
# step) 99826 Accuracy(IOU)= 0.42359078
# step) 99827 Accuracy(IOU)= 0.4244526
# step) 99828 Accuracy(IOU)= 0.42481676
# step) 99829 Accuracy(IOU)= 0.426937
# step) 99830 Accuracy(IOU)= 0.42927834
# step) 99831 Accuracy(IOU)= 0.4280806
# step) 99832 Accuracy(IOU)= 0.42855006
# step) 99833 Accuracy(IOU)= 0.42894322
# step) 99834 Accuracy(IOU)= 0.42985672
# step) 99835 Accuracy(IOU)= 0.43160185
# step) 99836 Accuracy(IOU)= 0.42998898
# step) 99837 Accuracy(IOU)= 0.43036735
# step) 99838 Accuracy(IOU)= 0.43159682
# step) 99839 Accuracy(IOU)= 0.43727303
# step) 99840 Accuracy(IOU)= 0.4338922
# step) 99841 Accuracy(IOU)= 0.43297067
# step) 99842 Accuracy(IOU)= 0.42963526
# step) 99843 Accuracy(IOU)= 0.4339257
# step) 99844 Accuracy(IOU)= 0.43339616
# step) 99845 Accuracy(IOU)= 0.43376124
# step) 99846 Accuracy(IOU)= 0.43380862
# step) 99847 Accuracy(IOU)= 0.4333092
# step) 99848 Accuracy(IOU)= 0.43369782
# step) 99849 Accuracy(IOU)= 0.4333978
# step) 99850 Accuracy(IOU)= 0.4342983
# step) 99851 Accuracy(IOU)= 0.43340838
# step) 99852 Accuracy(IOU)= 0.4337926
# step) 99853 Accuracy(IOU)= 0.4345769
# step) 99854 Accuracy(IOU)= 0.43473905
# step) 99855 Accuracy(IOU)= 0.43508393
# step) 99856 Accuracy(IOU)= 0.43601677
# step) 99857 Accuracy(IOU)= 0.43757796
# step) 99858 Accuracy(IOU)= 0.43716055
# step) 99859 Accuracy(IOU)= 0.43672606
# step) 99860 Accuracy(IOU)= 0.43579444
# step) 99861 Accuracy(IOU)= 0.43770248
# step) 99862 Accuracy(IOU)= 0.43743452
# step) 99863 Accuracy(IOU)= 0.4379819
# step) 99864 Accuracy(IOU)= 0.43572024
# step) 99865 Accuracy(IOU)= 0.43580726
# step) 99866 Accuracy(IOU)= 0.43467104
# step) 99867 Accuracy(IOU)= 0.43346876
# step) 99868 Accuracy(IOU)= 0.43514964
# step) 99869 Accuracy(IOU)= 0.4353259
# step) 99870 Accuracy(IOU)= 0.43446392
# step) 99871 Accuracy(IOU)= 0.4348499
# step) 99872 Accuracy(IOU)= 0.43305075
# step) 99873 Accuracy(IOU)= 0.43182394
# step) 99874 Accuracy(IOU)= 0.43173146
# step) 99875 Accuracy(IOU)= 0.43223527
# step) 99876 Accuracy(IOU)= 0.43193516
# step) 99877 Accuracy(IOU)= 0.43115014
# step) 99878 Accuracy(IOU)= 0.4317252
# step) 99879 Accuracy(IOU)= 0.4321324
# step) 99880 Accuracy(IOU)= 0.43271825
# step) 99881 Accuracy(IOU)= 0.43488702
# step) 99882 Accuracy(IOU)= 0.43190253
# step) 99883 Accuracy(IOU)= 0.432767
# step) 99884 Accuracy(IOU)= 0.43040016
# step) 99885 Accuracy(IOU)= 0.42916244
# step) 99886 Accuracy(IOU)= 0.42864698
# step) 99887 Accuracy(IOU)= 0.4280656
# step) 99888 Accuracy(IOU)= 0.4290724
# step) 99889 Accuracy(IOU)= 0.42984617
# step) 99890 Accuracy(IOU)= 0.42871577
# step) 99891 Accuracy(IOU)= 0.42811278
# step) 99892 Accuracy(IOU)= 0.42935616
# step) 99893 Accuracy(IOU)= 0.42868492
# step) 99894 Accuracy(IOU)= 0.42888963
# step) 99895 Accuracy(IOU)= 0.42637718
# step) 99896 Accuracy(IOU)= 0.426794
# step) 99897 Accuracy(IOU)= 0.43077788
# step) 99898 Accuracy(IOU)= 0.43103868
# step) 99899 Accuracy(IOU)= 0.42948964
# step) 99900 Accuracy(IOU)= 0.4304053
# step) 99901 Accuracy(IOU)= 0.4304119
# step) 99902 Accuracy(IOU)= 0.42777383
# step) 99903 Accuracy(IOU)= 0.42925632
# step) 99904 Accuracy(IOU)= 0.42697203
# step) 99905 Accuracy(IOU)= 0.42730337
# step) 99906 Accuracy(IOU)= 0.42833713
# step) 99907 Accuracy(IOU)= 0.42613393
# step) 99908 Accuracy(IOU)= 0.42654163
# step) 99909 Accuracy(IOU)= 0.43010744
# step) 99910 Accuracy(IOU)= 0.43017688
# step) 99911 Accuracy(IOU)= 0.42927313
# step) 99912 Accuracy(IOU)= 0.429913
# step) 99913 Accuracy(IOU)= 0.43016946
# step) 99914 Accuracy(IOU)= 0.43039757
# step) 99915 Accuracy(IOU)= 0.43092114
# step) 99916 Accuracy(IOU)= 0.42936766
# step) 99917 Accuracy(IOU)= 0.42919162
# step) 99918 Accuracy(IOU)= 0.42995793
# step) 99919 Accuracy(IOU)= 0.43094072
# step) 99920 Accuracy(IOU)= 0.43225682
# step) 99921 Accuracy(IOU)= 0.43043053
# step) 99922 Accuracy(IOU)= 0.42959854
# step) 99923 Accuracy(IOU)= 0.43455276
# step) 99924 Accuracy(IOU)= 0.4355014
# step) 99925 Accuracy(IOU)= 0.4327832
# step) 99926 Accuracy(IOU)= 0.4329968
# step) 99927 Accuracy(IOU)= 0.43242317
# step) 99928 Accuracy(IOU)= 0.4327721
# step) 99929 Accuracy(IOU)= 0.43285868
# step) 99930 Accuracy(IOU)= 0.43226787
# step) 99931 Accuracy(IOU)= 0.43167934
# step) 99932 Accuracy(IOU)= 0.43401578
# step) 99933 Accuracy(IOU)= 0.43393323
# step) 99934 Accuracy(IOU)= 0.43517923
# step) 99935 Accuracy(IOU)= 0.4340996
# step) 99936 Accuracy(IOU)= 0.43258983
# step) 99937 Accuracy(IOU)= 0.4382535
# step) 99938 Accuracy(IOU)= 0.43876666
# step) 99939 Accuracy(IOU)= 0.44092813
# step) 99940 Accuracy(IOU)= 0.44125652
# step) 99941 Accuracy(IOU)= 0.44039848
# step) 99942 Accuracy(IOU)= 0.4383456
# step) 99943 Accuracy(IOU)= 0.44103616
# step) 99944 Accuracy(IOU)= 0.442394
# step) 99945 Accuracy(IOU)= 0.44428498
# step) 99946 Accuracy(IOU)= 0.44912016
# step) 99947 Accuracy(IOU)= 0.4480988
# step) 99948 Accuracy(IOU)= 0.44646758
# step) 99949 Accuracy(IOU)= 0.4467987
# step) 99950 Accuracy(IOU)= 0.4478881
# step) 99951 Accuracy(IOU)= 0.44564024
# step) 99952 Accuracy(IOU)= 0.44343683
# step) 99953 Accuracy(IOU)= 0.44067577
# step) 99954 Accuracy(IOU)= 0.43964094
# step) 99955 Accuracy(IOU)= 0.43815184
# step) 99956 Accuracy(IOU)= 0.43801236
# step) 99957 Accuracy(IOU)= 0.43676704
# step) 99958 Accuracy(IOU)= 0.43633163
# step) 99959 Accuracy(IOU)= 0.437007
# step) 99960 Accuracy(IOU)= 0.4370125
# step) 99961 Accuracy(IOU)= 0.44093508
# step) 99962 Accuracy(IOU)= 0.44386223
# step) 99963 Accuracy(IOU)= 0.4439457
# step) 99964 Accuracy(IOU)= 0.44301662
# step) 99965 Accuracy(IOU)= 0.4460527
# step) 99966 Accuracy(IOU)= 0.44436237
# step) 99967 Accuracy(IOU)= 0.444536
# step) 99968 Accuracy(IOU)= 0.4451821
# step) 99969 Accuracy(IOU)= 0.44511336
# step) 99970 Accuracy(IOU)= 0.44585103
# step) 99971 Accuracy(IOU)= 0.443868
# step) 99972 Accuracy(IOU)= 0.44252083
# step) 99973 Accuracy(IOU)= 0.44152647
# step) 99974 Accuracy(IOU)= 0.44258055
# step) 99975 Accuracy(IOU)= 0.44365987
# step) 99976 Accuracy(IOU)= 0.444697
# step) 99977 Accuracy(IOU)= 0.44635546
# step) 99978 Accuracy(IOU)= 0.44659337
# step) 99979 Accuracy(IOU)= 0.44447243
# step) 99980 Accuracy(IOU)= 0.44427788
# step) 99981 Accuracy(IOU)= 0.4424831
# step) 99982 Accuracy(IOU)= 0.44414353
# step) 99983 Accuracy(IOU)= 0.44405136
# step) 99984 Accuracy(IOU)= 0.44282487
# step) 99985 Accuracy(IOU)= 0.44336227
# step) 99986 Accuracy(IOU)= 0.44334134
# step) 99987 Accuracy(IOU)= 0.4415587
# step) 99988 Accuracy(IOU)= 0.44308293
# step) 99989 Accuracy(IOU)= 0.44239652
# step) 99990 Accuracy(IOU)= 0.44343436
# step) 99991 Accuracy(IOU)= 0.44466153
# step) 99992 Accuracy(IOU)= 0.44569173
# step) 99993 Accuracy(IOU)= 0.44533682
# step) 99994 Accuracy(IOU)= 0.44355956
# step) 99995 Accuracy(IOU)= 0.44320008
# step) 99996 Accuracy(IOU)= 0.441626
# step) 99997 Accuracy(IOU)= 0.4425134
# step) 99998 Accuracy(IOU)= 0.4418245
# step) 99999 Accuracy(IOU)= 0.44063407

# %% [markdown]
# ## 调用微调后的模型

# %%
import numpy as np
import torch
import cv2
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor

# use bfloat16 for the entire script (memory efficient)
torch.autocast(device_type="cuda", dtype=torch.bfloat16).__enter__()

# %%
# Load image

image_path = r"./notebooks/images/Train.png" # path to image
mask_path = r"./notebooks/images/Train_mask.png" # path to mask, the mask will define the image region to segment

def read_image(image_path, mask_path): # read and resize image and mask
        img = cv2.imread(image_path)[...,::-1]  # read image as rgb
        mask = cv2.imread(mask_path,0) # mask of the region we want to segment

        # Resize image to maximum size of 1024

        r = np.min([1024 / img.shape[1], 1024 / img.shape[0]])
        img = cv2.resize(img, (int(img.shape[1] * r), int(img.shape[0] * r)))
        mask = cv2.resize(mask, (int(mask.shape[1] * r), int(mask.shape[0] * r)),interpolation=cv2.INTER_NEAREST)
        return img, mask
image,mask = read_image(image_path, mask_path)
num_samples = 30 # number of points/segment to sample
def get_points(mask,num_points): # Sample points inside the input mask
        points=[]
        for i in range(num_points):
            coords = np.argwhere(mask > 0)
            yx = np.array(coords[np.random.randint(len(coords))])
            points.append([[yx[1], yx[0]]])
        return np.array(points)
input_points = get_points(mask,num_samples)
# read image and sample points

# %%
# Load model
sam2_checkpoint = "./checkpoints/sam2.1_hiera_tiny.pt" # "sam2_hiera_large.pt"
model_cfg = "configs/sam2.1/sam2.1_hiera_t.yaml" # "sam2_hiera_l.yaml"
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda")

# Build net and load weights
predictor = SAM2ImagePredictor(sam2_model)
predictor.model.load_state_dict(torch.load("model_t2.torch"))
# Out:
# <All keys matched successfully>

# %%
# predict mask

with torch.no_grad():
        predictor.set_image(image)
        masks, scores, logits = predictor.predict(
            point_coords=input_points,
            point_labels=np.ones([input_points.shape[0],1])
        )

# Short predicted masks from high to low score

masks=masks[:,0].astype(bool)
shorted_masks = masks[np.argsort(scores[:,0])][::-1].astype(bool)

# Stitch predicted mask into one segmentation mask

seg_map = np.zeros_like(shorted_masks[0],dtype=np.uint8)
occupancy_mask = np.zeros_like(shorted_masks[0],dtype=bool)
for i in range(shorted_masks.shape[0]):
    mask = shorted_masks[i]
    if (mask*occupancy_mask).sum()/mask.sum()>0.15: continue
    mask[occupancy_mask]=0
    seg_map[mask]=i+1
    occupancy_mask[mask]=1

# create colored annotation map
height, width = seg_map.shape

# Create an empty RGB image for the colored annotation
rgb_image = np.zeros((seg_map.shape[0], seg_map.shape[1], 3), dtype=np.uint8)
for id_class in range(1,seg_map.max()+1):
    rgb_image[seg_map == id_class] = [np.random.randint(255), np.random.randint(255), np.random.randint(255)]

# %%
# save and display

cv2.imwrite("annotation2.png",rgb_image)
cv2.imwrite("mix2.png",(rgb_image/2+image/2).astype(np.uint8))

# cv2.imshow("annotation",rgb_image)
# cv2.imshow("mix",(rgb_image/2+image/2).astype(np.uint8))
# cv2.imshow("image",image)
# Out:
# True
